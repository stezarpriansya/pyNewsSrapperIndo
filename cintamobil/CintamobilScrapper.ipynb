# %%
from Cintamobil import Cintamobil
import mysql.connector

# %%
obj = Cintamobil()

# %%
links = obj.getAllBerita([], 125, 'berita-mobil')
# Out:
# page  71
# https://cintamobil.com/berita-mobil/berita-mobil/p71
# memasukkan berita id  1263
# Insert berita  Inden All New Rush Lama, Astrido Lakukan Pendekatan Ke Konsumen Agar Tak Berpaling
# masuk
# memasukkan berita id  1267
# Insert berita  Kalahkan Accord dan Ioniq, Honda Clarity Meraih Penghargaan sebagai Mobil Paling Ramah Lingkungan
# masuk
# memasukkan berita id  1259
# Insert berita  Menggabungkan Efesiensi Mengemudi dengan Gaya Honda, Honda Insight Debut pada New York International Auto Show 2018
# masuk
# memasukkan berita id  1257
# Insert berita  SUV Listrik Ramah Lingkungan Hyundai NEXO Mulai Dipasarkan di Korea Selatan
# masuk
# memasukkan berita id  1256
# Insert berita  SUV Paling Populer di Amerika akan Mendapatkan Make Over Tahun Ini
# masuk
# memasukkan berita id  1258
# Insert berita  Nuansa Nostalgia MINI Electric Klasik dengan Teknologi Masa Depan
# masuk
# memasukkan berita id  1260
# Insert berita  Selamat Datang Toyota C-HR!
# salah2
# memasukkan berita id  1255
# Insert berita  SUV Penantang Honda CR-V, Sokon Glory 580 Bakal Diluncurkan April 2018
# masuk
# memasukkan berita id  1252
# Insert berita  Mitsubishi Xpander Raih Penghargaan Car of The Year Otomotif Award 2018
# masuk
# memasukkan berita id  1251
# Insert berita  Penjualan Menurun Akankah Ignis Bertahan?
# salah2
# page  72
# https://cintamobil.com/berita-mobil/berita-mobil/p72
# memasukkan berita id  1248
# Insert berita  Dukung Pelestarian Sumber Daya Alam Hayati, Toyota Sumbangkan Satu Unit Hilux Ke Yayasan Konservasi di Jawa Barat
# masuk
# memasukkan berita id  1247
# Insert berita  Belajar Off-Road, MMKSI Ajak Pengguna Triton Menjelajah Medan Ekstrem Kopeng Jawa Tengah
# masuk
# memasukkan berita id  1242
# Insert berita  Start-up di Australia ini Ingin Mengadakan Balapan Mobil Terbang
# masuk
# memasukkan berita id  1243
# Insert berita  Masih Kepikiran Selena Gomez, Justin Bieber Terlibat Tabrakan
# masuk
# memasukkan berita id  1244
# Insert berita  Dapatkan Nama Baru, Sedan Toyota Yaris Sedan Versi Amerika Resmi Diperkenalkan
# masuk
# memasukkan berita id  1245
# Insert berita  Toyota Corolla Hatchback Diluncurkan di Amerika
# salah2
# memasukkan berita id  1241
# Insert berita  Seberapa Amankah Teknologi Self-Driving untuk Jalanan Saat ini?
# masuk
# memasukkan berita id  1240
# Insert berita  Mau Beli Xpander? Baca Dulu Berita Ini
# salah2
# memasukkan berita id  1238
# Insert berita  “Garasi Langit” untuk Orang Kaya di Menara Porsche, Miami
# salah2
# memasukkan berita id  1237
# Insert berita  Mengunjungi Showroom Pertama di Dunia, Jack Barclay Bentley di London
# masuk
# page  73
# https://cintamobil.com/berita-mobil/berita-mobil/p73
# memasukkan berita id  1239
# Insert berita  Mercedes-Benz Gelontorkan 100 Juta EURO Di Thailand Untuk Bangun Pabrik Baterai Pertama di ASEAN
# masuk
# memasukkan berita id  1234
# Insert berita  Truk Mercy Axor 4843 K Sasar Perusahaan Tambang di Balikpapan, Kaltim
# masuk
# memasukkan berita id  1233
# Insert berita  Pemeriksaan Masalah Airbag Hyundai Dilakukan Setelah Dua Orang Meninggal
# masuk
# memasukkan berita id  1232
# Insert berita  Cuaca Menjadi Masalah Terbesar Sensor Mobil Otonom Saat Ini
# masuk
# memasukkan berita id  1231
# Insert berita  Mengalami Kecelakaan yang Menewaskan Kekasihnya, Bassis Navicula Kritis di Rumah Sakit
# masuk
# memasukkan berita id  1230
# Insert berita  Toyota Vios 2018 Segera Meluncur Sebelum IIMS?
# salah2
# memasukkan berita id  1228
# Insert berita  Debut Santa Fe, Kona, dan Tucson di Amerika akan Dibarengi dengan Live-Streaming
# masuk
# memasukkan berita id  1229
# Insert berita  Konsep Terbaru Mazda 3 2019
# salah2
# memasukkan berita id  1226
# Insert berita  Duo Indonesia Mendomiasi Kualifikasi Ferrari Challenge Asia di Melbourne GP
# masuk
# memasukkan berita id  1215
# Insert berita  Kenapa Porsche Panamera Bisa Memenangkan Car of the Year di Afrika Selatan?
# masuk
# page  74
# https://cintamobil.com/berita-mobil/berita-mobil/p74
# memasukkan berita id  1216
# Insert berita  Spotify akan Bekerja Sama dengan Cadillac untuk Layanan Musik dalam Mobil
# masuk
# memasukkan berita id  1221
# Insert berita  Teknologi Parkir Otonom Membuat Mobil Menjadi Lebih Mandiri untuk Parkir
# masuk
# memasukkan berita id  1220
# Insert berita  Enam Orang Tewas dalam Kecelakaan Beruntun di Lintas Sumatera, Lampung Selatan
# masuk
# memasukkan berita id  1217
# Insert berita  Kilas Balik Persaingan Harga Mobil LSUV Yang Makin Menghangat
# masuk
# memasukkan berita id  1207
# Insert berita  Mobil Klasik akan Turut Memeriahkan Indonesia International Motor Show 2018 April Nanti
# masuk
# memasukkan berita id  1208
# Insert berita  Kecelakaan Kendaraan Otonom Uber: Uber Bisa Saja Tidak Bersalah
# masuk
# memasukkan berita id  1209
# Insert berita  Mercedes-AMG GT R, Safety Car F1 Tercepat dan Terkuat yang Pernah Ada
# masuk
# memasukkan berita id  1205
# Insert berita  Pikap Legendaris Toyota Hilux Rayakan Hari Jadi Ke-50
# salah2
# memasukkan berita id  1204
# Insert berita  Xpander dan Wuling kalahkan Avanza di Bursa Mobil Bekas
# salah2
# memasukkan berita id  1197
# Insert berita  Mobil Ini Didaulat Sebagai Mobil Terjelek Di Geneva Motor Show 2018
# masuk
# page  75
# https://cintamobil.com/berita-mobil/berita-mobil/p75
# memasukkan berita id  1199
# Insert berita  Layanan Penyewaan Mobil Per Menit Udrive akan Dibuka di Shajah, Uni Emirat Arab
# masuk
# memasukkan berita id  1196
# Insert berita  Nissan GT-R Akan Hadir Di Thailand, Kapan Indonesia?
# salah2
# memasukkan berita id  1202
# Insert berita  Suzuki Karimun Wagon R Tengah Menjalani Proses Desain Facelift Baru
# masuk
# memasukkan berita id  1193
# Insert berita  BMW Kembangkan Drone Tercepat di Dunia Bersama Liga Drone Professional
# masuk
# memasukkan berita id  1192
# Insert berita  LSEV, Kendaraan Mini Hasil Cetak 3D Produksi Massal Pertama di Dunia
# masuk
# memasukkan berita id  1190
# Insert berita  Suara dan Gambar akan Menjadi ‘Bahasa’ Mobil Otonom untuk Berkomunikasi dengan Pejalan Kaki
# masuk
# memasukkan berita id  1194
# Insert berita  Toyota Malaysia Rilis Avanza 1.5X Bergaya Crossover
# salah2
# memasukkan berita id  1189
# Insert berita  Menyingkirkan BMW, Porsche Panamara Memenangkan Car of the Year 2018 di Afrika Selatan
# masuk
# memasukkan berita id  1188
# Insert berita  Teleponan dan Merokok Saat Mengemudi Ditilang; Apa Kata Bos Mitsubishi?
# masuk
# memasukkan berita id  1187
# Insert berita  Kenaikan Harga Mobil Klasik Di Pasar Mobil Dikhawatirkan Memicu Kenaikan Pajak
# masuk
# page  76
# https://cintamobil.com/berita-mobil/berita-mobil/p76
# memasukkan berita id  1185
# Insert berita  Varian Baru Honda Accord Hybrid Meluncur Perdana di Amerika
# masuk
# memasukkan berita id  1184
# Insert berita  Resmi! Peluncuran Facelift New Kia Sedona di Korea Selatan
# salah2
# memasukkan berita id  1183
# Insert berita  5 Mobil Paling Menakjubkan Pilihan Mercedes-Benz
# salah2
# memasukkan berita id  1182
# Insert berita  Presiden Durtete Hancurkan 14 Kendaraan Mewah Ilegal yang Masuk ke Filipina
# masuk
# memasukkan berita id  1130
# Insert berita  Toyota Aygo Baru Siap Dipasarkan Secara Global
# salah2
# memasukkan berita id  1180
# Insert berita  Jangan Harap Ada Toyota 86 Bermesin Turbocharger, Ini Sebabnya
# masuk
# memasukkan berita id  1129
# Insert berita  Datsun Cross Mulai Resmi Dijual, Harga Turun Dari Pengumuman Sebelumnya.
# masuk
# memasukkan berita id  1179
# Insert berita  Gelar SUV Kecil Paling Bisa Diandalkan Jatuh Kepada: Hyundai Tucson!
# masuk
# memasukkan berita id  1174
# Insert berita  Honda Odyssey Baru Mendapatkan Tambahan Fitur Baru dan Desain yang Lebih Stylish
# masuk
# memasukkan berita id  1175
# Insert berita  Genesis Menjadi Pilihan Top Model Teratas Consumer Reports
# masuk
# page  77
# https://cintamobil.com/berita-mobil/berita-mobil/p77
# memasukkan berita id  1170
# Insert berita  Ford Menarik 1.4 Juta Mobil karena Masalah Kemudi yang Kendur
# masuk
# memasukkan berita id  1169
# Insert berita  NHTSA akan Membuat Mobil Listrik dan Hibrida Mengeluarkan Suara ‘Buatan’
# masuk
# memasukkan berita id  1163
# Insert berita  Telaah Uji Kendaraan Diproyeksikan Untuk Mobil Listrik
# salah2
# memasukkan berita id  1162
# Insert berita  Persaingan Sengit Februari 2018, Segmen Mobil Kota Kembali Dikuasai Honda Brio
# masuk
# memasukkan berita id  1161
# Insert berita  BMW akan Memberikan Diskon untuk Pertukaran Mobil Diesel Lama dengan Mobil Baru di Jerman
# masuk
# memasukkan berita id  1160
# Insert berita  Mobil ‘Alien’ Lagonda Vision Terinspirasi dari Fiksi Ilmiah Abad ke-22
# masuk
# memasukkan berita id  1158
# Insert berita  BMW i8 Roadster Mulai Diproduksi Dan Berpeluang Kembali Masuk Pasar Indonesia
# masuk
# memasukkan berita id  1154
# Insert berita  MOI Chapter Banten Siap Menantang Pemenang Seri Sebelumnya dalam Babak Final Honda Mobilio Battle of Efficiency
# masuk
# memasukkan berita id  1156
# Insert berita  What Car? Safety Awards Mengeluarkan Daftar 10 Mobil dengan Tingkat Keselamatan Terbaik Tahun 2018
# masuk
# memasukkan berita id  1155
# Insert berita  Peresmian Diler Pertama di Banyuwangi Menandai Diler ke-112 Mitsubishi di Indonesia
# masuk
# page  78
# https://cintamobil.com/berita-mobil/berita-mobil/p78
# memasukkan berita id  1150
# Insert berita  Xpander Rebut Gelar Mobil Terlaris Februari 2018 Dari Tangan Avanza
# masuk
# memasukkan berita id  1138
# Insert berita  Gambaran Terbaru Lexus UX 2019 yang lebih Dinamis dan Ramah Lingkungan
# masuk
# memasukkan berita id  1127
# Insert berita  Nissan Luncurkan Grand Livina Special Version Dengan Tampilan Lebih Sporty
# masuk
# memasukkan berita id  1128
# Insert berita  Porsche Mission E Cross Turismo Tunjukkan Keseriusan Porsche Bermain Di Segmen Mobil Listrik
# masuk
# memasukkan berita id  1125
# Insert berita  Mesin Terbersih Diesel Bahkan Masih Berpengaruh Buruk pada Lingkungan
# masuk
# memasukkan berita id  1124
# Insert berita  Kesan Anggun dan Menawan kupe 4-pintu BMW M8 Gran Coupe
# salah2
# memasukkan berita id  1123
# Insert berita  Strategi Dual Hybrid pada Debut All New Toyota Auris
# salah2
# memasukkan berita id  1118
# Insert berita  Dari Geneva Motor Show 2018, Dua Mobil Mahal dan Mewah Ini Tak Boleh Melaju di Jalanan Umum
# masuk
# memasukkan berita id  1120
# Insert berita  Ferrari 488 Pista, Kuda V8 Paling Bertenaga Maranello Sarat Nuansa Balap
# masuk
# memasukkan berita id  1116
# Insert berita  10 Mobil Bertenaga Super Besar pada Geneva Motor Show 2018
# masuk
# page  79
# https://cintamobil.com/berita-mobil/berita-mobil/p79
# memasukkan berita id  1117
# Insert berita  10.950 Unit CR-V Terindikasi Recall Terkait Kampanye Product Update
# masuk
# memasukkan berita id  1112
# Insert berita  Coupe Empat Pintu Mercedes AMG GT nan Melesat di Geneva Motor Show
# masuk
# memasukkan berita id  1115
# Insert berita  Oxygene, “Ban Pintar” Goodyear yang Ramah Lingkungan dan Bisa Menghasilkan Tenaga Sendiri
# masuk
# memasukkan berita id  1113
# Insert berita  Orang Tua di Inggris Masih Belum Mengetahui Peraturan Kursi Anak Pada Mobil yang Baru
# masuk
# memasukkan berita id  1099
# Insert berita  Mobil Konsep Toyota GR Supra Hadir Melepas Kenangan pada Geneva Motor Show 2018
# masuk
# memasukkan berita id  1098
# Insert berita  MARET FIESTA, Promo Berlimpah Mitsubishi di Bulan Maret 2018
# masuk
# memasukkan berita id  1105
# Insert berita  Mobil Terbang Ini Siap Dipesan Di Arena Geneva Motor Show 2018
# masuk
# memasukkan berita id  1092
# Insert berita  Mobil-mobil Eksotik Ini Bakal Nampang di Geneva Motor Show 2018
# masuk
# memasukkan berita id  1109
# Insert berita  Menjelajahi Semarang – Solo Bersama MPV Fenomenal Mitsubishi Xpander
# masuk
# memasukkan berita id  1095
# Insert berita  McLaren Senna, Hypercar Bermesin Sangar Seharga 1 Juta Dollar
# masuk
# page  80
# https://cintamobil.com/berita-mobil/berita-mobil/p80
# memasukkan berita id  1094
# Insert berita  Menarik Pelanggan Pre-Order, Polestar 1 Dipajang pada Geneva Motor Show 2018
# masuk
# memasukkan berita id  1093
# Insert berita  Tampilan Berbeda untuk Rancangan Masa depan Hyundai pada Le Fil Rouge
# masuk
# memasukkan berita id  1090
# Insert berita  5 Hal yang Perlu Diketahui dalam Gelaran Geneva Motor Show 2018
# masuk
# memasukkan berita id  1086
# Insert berita  Lexus RX 350L, Pendatang Baru Segmen SUV Mewah di Indonesia
# salah2
# memasukkan berita id  1088
# Insert berita  Tak Ingin Rendahkan Siapapun, Geneva Motor Show 2018 Tak Akan Pakai Booth Girl Berpakaian Minim
# masuk
# memasukkan berita id  1091
# Insert berita  10 Mobil Baru Paling Menarik dalam Gelaran Geneva Motor Show 2018
# masuk
# memasukkan berita id  1076
# Insert berita  Emblem Premier di Chevrolet Trax Coopertino Curi Perhatian Komunitas
# masuk
# memasukkan berita id  1078
# Insert berita  Perkenalkan, Audi A6 Saloon, Mobil Sedan Eksekutif Bertabur Inovasi Futuristik
# masuk
# memasukkan berita id  1074
# Insert berita  Konsep Mobil Masa Depan Icona Nucleus akan Mejeng pada Gelaran Geneva Motor Show 2018
# masuk
# memasukkan berita id  1070
# Insert berita  Jaguar I-Pace Mengalahkan Tesla Model X dalam Pertarungan Drag Mobil Listrik
# masuk
# page  81
# https://cintamobil.com/berita-mobil/berita-mobil/p81
# memasukkan berita id  1072
# Insert berita  KTB Hadirkan Jagoan Baru, Fuso Fighter Plus Fitur GPS Runner Telematics
# masuk
# memasukkan berita id  1065
# Insert berita  Penjualan Meningkat Tajam, Chevrolet Luncurkan Varian Baru Trax Coppertino
# masuk
# memasukkan berita id  1063
# Insert berita  Keinginan Honda Menguasai Trek Balap dengan Honda Civic Type R Time Attack 2018
# masuk
# memasukkan berita id  1057
# Insert berita  Hyundai Santa Fe 2019 Incar Pasar SUV Hybrid Negeri Paman Sam
# masuk
# memasukkan berita id  1048
# Insert berita  Mitsubishi Siapkan 10 Mobil Listrik Untuk Studi Pemerintah
# masuk
# memasukkan berita id  1042
# Insert berita  Mengiklankan SUV EcoSport di Spanyol, Ford Menjadi Pemilik Gelar Papan Reklame Terbesar di Dunia
# masuk
# memasukkan berita id  1056
# Insert berita  Toyota Memperkenalkan Powertrain Baru untuk Peningkatan Performa dan Efisiensi Bahan Bakar
# masuk
# memasukkan berita id  1038
# Insert berita  Kebijakan Baru untuk Impor Mobil Vietnam Ditakutkan Mengganggu Hubungan Dagang Indonesia – Vietnam
# masuk
# memasukkan berita id  1037
# Insert berita  Debut pada Geneva Motor Show, Toyota Aygo 2018 Hadir Lebih Segar dan Ramah Lingkungan
# masuk
# memasukkan berita id  1049
# Insert berita  All-new Nissan Terra Akan Hadir Sebagai Penantang Fortuner dan Pajero Sport
# masuk
# page  82
# https://cintamobil.com/berita-mobil/berita-mobil/p82
# memasukkan berita id  1049
# Insert berita  All-new Nissan Terra Akan Hadir Sebagai Penantang Fortuner dan Pajero Sport
# masuk
# memasukkan berita id  1030
# Insert berita  Pasangan Tunawisma di Newcastle, Australia Mendapatkan Mobil dan Voucher Bensin untuk Awal yang Baru
# masuk
# memasukkan berita id  1047
# Insert berita  Tuna Netra Menjadi Navigator dalam Reli Mobil yang Diadakan di India
# masuk
# memasukkan berita id  1046
# Insert berita  Pameran Otomotif Terbesar Awal Tahun ini, Indonesia International Motor Show Siap Berinovasi
# masuk
# memasukkan berita id  1045
# Insert berita  BMW Melakukan Recall Terhadap 11.700 Mobil Mereka Karena Masalah Perangkat Lunak
# masuk
# memasukkan berita id  1044
# Insert berita  V60 akan Menjadi Mobil Bermesin Bensin Terakhir yang Dikembangkan Volvo
# masuk
# memasukkan berita id  1028
# Insert berita  Pengumpulan Data oleh Mobil: Menguntungkan atau Merusak Privasi Pengemudi?
# masuk
# memasukkan berita id  1034
# Insert berita  Penghargaan Mercedes–Benz terhadap Dealer di Indonesia dalam Car Dealer of the Year 2017
# masuk
# memasukkan berita id  1025
# Insert berita  Walang Sangit Membuat 10.000 Mobil Ekspor Tidak Bisa Masuk ke Selandia Baru
# masuk
# memasukkan berita id  1023
# Insert berita  Hyundai Nexo, Penerus Tucson sebagai Unggulan Hyundai untuk Mobil Listrik
# masuk
# page  83
# https://cintamobil.com/berita-mobil/berita-mobil/p83
# memasukkan berita id  1026
# Insert berita  5 Perbedaan Hyundai i20 facelift 2018 dengan Generasi Terdahulunya
# masuk
# memasukkan berita id  1019
# Insert berita  5 Nama Mobil yang (Sepertinya) Diambil dari Benda-Benda Luar Angkasa, Tapi Tidak Memberikan Kesan Menarik
# masuk
# memasukkan berita id  1016
# Insert berita  Toyota Yaris 2018 Diluncurkan Di Indonesia, Andalkan Pembaruan Wajah
# masuk
# memasukkan berita id  1015
# Insert berita  Mobil Listrik Mungil Ramah Lingkungan, Smart Fortwo Cabrio EV
# masuk
# memasukkan berita id  1010
# Insert berita  Aspark Owl, Mobil Tercepat Sejagad dari Pabrikan Kecil di Jepang
# masuk
# memasukkan berita id  1011
# Insert berita  Alat Baru untuk Membantu membeli Mobil Bekas Dikeluarkan di Inggris
# masuk
# memasukkan berita id  1013
# Insert berita  Honda Akhirnya Meluncurkan Civic Type R Terbaru di Ranah Afrika
# masuk
# memasukkan berita id  1005
# Insert berita  Pengembangan Mobil Otonom: Mengatasi Pengemudi yang Mengantuk
# masuk
# memasukkan berita id  1007
# Insert berita  Toyota akan Melakukan Recall Pada Toyota Camry 2018 dan Beberapa Model Lexus Terbaru
# masuk
# memasukkan berita id  1003
# Insert berita  Hyundai Kona Electric, Mobil Listrik Pemberi Harapan Pasti
# salah2
# page  84
# https://cintamobil.com/berita-mobil/berita-mobil/p84
# memasukkan berita id  1000
# Insert berita  Mengenal Honda Amaze, Kembaran Honda Brio untuk Pasar India
# salah2
# memasukkan berita id  998
# Insert berita  Jalanan di Inggris Mulai menyusut Karena Banyaknya Mobil-Mobil Tua yang Ditelantarkan di Jalanan
# masuk
# memasukkan berita id  1009
# Insert berita  Bersiap-siaplah Penggemar Back to The Future, Mobil DeLorean DMC-12 akan Hadir dengan Spesifikasi Baru
# masuk
# memasukkan berita id  990
# Insert berita  Pencurian Mobil Tanpa Kunci Meningkat dengan Menggunakan Perangkat Lunak di Malaysia
# masuk
# memasukkan berita id  989
# Insert berita  7 Hal yang Akan Hilang Jika Mobil Otonom Diluncurkan di Jalanan
# masuk
# memasukkan berita id  975
# Insert berita  Toyota Camry 2018, Calon Kuat World Car of the Year Tahun ini
# masuk
# memasukkan berita id  969
# Insert berita  Abu-Abu Mulai Digemari Sebagai Warna Mobil Daerah Perkotaan
# masuk
# memasukkan berita id  972
# Insert berita  Profesor Ekonomi di Inggris Menyarankan Pengemudi Membayar Sebanyak Jam Pemakaian Jalan
# masuk
# memasukkan berita id  967
# Insert berita  Honda Menunjukan Peningkatan Impresif Penjualan untuk Daerah Asia dan Oceania
# masuk
# memasukkan berita id  968
# Insert berita  5 Fakta yang Perlu Anda Ketahui Tentang Mitsubishi Eclipse Cross
# masuk
# page  85
# https://cintamobil.com/berita-mobil/berita-mobil/p85
# memasukkan berita id  964
# Insert berita  Raksasa Otomotif Jerman, Audi dan Porsche, akan Bekerja Sama untuk Pengembangan Mobil Listrik
# masuk
# memasukkan berita id  962
# Insert berita  Bus Listrik Diperkirakan akan Beroperasi di Seluruh Dunia pada 2025
# masuk
# memasukkan berita id  965
# Insert berita  Liputan Gelaran Auto Show 2018 yang Diadakan di India
# salah2
# memasukkan berita id  961
# Insert berita  Bus Listrik Dipersiapkan sebagai Armada Pariwisata di Kota Oxford
# masuk
# memasukkan berita id  957
# Insert berita  Volkswagen Meluncurkan Sedan VW Arteon 2019 sebagai Pengganti Sedan CC
# masuk
# memasukkan berita id  956
# Insert berita  Jaguar Berencana Menghidupkan Kembali Mesin Klasik Tipe D
# salah2
# memasukkan berita id  943
# Insert berita  Revolusi Mobil Otonom Semakin Dekat, Bisa Jadi Solusi untuk Kemacetan
# masuk
# memasukkan berita id  941
# Insert berita  Serikat Pekerja Otomotif Jerman Melakukan Pemogokan untuk Mendapatkan Kenaikan Gaji dan Pengurangan Jam Kerja
# masuk
# memasukkan berita id  940
# Insert berita  Produsen Mobil Jerman Mengkonfirmasi Menggunakan Monyet untuk Penelitian Pengujian Asap Diesel
# masuk
# memasukkan berita id  928
# Insert berita  BMW 5-series Touring: Salah Satu Mobil yang Benar-Benar Hebat ini Mendapat Penghargaan Tertinggi?
# masuk
# page  86
# https://cintamobil.com/berita-mobil/berita-mobil/p86
# memasukkan berita id  912
# Insert berita  10 Kasus Pencurian Konverter Katalitik Honda CRV Terjadi Baru-baru ini di London
# masuk
# memasukkan berita id  908
# Insert berita  Mobil Otonom Uber Diperkirakan Bisa Dinikmati 18 Bulan Lagi
# masuk
# memasukkan berita id  916
# Insert berita  Honda Mengumumkan akan Melakukan Recall Terhadap Lima Produk Mobil Mereka
# masuk
# memasukkan berita id  913
# Insert berita  GM dan Tesla Mendapatkan Tuntutan Terkait Uji Coba Mobil Otonom
# masuk
# memasukkan berita id  899
# Insert berita  Berapa Harga Daihatsu Terios 2018 di Indonesia?
# salah2
# memasukkan berita id  898
# Insert berita  Meskipun Melemah, Pasar Otomotif Indonesia Diprediksi Masih Tetap Tangguh
# masuk
# memasukkan berita id  895
# Insert berita  Wayne Rooney Menjual BMW i8 Setelah Dinyatakan Bersalah karena Mengemudi Ketika Mabuk
# masuk
# memasukkan berita id  890
# Insert berita  Perkembangan Industri Mobil Otonom Ditakutkan Menghilangkan Banyak Pekerjaan
# masuk
# memasukkan berita id  889
# Insert berita  Honda Mengeluarkan Civic dan Jazz 2018, Lebih Bertenaga dan Hemat Bahan Bakar
# masuk
# memasukkan berita id  892
# Insert berita  Perusahaan Startup Menyediakan Layanan Makanan dan Minuman Gratis untuk Penumpang Uber
# masuk
# page  87
# https://cintamobil.com/berita-mobil/berita-mobil/p87
# memasukkan berita id  888
# Insert berita  Lexus LC 500 Unjuk Gigi di Film Superhero Marvel Terbaru, Black Panther
# masuk
# memasukkan berita id  886
# Insert berita  Setiap Pelanggan yang Membeli Mobil di Dealer ini akan Mendapatkan Website Pribadi
# masuk
# memasukkan berita id  885
# Insert berita  General Motors Dalam Proses Pengembangan Sistem Perlindungan Pejalan Kaki
# masuk
# memasukkan berita id  864
# Insert berita  Masuk ke Pasar Asia Tenggara, Hyundai Berencana Membuat Pabrik di Indonesia atau Vietnam
# masuk
# memasukkan berita id  863
# Insert berita  Nissan Sedang Mengembangkan ‘Topi’ Pembaca Pikiran Pengemudi
# salah2
# memasukkan berita id  858
# Insert berita  5 Perubahan Menarik Mobil Populer Pada Gelaran Detroit Auto Show 2018
# masuk
# memasukkan berita id  854
# Insert berita  Infiniti Mengawali 2018 dengan Memperbaharui Wajah Produk dan Mobil Unggulan
# masuk
# memasukkan berita id  852
# Insert berita  Honda Insight 2019, Mobil Listrik Hybrid Generasi ke Tiga dari Honda
# masuk
# memasukkan berita id  851
# Insert berita  Niro EV, Mobil Konsep Listrik dari Kia yang Menjadi Pesaing Toyota Prius
# masuk
# memasukkan berita id  848
# Insert berita  Mobil Robot General Motor, GM Cruise, Direncanakan Dijual Pada 2019 Nanti
# masuk
# page  88
# https://cintamobil.com/berita-mobil/berita-mobil/p88
# memasukkan berita id  841
# Insert berita  Showroom Khusus Wanita Akhirnya Pertama Kali Dibuka di Arab Saudi
# masuk
# memasukkan berita id  830
# Insert berita  Mini Menghadirkan Facelift 2018 Dengan Mobil Yang Lebih Berteknologi
# masuk
# memasukkan berita id  821
# Insert berita  Honda Mengembangkan Pabrik Baterai Lithium Ion di India
# salah2
# memasukkan berita id  820
# Insert berita  e-Palette, Mobil Otomatis Masa Depan Keluaran Toyota
# salah2
# memasukkan berita id  808
# Insert berita  Selain Grafis, Nvidia akan Berada pada Dunia Otomotif dalam Beberapa Tahun Kedepan
# masuk
# memasukkan berita id  804
# Insert berita  Kerjasama $200 Juta Renault-Nissan-Mitsubishi untuk Pengembangan Teknologi
# masuk
# memasukkan berita id  798
# Insert berita  Kebijakan Baru Kosta Rika untuk Peningkatan Mobil Plug-In Listrik
# masuk
# memasukkan berita id  794
# Insert berita  Volvo Mempersiapkan Pemakaian “Berlangganan” untuk XC40
# salah2
# memasukkan berita id  792
# Insert berita  Honda, Tesla dan BMW Hadir Sebagai Beberapa Mobil Paling Dicintai oleh Konsumen
# masuk
# memasukkan berita id  791
# Insert berita  Mobil Arcimoto, “Fun Ultility Vehicle”, Memulai Babak Baru untuk Produksi Masal
# masuk
# page  89
# https://cintamobil.com/berita-mobil/berita-mobil/p89
# memasukkan berita id  786
# Insert berita  Hyundai dan Kia Meningkatkan Persaingan untuk Industri Otomotif Dunia
# masuk
# memasukkan berita id  788
# Insert berita  Kabar Buruk, Produksi Tesla Model 3 Akan Molor karena Penjualan Rendah
# masuk
# memasukkan berita id  782
# Insert berita  7 Mobil Paling Dinanti di Indonesia Tahun Ini
# salah2
# memasukkan berita id  779
# Insert berita  Tesla akan Mengeluarkan Truk Pick Up Elektrik dalam Kurun Waktu 2 Tahun
# masuk
# memasukkan berita id  777
# Insert berita  Perkembangan Stasiun Pengisian Daya Mobil Listrik Akan Meningkat Tajam Tahun Depan
# masuk
# memasukkan berita id  771
# Insert berita  Toyota, Hadangan Baru Tesla untuk Kendaraan Listrik di Masa Depan
# masuk
# memasukkan berita id  770
# Insert berita  Apa yang Ditawarkan Industri Otomotif pada 2018?
# salah2
# memasukkan berita id  767
# Insert berita  China Menyetujui Pengujian Mobil Otonom Dilakukan di Jalanan Kota
# masuk
# memasukkan berita id  769
# Insert berita  Ferrari Mengancam akan Mengundurkan Diri Menyusul Rencana Peraturan baru F1
# masuk
# memasukkan berita id  762
# Insert berita  Nissan Menggunakan Mobil Mini untuk Mengetes Ketahanan Cat
# salah2
# page  90
# https://cintamobil.com/berita-mobil/berita-mobil/p90
# memasukkan berita id  752
# Insert berita  Menghindari Emisi, Taksi Kota London Akhirnya masuk dalam Jajaran Mobil Listrik
# masuk
# memasukkan berita id  760
# Insert berita  Honda Bersiap Untuk Perang Industri Otomotif di Masa Depan
# salah2
# memasukkan berita id  756
# Insert berita  ES8, SUV baru milik NIO yang akan Merusak Dominasi Tesla dan BMW
# masuk
# memasukkan berita id  753
# Insert berita  Rencana Besar Alibaba untuk Menjual Mobil dalam “Vending Machine”
# masuk
# memasukkan berita id  747
# Insert berita  Kerjasama Indonesia dan Hyundai dengan Pembangunan Pabrik Bus dan Truk di Karawang
# masuk
# memasukkan berita id  746
# Insert berita  Singapura Memperkenalkan Layanan Berbagi-Pakai Mobil Listrik, BlueSG
# masuk
# memasukkan berita id  739
# Insert berita  Volvo Cars memperkenalkan Polestar sebagai pesaing Tesla dan BMW i
# masuk
# memasukkan berita id  740
# Insert berita  Samsung Menggandeng Renovo Auto untuk Mengembankan Taxi Otonom
# masuk
# memasukkan berita id  741
# Insert berita  Alauda Mark 1: Kendaraan Udara yang Merealisasikan Mobil Terbang di Karya Fiksi Ilmiah
# masuk
# memasukkan berita id  737
# Insert berita  Nissan Last Jedi: Mobil Promosi Nissan untuk Star Wars: The Last Jedi
# masuk
# page  91
# https://cintamobil.com/berita-mobil/berita-mobil/p91
# memasukkan berita id  736
# Insert berita  Benarkah Generasi Z Saat ini Tidak Membutuhkan Mobil Lagi?
# salah2
# memasukkan berita id  734
# Insert berita  Uniti Memperkenalkan Mobil Masa Depan yang Ramah Lingkungan
# masuk
# memasukkan berita id  733
# Insert berita  Pemerintah akan Menjalani Uji Coba Mobil Listrik Terbaru Mitsubishi Tahun Depan
# masuk
# memasukkan berita id  732
# Insert berita  Ford Dikabarkan akan Membuat Perjanjian Penjualan Mobil Secara Online dengan Alibaba
# masuk
# memasukkan berita id  730
# Insert berita  Rencana Besar BMW untuk Meningkatkan Penjualan Global
# salah2
# memasukkan berita id  731
# Insert berita  Mengapa Penjualan Mobil di Amerika Tidak Mengalami Penurunan?
# masuk
# memasukkan berita id  727
# Insert berita  REDS Project Redspace Untuk Solusi Kepadatan Lalu Lintas di “Megacity”
# masuk
# memasukkan berita id  720
# Insert berita  Chevrolet Bolt, Flagship General Motor untuk Persaingan Mobil Tanpa Sopir
# masuk
# memasukkan berita id  721
# Insert berita  Menteri Perindustrian Meminta Pelaku Industri Indonesia untuk Semakin Kompetitif
# masuk
# memasukkan berita id  718
# Insert berita  Sokonindo Automobile, Geliat Baru Industri Otomotif di Indonesia
# masuk
# page  92
# https://cintamobil.com/berita-mobil/berita-mobil/p92
# memasukkan berita id  717
# Insert berita  Nissan Akan Memperkenalkan Infiniti QX50: Mesin Bensin Belum Mati
# masuk
# memasukkan berita id  710
# Insert berita  Salahkah Toyota Mengembangkan Mobil Bertenaga Hidrogen?
# salah2
# memasukkan berita id  708
# Insert berita  Honda Melakukan Recall untuk Honda Accord di Seluruh Dunia
# salah2
# memasukkan berita id  707
# Insert berita  Mitsubishi Memilih untuk Mengembangkan Sedan dan Truk Pickup
# masuk
# memasukkan berita id  706
# Insert berita  Keperkasaan Tesla dalam Industri Otomotif Dunia
# salah2
# memasukkan berita id  689
# Insert berita  Uber Mempersiapkan 24.000 SUV XC90 sebagai mobil Driverless Terdepan
# masuk
# memasukkan berita id  690
# Insert berita  Pertamina Mengatakan Kemungkinan Kenaikan BBM Tahun Depan
# salah2
# memasukkan berita id  684
# Insert berita  Elon Musk: Perjalanan Jauh Dengan Truk Akan Menjadi Lebih Mudah Di Masa Depan
# masuk
# memasukkan berita id  679
# Insert berita  Pemerintah Menjanjikan Undang-Undang Kendaraan Rendah Emisi Selesai Tahun Ini
# masuk
# memasukkan berita id  673
# Insert berita  Mobil Terlaris dan Mobil Terugi selama 2017
# salah2
# page  93
# https://cintamobil.com/berita-mobil/berita-mobil/p93
# memasukkan berita id  674
# Insert berita  Mantan Wakil Ketua General Motors Meramalkan Kematian Industri Otomotif
# masuk
# memasukkan berita id  668
# Insert berita  5 Pekerjaan Otomotif dengan Penghasilan Besar
# salah2
# memasukkan berita id  666
# Insert berita  Ford dan Zetye Mengumumkan Investasi Senilai 5 Milliar Yuan
# masuk
# memasukkan berita id  656
# Insert berita  BMW M3 CS Terbaru Diluncurkan, Berapa Harganya?
# masuk
# memasukkan berita id  659
# Insert berita  Audi Memilih Detroit Show untuk Penampilan Perdana A7
# masuk
# memasukkan berita id  660
# Insert berita  Indonesia akan Menjadi Tuan Rumah Small Engines Technology Conference
# masuk
# memasukkan berita id  661
# Insert berita  Misi Ambisius China terhadap Perkembangan Otomotif Dunia
# masuk
# memasukkan berita id  649
# Insert berita  Era Baru untuk Mobil Listrik
# masuk
# memasukkan berita id  655
# Insert berita  Pemerintah akan Menggunakan Metode Genap-Ganjil untuk Mengurai Kemacetan di Tol Cikampek
# masuk
# memasukkan berita id  654
# Insert berita  Banyak Promo Menanti dalam Gelaran BMW Exhibition 2017 di Plaza Senayan
# masuk
# page  94
# https://cintamobil.com/berita-mobil/berita-mobil/p94
# memasukkan berita id  651
# Insert berita  Ferrari: Race to Immortality, Mengenang Tragedi Ferrari tahun 1950an
# masuk
# memasukkan berita id  648
# Insert berita  CEO Toyota Mendapatkan 2 Penghargaan Indonesia Foreign CEO Awards
# masuk
# memasukkan berita id  641
# Insert berita  Inilah Alasan Anda Tidak Boleh Meletakkan Kaki di Atas Dashboard
# masuk
# memasukkan berita id  640
# Insert berita  Kenapa Mobil Buatan Pabrikan Jepang Bisa Menguasai Pasar Otomotif Indonesia?
# masuk
# memasukkan berita id  630
# Insert berita  Pemerintah Mengembangkan Pembangunan Mobil Listrik Untuk 2025
# masuk
# memasukkan berita id  629
# Insert berita  Wuling Confero, Mobil LMPV asal China mulai dicintai
# masuk
# memasukkan berita id  628
# Insert berita  Akankah Honda CR-V Hybrid Dijual Di Indonesia?
# masuk
# memasukkan berita id  623
# Insert berita  Mobil Konsep Baru Yamaha Hasil Garapan Desainer Tim Formula 1
# masuk
# memasukkan berita id  622
# Insert berita  Mazda Kai Concept – Desain Dan Teknologi  Mazda Masa Depan
# masuk
# memasukkan berita id  621
# Insert berita  i-Performance, Teknologi Listrik BMW Siap Masuk Indonesia
# masuk
# page  95
# https://cintamobil.com/berita-mobil/berita-mobil/p95
# memasukkan berita id  619
# Insert berita  Tujuan Indonesia Road Safety Award (IRSA) 2017  Menekan Angka Kecelakaan Jalan Raya
# masuk
# memasukkan berita id  618
# Insert berita  Jumlah Pelanggaran Lalu Lintas Di Indonesia Terus Meningkat Dari Tahun Ke Tahun
# masuk
# memasukkan berita id  620
# Insert berita  Sports EV Concept: Apa Yang Menarik Dalam Model ini?
# masuk
# memasukkan berita id  612
# Insert berita  1.000.000 Unit Mercedes-Benz Recall Karena Masalah Airbagnya
# masuk
# memasukkan berita id  615
# Insert berita  Apakah Harga Murah Wuling Bisa Bertahan Masa Depan?
# masuk
# memasukkan berita id  614
# Insert berita  Suzuki Ertiga Terbaru Punya Perubahan Drastis
# masuk
# memasukkan berita id  617
# Insert berita  Apakah Generasi Terbaru Honda Freed Dijual Di Indonesia?
# masuk
# memasukkan berita id  616
# Insert berita  Bisakah Mobil Note e-Power Dijual Di Luar Jepang?
# masuk
# memasukkan berita id  609
# Insert berita  Apakah Etios Valco Terus Diproduksi Di Tanah Air?
# masuk
# memasukkan berita id  608
# Insert berita  Mazda Hadiri Pameran Tokyo Motor Show Dengan Mobil Konsep Barunya
# masuk
# page  96
# https://cintamobil.com/berita-mobil/berita-mobil/p96
# memasukkan berita id  608
# Insert berita  Mazda Hadiri Pameran Tokyo Motor Show Dengan Mobil Konsep Barunya
# masuk
# memasukkan berita id  607
# Insert berita  Concept-i Series, Pengejawantahan Masa Depan Mobilitas Manusia
# masuk
# memasukkan berita id  606
# Insert berita  Wuling Cortez Siap Masuk Pasar Otomotif Tanah Air Pada Tahun Depan
# masuk
# memasukkan berita id  604
# Insert berita  Spare Part Lebih Murah 20 Persen, Wuling Confero Memuaskan Konsumen
# masuk
# memasukkan berita id  605
# Insert berita  Beli Mobil Suzuki, Dapatkan Hadiah Menarik Secara Langsung
# masuk
# memasukkan berita id  602
# Insert berita  Pemilik SIM Pertama Di Dunia
# masuk
# memasukkan berita id  598
# Insert berita  BMW Mampu Menjadi Mobil Kepresidenan Republik Indonesia?
# masuk
# memasukkan berita id  597
# Insert berita  Wuling Siap Memperkenalkan Mobil Berharga Dibawah Rp.100 Juta
# masuk
# memasukkan berita id  593
# Insert berita  Target 100 Persen Transaksi Non-tunai Siap Tercapai
# masuk
# memasukkan berita id  594
# Insert berita  Honda Accord 2018 Diharapkan Menempati Posisi Terdepan Di Segmen Sedan
# masuk
# page  97
# https://cintamobil.com/berita-mobil/berita-mobil/p97
# memasukkan berita id  594
# Insert berita  Honda Accord 2018 Diharapkan Menempati Posisi Terdepan Di Segmen Sedan
# masuk
# memasukkan berita id  591
# Insert berita  Spyshot SX4 S-Cross Facelift Baru Terungkap
# masuk
# memasukkan berita id  590
# Insert berita  5 Pabrik Nissan Ada Kecurangan Dalam Proses Produksi Mobilnya
# masuk
# memasukkan berita id  586
# Insert berita  Bisakah Jakarta Akan Menjadi Tuan Rumah Formula E?
# masuk
# memasukkan berita id  587
# Insert berita  Momen Buruk Terakhir Seorang Pengendara Sepeda Motor
# masuk
# memasukkan berita id  584
# Insert berita  Setelah Keberhasilan Xpander, Mitsubishi Lanjut Membuka Dealer Di Kalimantan Timur
# masuk
# memasukkan berita id  581
# Insert berita  Harga Nissan Teana 2018 Meningkat Sedikit
# masuk
# memasukkan berita id  579
# Insert berita  Truck Chevrolet edisi Centennial Terlihat Sangat Sporty Dengan Desain Eksterior Dan Interior Modern
# masuk
# memasukkan berita id  580
# Insert berita  Rolls-Royce Phantom Melompat Ke “Lubang Kematian”
# masuk
# memasukkan berita id  576
# Insert berita  Xpander Akan Diekspor Ke Asia Tenggara Melalui MMKSI
# masuk
# page  98
# https://cintamobil.com/berita-mobil/berita-mobil/p98
# memasukkan berita id  575
# Insert berita  Toyota Menutup Pabriknya Di Australia Setelah 54 Tahun Beroperasi
# masuk
# memasukkan berita id  574
# Insert berita  Nissan Jepang: Bisa Rugi 25 Miliar Yen Untuk Recall 1.2 Juta Mobil
# masuk
# memasukkan berita id  571
# Insert berita  Setelah Persembunyian, Begini Penampilan Suzuki Jimny Generasi Ke-4 Disingkap
# masuk
# memasukkan berita id  570
# Insert berita  Rival Mercedes-Benz S Class, BMW Seri 8 Siap Diproduksi Di Jerman
# masuk
# memasukkan berita id  569
# Insert berita  Model Mobil Apa Yang Paling Dicintai Oleh Keluarga Indonesia?
# masuk
# memasukkan berita id  568
# Insert berita  Toyota Avanza Menjadi Mobil Favorit Keluarga Pada Ajang Readers Choice Award 2017
# masuk
# memasukkan berita id  567
# Insert berita  Lanjutkan Urban EV, Honda Menyiapkan Kehadiran Mobil Listrik Barunya, Sport EV Concept
# masuk
# memasukkan berita id  566
# Insert berita  Banyak Pemasok ASEAN Diterima Penghargaan “GM Southeast Asia 2016 Supplier Quality Excellence Awards”
# masuk
# memasukkan berita id  564
# Insert berita  Kia Stinger Bisa Dipesan Pada Akhir Tahun 2017
# masuk
# memasukkan berita id  563
# Insert berita  Confero S 1.5L Menjadi Mobil Terlaris Wuling
# masuk
# page  99
# https://cintamobil.com/berita-mobil/berita-mobil/p99
# memasukkan berita id  562
# Insert berita  Apakah Pintu Mobil Tesla Otomatis Terbuka Sendiri?
# masuk
# memasukkan berita id  561
# Insert berita  Mitsubishi Siap Mengirim Xpander Pada Awal Oktober
# masuk
# memasukkan berita id  560
# Insert berita  Resmikan Dealer Baru, Honda Lebarkan Sayap Di Tangerang
# masuk
# memasukkan berita id  559
# Insert berita  Mitsubishi Meluncurkan Outlander PHEV Baru Di Amerika Serikat
# masuk
# memasukkan berita id  558
# Insert berita  Wuling Mencatat Ribuan SPK Di Tanah Air
# masuk
# memasukkan berita id  557
# Insert berita  Tata Meluncurkan Mobil Baru Dalam Segmen SUV
# masuk
# memasukkan berita id  556
# Insert berita  Suzuki Xbee Siap Diluncurkan, Menjanjikan Gaya Yang Lebih Beragam
# masuk
# memasukkan berita id  555
# Insert berita  Inilah 15 Merek Mobil Yang Punya Nilai Tertinggi Di Dunia
# masuk
# memasukkan berita id  553
# Insert berita  Power Steering Berisiko Mati, 60.000 Unit Sedan Mazda6 di-Recall
# masuk
# memasukkan berita id  554
# Insert berita  GIIAS Surabaya 2017: Honda Mencatat Penjualan 515 Unit Mobil
# masuk
# page  100
# https://cintamobil.com/berita-mobil/berita-mobil/p100
# memasukkan berita id  552
# Insert berita  HR-V Devotee Indonesia Gelar Jambore Nasional Kedua
# masuk
# memasukkan berita id  551
# Insert berita  5 Model Mobil Finalis Forwot Car of The Year 2017
# masuk
# memasukkan berita id  550
# Insert berita  Honda Odyssey Raih 5 Bintang Dalam Uji Tabrak di Amerika
# masuk
# memasukkan berita id  549
# Insert berita  Kamera CCTV Telah Dipasang Untuk E-Tilang Di Persimpangan Kota Semarang
# masuk
# memasukkan berita id  548
# Insert berita  GIIAS Surabaya 2017: Mitsubishi Xpander Mencuri Perhatian, Pemesanan Melebihi Ekspektasi
# masuk
# memasukkan berita id  547
# Insert berita  Konsep Mitsubishi Evo Baru: Tidak Berbentuk Sedan Lagi
# masuk
# memasukkan berita id  544
# Insert berita  Wuling Terlambat Mendirikan 50 Dealer Di Seluruh Indonesia
# masuk
# memasukkan berita id  546
# Insert berita  Adakah Perbedaan Asuransi Untuk Mobil Mewah Dengan Mobil Biasa?
# masuk
# memasukkan berita id  545
# Insert berita  Model Honda Baru Hadir Di GIIAS Surabaya 2017
# masuk
# memasukkan berita id  542
# Insert berita  GIIAS Surabaya 2017: Suzuki Kasih Diskon Gede-Gedean Hingga Rp 29 Juta
# masuk
# page  101
# https://cintamobil.com/berita-mobil/berita-mobil/p101
# memasukkan berita id  538
# Insert berita  Toyota Siap Meluncurkan Beragam Varian Sporty GR Baru
# masuk
# memasukkan berita id  541
# Insert berita  GIIAS 2017 Kembali Berlangsung Di Surabaya
# masuk
# memasukkan berita id  543
# Insert berita  Honda Accord 2018 Resmi Diproduksi Di Pabrik Ohio, Amerika
# masuk
# memasukkan berita id  537
# Insert berita  110 Gran Max Moko Siap Ramaikan Festival Bisnis Di Bandung
# masuk
# memasukkan berita id  540
# Insert berita  150 Juta Unit Mobil Nissan Diproduksi Di Seluruh Dunia
# masuk
# memasukkan berita id  539
# Insert berita  Toyota Hadirkan Hilux Edisi Spesial 50 Tahun
# masuk
# memasukkan berita id  535
# Insert berita  Pengiriman BR-V Ke Dealer Turun Tajam, Inilah Penjelasan Dari Honda
# masuk
# memasukkan berita id  533
# Insert berita  Ini Daftar 10 Mobil Terlaris Selama Delapan Bulan Pertama 2017
# masuk
# memasukkan berita id  536
# Insert berita  Memilih Mobil Bekas Non-Jepang Di Bawah Rp 100 Juta
# masuk
# memasukkan berita id  531
# Insert berita  Wuling Resmikan Diler Kedua Di Kendari, Sulawesi
# masuk
# page  102
# https://cintamobil.com/berita-mobil/berita-mobil/p102
# memasukkan berita id  532
# Insert berita  BMW: Kunci Mobil Bisa Diganti Dengan Aplikasi Telepon
# masuk
# memasukkan berita id  527
# Insert berita  Pemilik Mobil Wajib Memiliki Garasi
# masuk
# memasukkan berita id  529
# Insert berita  Mazda CX-5 Terbaru Mendapat Rating Keselamatan Berbintang 5 Dari Euro NCAP
# masuk
# memasukkan berita id  528
# Insert berita  Jumlah Mobil Dari Indonesia Semakin Meningkat Di Pasar Vietnam
# masuk
# memasukkan berita id  525
# Insert berita  Dealer Mobil Terkecil Di Dunia
# masuk
# memasukkan berita id  524
# Insert berita  Toyota Siap Perkenalkan Land Cruiser Prado Terbaru
# masuk
# memasukkan berita id  523
# Insert berita  Siap – Siap! Suzuki Swift Diluncurkan Pertengahan September
# masuk
# memasukkan berita id  508
# Insert berita  Model Sport Toyota Siap Debut Perdana Bulan Depan
# masuk
# memasukkan berita id  517
# Insert berita  Peningkatan Penjualan: Sinyal Positif Pada Pasar Otomotif Asia Tenggara
# masuk
# memasukkan berita id  516
# Insert berita  Voxy, Xpander: Penjualan Melebihi Ekspektasi
# masuk
# page  103
# https://cintamobil.com/berita-mobil/berita-mobil/p103
# memasukkan berita id  522
# Insert berita  Top 10 Mobil Asia Terlaris di Dunia: Toyota & Honda On Top
# masuk
# memasukkan berita id  521
# Insert berita  Model SUV Nissan elektrik Akan Diluncurkan pada bulan Oktober mendatang!
# masuk
# memasukkan berita id  513
# Insert berita  Vietnam Akan Punya Mobil Nasional
# masuk
# memasukkan berita id  514
# Insert berita  Pajak Sedan Turun, Toyota Tetap Optimis
# masuk
# memasukkan berita id  507
# Insert berita  Honda Pamerkan Gambar Urban EV terbarunya
# masuk
# memasukkan berita id  520
# Insert berita  Ini Harga BMW M3 Milik Hamish Daud
# masuk
# memasukkan berita id  519
# Insert berita  Tol Jagorawi: Tidak Lagi Ambil Kartu dari tanggal 8 bulan September 2017
# masuk
# memasukkan berita id  511
# Insert berita  India: Pajak Mobil Mewah Dinaikkan
# masuk
# memasukkan berita id  515
# Insert berita  Mitsubishi Tambah Dealer Baru di Bengkulu
# masuk
# memasukkan berita id  512
# Insert berita  Sudah Berapa Pengguna e-Money di Indonesia?
# masuk
# page  104
# https://cintamobil.com/berita-mobil/berita-mobil/p104
# memasukkan berita id  509
# Insert berita  Toyota Siap Meluncurkan C-HR Hy-Power Di Frankfurt
# masuk
# memasukkan berita id  510
# Insert berita  Mercedes-Benz EQ A Concept Debut di FrankFurt Motor Show 2017
# masuk
# memasukkan berita id  502
# Insert berita  Toyota Indonesia Sudah Siap Kirim Mobil ke Australia?
# masuk
# memasukkan berita id  503
# Insert berita  Nissan Fairlady Z 2018, Apa Bedanya?
# masuk
# memasukkan berita id  504
# Insert berita  Nissan Menarik Pelanggan Dengan Cara Menjual Mobil Secara Fleet
# masuk
# memasukkan berita id  499
# Insert berita  Toyota Indonesia Recall Ribuan Mobil Karena  Airbag Bermasalah
# masuk
# memasukkan berita id  501
# Insert berita  Produksi MPV: Alasan Ekspor Mobil Di Indonesia Turun?
# masuk
# memasukkan berita id  500
# Insert berita  Daihatsu Dress-Up Challenge Sukses Digelar Di Balikpapan
# masuk
# memasukkan berita id  498
# Insert berita  Honda Civic  menabrak  belakang Audi, 9 orang segera melarikan  diri
# masuk
# memasukkan berita id  496
# Insert berita  Bermain Mobil Antik, Sabar Saja
# masuk
# page  105
# https://cintamobil.com/berita-mobil/berita-mobil/p105
# memasukkan berita id  497
# Insert berita  Kalau Pajak Sedan Turun, Nissan Sudah Siap
# masuk
# memasukkan berita id  490
# Insert berita  Honda Resmikan Dealer Pertama di Papua
# masuk
# memasukkan berita id  488
# Insert berita  Pakai e-toll  Di Gerbang Tol Dimiliki PT Jasa Marga Dapat Diskon 10 Persen
# masuk
# memasukkan berita id  489
# Insert berita  Pajak Sedan Turun: Ekspor Mobil Berpotensi Meningkat
# masuk
# memasukkan berita id  484
# Insert berita  Gaikindo: Indonesia Jago Kandang, Kalah Produksi Dari Thailand
# masuk
# memasukkan berita id  483
# Insert berita  Mengapa Honda Civic Type R Hanya Ada Transmisi Manual?
# masuk
# memasukkan berita id  482
# Insert berita  5 Pemilik Mobil Pertama di Indonesia
# masuk
# memasukkan berita id  481
# Insert berita  Perkuat Aura Elegan, Honda Beri Aksesori Resmi Untuk Civic Hatchback
# masuk
# memasukkan berita id  480
# Insert berita  Pembatasan Motor: Solusi Untuk Mengurangi Kemacetan Di Jakarta
# masuk
# memasukkan berita id  479
# Insert berita  Suzuki Baleno: Sedan Berubah Menjadi Berbentuk Hatchback
# masuk
# page  106
# https://cintamobil.com/berita-mobil/berita-mobil/p106
# memasukkan berita id  477
# Insert berita  Tanpa Produk Baru, KMI Masih Memperoleh 206 Pesanan di Ajang GIIAS 2017
# masuk
# memasukkan berita id  476
# Insert berita  GIIAS 2018 Diharapkan Lebih Banyak Mobil Ramah Lingkungannya
# masuk
# memasukkan berita id  471
# Insert berita  5 Juta Orang Indonesia Mampu Beli Mobil Mewah
# masuk
# memasukkan berita id  470
# Insert berita  Daftar Gerbang Tol Non Tunai Milik Jasa Marga
# masuk
# memasukkan berita id  469
# Insert berita  Proyek Ambisius, Australia Bangun Tol Khusus Mobil Listrik
# masuk
# memasukkan berita id  467
# Insert berita  5 Mobil Honda Terlaris Pada Bulan Juli 2017
# masuk
# memasukkan berita id  466
# Insert berita  Mitsubishi Xpander: Mobil Terlaris Di GIIAS 2017
# masuk
# memasukkan berita id  465
# Insert berita  17.000 Unit Kendaraan Ditransaksikan Dalam GIIAS 2017
# masuk
# memasukkan berita id  463
# Insert berita  755 Angkutan Umum Di Kota Bekasi Belum Lakukan Uji KIR
# masuk
# memasukkan berita id  462
# Insert berita  Perbedaan Pria Dan Wanita Saat Membeli Mobil
# masuk
# page  107
# https://cintamobil.com/berita-mobil/berita-mobil/p107
# memasukkan berita id  461
# Insert berita  Mobil Murah Toyota Resmi Diluncurkan Di Thailand, Harganya Mulai Rp 188 Juta
# masuk
# memasukkan berita id  459
# Insert berita  Samsat Online di Kampus Dibuka, Civitas Academica Lebih Mudah Bayar Pajak Kendaraan
# masuk
# memasukkan berita id  456
# Insert berita  Promo Menarik dari Goodyear di GIIAS 2017
# masuk
# memasukkan berita id  455
# Insert berita  Keren! Beli Honda di GIIAS 2017, Bisa Gratis ke Jepang
# masuk
# memasukkan berita id  453
# Insert berita  Nissan Note e-Power: Teknologi Hybrid Pada Mobil Masa Depan
# masuk
# memasukkan berita id  106
# Insert berita  Toyota Indonesia Recall 44 Ribu Mobil Yang Ada Masalah Tentang  Airbag
# masuk
# memasukkan berita id  301
# Insert berita  BMW 850 CSi: Timeless Design, Ultimate Driving Machine
# masuk
# memasukkan berita id  323
# Insert berita  Pilihan SUV Bekas Terbaik Rp 150 Jutaan
# masuk
# memasukkan berita id  38
# Insert berita  15 Mobil Amazing Para Pemimpin Dunia dan Kerajaan
# masuk
# memasukkan berita id  170
# Insert berita  Alasan Toyota Agya Terbaru Tanpa Head Unit Audio Layar Sentuh
# masuk
# page  108
# https://cintamobil.com/berita-mobil/berita-mobil/p108
# memasukkan berita id  281
# Insert berita  Harga Lengkap Nissan March dan Nissan Grand Livina  Sebelum Diskon
# masuk
# memasukkan berita id  296
# Insert berita  GIIAS 2017 Pamerkan Mobilitas Masa Depan
# masuk
# memasukkan berita id  422
# Insert berita  Inilah Alasan Honda CR-V 2017  ada Pilihan 7-seater
# masuk
# memasukkan berita id  427
# Insert berita  “VMS” 2017 Ke-13 Siap Berlangsung pada Bulan Agustus Menjelang di Vietnam!
# masuk
# memasukkan berita id  416
# Insert berita  Mobil Listrik Tanpa “PPnBM” di Indonesia
# masuk
# memasukkan berita id  367
# Insert berita  Peugeot Siapkan Penawaran Khusus
# masuk
# memasukkan berita id  398
# Insert berita  Berapa Harga Mazda CX-5 Terbaru Saat Meluncur di Nusantara?
# masuk
# memasukkan berita id  196
# Insert berita  Hebat banget!  Mobil Porsche Dipakai untuk Menderek Airbus A380.
# masuk
# memasukkan berita id  365
# Insert berita  Tahun Depan, Honda Rilis Dua Mobil Listrik
# masuk
# memasukkan berita id  364
# Insert berita  Dibekali Fitur Canggih, Tesla Model X Jadi SUV Paling Aman
# masuk
# page  109
# https://cintamobil.com/berita-mobil/berita-mobil/p109
# memasukkan berita id  396
# Insert berita  Pada Tahun 2019, Setiap Mobil VW Bisa Bicara
# masuk
# memasukkan berita id  393
# Insert berita  Tiga Lubang Knalpot Honda Civic Type R, Buat Apa?
# masuk
# memasukkan berita id  294
# Insert berita  Puluhan Pabrikan Ikut Tokyo Motor Show, Big 3 Tidak Gabung
# masuk
# memasukkan berita id  397
# Insert berita  Sampai Akhir Tahun 2017, Jakarta menyembut 19 Dialer Wuling!
# masuk
# memasukkan berita id  392
# Insert berita  Rem Parkir Rentan Karat, Mazda Recall Ratusan Ribu Mobil
# masuk
# memasukkan berita id  51
# Insert berita  Tren penjualan Mobil Bekas pada 2017 Di Indonesia
# masuk
# memasukkan berita id  362
# Insert berita  10 Mobil Terlaris di Dunia
# masuk
# memasukkan berita id  253
# Insert berita  Ignis Laris, Suzuki Tambah Dialer dan Perkuat Jual Purna
# masuk
# memasukkan berita id  92
# Insert berita  Varian Mobil Ramah Lingkungan Udah Diperkenalkan Honda
# masuk
# memasukkan berita id  291
# Insert berita  Tampilan Liar Jeep “Off-Road” Tahun 2035
# masuk
# page  110
# https://cintamobil.com/berita-mobil/berita-mobil/p110
# memasukkan berita id  176
# Insert berita  Ignis Laku, Suzuki Makin “Pede”
# masuk
# memasukkan berita id  209
# Insert berita  Nissan Berikan Layanan Purna Jual  Menarik  sebelum Puasa & Lebaran
# masuk
# memasukkan berita id  142
# Insert berita  ​ Mark Zuckerberg Jadi Buruh Pabrik Mobil
# masuk
# memasukkan berita id  188
# Insert berita  Inilah Generasi Lancer Terakhir Jika Mitsubishi Menghentikan Produksinya
# masuk
# memasukkan berita id  335
# Insert berita  Harga Resmi Honda Civic Hatchback Turbo
# masuk
# memasukkan berita id  341
# Insert berita  7 Alasan yang Membuat Para Cewek Suka Selfie di Dalam Mobil
# masuk
# memasukkan berita id  306
# Insert berita  Berapa Harga Toyota C-HR Jika Masuk Indonesia?
# masuk
# memasukkan berita id  340
# Insert berita  Model Cantik Bergaya di Samping Mobil Klasik
# masuk
# memasukkan berita id  339
# Insert berita  Mengapa Toyota Kijang bisa bertahan 40 tahun di otomotif Indonesia?
# masuk
# memasukkan berita id  338
# Insert berita  Lima Mobil Referensi yang Diminatti Banyak Remaja Indonesia
# masuk
# page  111
# https://cintamobil.com/berita-mobil/berita-mobil/p111
# memasukkan berita id  337
# Insert berita  Semua Mobil Baru Nissan Akan Pakai Rem Darurat Otomatis
# masuk
# memasukkan berita id  336
# Insert berita  Suzuki Meramaikan Jakarta Fair Kemayoran 2017
# masuk
# memasukkan berita id  334
# Insert berita  Promo Penjualan Wuling di Jakarta Fair 2017
# masuk
# memasukkan berita id  333
# Insert berita  Wuling Confero S Dijual Seharga Rp 130 Juta Sepanjang Jakarta Fair 2017
# masuk
# ...
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      53             #     break
#      54             # else:
# ---> 55             detail = self.getDetailBerita(link)
#      56             if self.insertDB(con, detail):
#      57                 details.append(detail)
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getDetailBerita(self, link)
#      79         html = response.text
#      80         # Create a BeautifulSoup object from the HTML: soup
# ---> 81         soup = BeautifulSoup(html, "html5lib")
#      82
#      83         #category
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     226             self.reset()
#     227             try:
# --> 228                 self._feed()
#     229                 break
#     230             except ParserRejectedMarkup:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\bs4\__init__.py in _feed(self)
#     287         self.builder.reset()
#     288
# --> 289         self.builder.feed(self.markup)
#     290         # Close out any unfinished strings and close all the open tags.
#     291         self.endData()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\bs4\builder\_html5lib.py in feed(self, markup)
#      70             else:
#      71                 extra_kwargs['encoding'] = self.user_specified_encoding
# ---> 72         doc = parser.parse(markup, **extra_kwargs)
#      73
#      74         # Set the character encoding detected by the tokenizer.
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\html5lib\html5parser.py in parse(self, stream, encoding, parseMeta, useChardet)
#     234         """
#     235         self._parse(stream, innerHTML=False, encoding=encoding,
# --> 236                     parseMeta=parseMeta, useChardet=useChardet)
#     237         return self.tree.getDocument()
#     238
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\html5lib\html5parser.py in _parse(self, stream, innerHTML, container, encoding, parseMeta, useChardet, **kwargs)
#      92         while True:
#      93             try:
# ---> 94                 self.mainLoop()
#      95                 break
#      96             except ReparseException:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\html5lib\html5parser.py in mainLoop(self)
#     195                         new_token = phase.processCharacters(new_token)
#     196                     elif type == SpaceCharactersToken:
# --> 197                         new_token = phase.processSpaceCharacters(new_token)
#     198                     elif type == StartTagToken:
#     199                         new_token = phase.processStartTag(new_token)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\html5lib\html5parser.py in processSpaceCharacters(self, token)
#    1010         def processSpaceCharacters(self, token):
#    1011             self.tree.reconstructActiveFormattingElements()
# -> 1012             self.tree.insertText(token["data"])
#    1013
#    1014         def startTagProcessInHead(self, token):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\html5lib\treebuilders\_base.py in insertText(self, data, parent)
#     318                                          self.openElements[-1].name
#     319                                          not in tableInsertModeElements)):
# --> 320             parent.insertText(data)
#     321         else:
#     322             # We should be in the InTable mode. This means we want to do
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\bs4\builder\_html5lib.py in insertText(self, data, insertBefore)
#     316             self.insertBefore(text, insertBefore)
#     317         else:
# --> 318             self.appendChild(text)
#     319
#     320     def insertBefore(self, node, refNode):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\bs4\builder\_html5lib.py in appendChild(self, node)
#     235             # string.
#     236             string_child = child = node
# --> 237         elif isinstance(node, Tag):
#     238             # Some other piece of code decided to pass in a Tag
#     239             # instead of creating an Element object to contain the
#
# KeyboardInterrupt:

# %%
details = obj.getDetailBerita(links[:3])

# %%
con = mysql.connector.connect(user='root', password='', host='127.0.0.1', database='news_db')
cursor = con.cursor()

# %%
for det in details:
    add_article = ("INSERT INTO article"
              "(post_id, author, pubdate, category, subcategory, content, comments, images, title, tags, url, source) "
              "VALUES (%(id)s, %(author)s, %(pubdate)s, %(category)s, %(subcategory)s, %(content)s, %(comments)s, %(images)s, %(title)s, %(tags)s, %(url)s, %(source)s)")
    # Insert article
    cursor.execute(add_article, det)
    con.commit()

cursor.close()

# %%
con.close()
p15
