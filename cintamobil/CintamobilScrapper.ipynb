# %%
from Cintamobil import Cintamobil
# import mysql.connector

# %%
obj = Cintamobil()

# %%
obj.getAllBerita([], 17, 'berita-mobil')
# Out:
# page  1
# https://cintamobil.com/berita-mobil/berita-mobil/p1
# memasukkan berita id  2279
# Insert berita  GIIAS 2018: Kerennya Toyota Vios TRD 2018, Sayang Tidak Bisa Dibeli
# masuk
# memasukkan berita id  2280
# Insert berita  Dibuat Hanya 18 Unit, Great New Xenia Special Edition Hadir Dengan Tampilan Makin Sporty
# masuk
# memasukkan berita id  2278
# Insert berita  Tidak Ada Hubungan Dengan Jendral Kardus, Ini Teknologi Eco Turbo Milik Lexus Yang Pintar Ramah Lingkungan Dan Reliable
# masuk
# memasukkan berita id  2277
# Insert berita  Dapatkan Hasil Positif, Kebijakan Ganjil Genap akan Dikaji untuk Depok
# masuk
# memasukkan berita id  2276
# Insert berita  GIIAS 2018: Manhart Performance & ART Perlihatkan Proses Bangun Mobil Modifikasi BMW 1M
# masuk
# memasukkan berita id  2272
# Insert berita  Keren, Bus Tingkat Legacy SR2 Double Decker Hadir Berlimpah Kemewahan
# masuk
# memasukkan berita id  2266
# Insert berita  GIIAS 2018: Honda Berikan Edukasi Teknologi Canggih Kepada Pelajar Sekolah Menengah Kejuruan
# masuk
# memasukkan berita id  2265
# Insert berita  GIIAS 2018: Lexus Menyuguhkan ‘Amazing Experience’ di Royal Majestic Booth GIIAS 2018
# masuk
# memasukkan berita id  2263
# Insert berita  Autopilot Masih Menang, Tesla Model S dan Model 3 Gagal Tes Rem IIHS
# masuk
# memasukkan berita id  2264
# Insert berita  Rekor Kelima Honda Civic Type R Taklukan Waktu Sirkuit Hungaroring
# masuk
# page  2
# https://cintamobil.com/berita-mobil/berita-mobil/p2
# memasukkan berita id  2273
# Insert berita  Luar Biasa, Ferrari Untung 80 Ribu Dollar Per Mobil
# masuk
# memasukkan berita id  2260
# Insert berita  Toyota Akan Kembangkan Model Berbasis Suzuki Baleno
# masuk
# memasukkan berita id  2255
# Insert berita  Honda Gelar Kontes Modifikasi Digital “Honda Brio Virtual Modification (V-Mod)”
# masuk
# memasukkan berita id  2254
# Insert berita  GIIAS 2018: New BMW M2 Coupé Hadir Di Ajang GIIAS 2018
# masuk
# memasukkan berita id  2253
# Insert berita  GIIAS 2018: Bersinar di Indonesia, Alasan World Premiere All New Honda Brio Di Tanah Air
# masuk
# memasukkan berita id  2252
# Insert berita  GIIAS 2018 Lanjutkan Kampanye #Amandijalan, Honda Bawa Perangkat Honda Sensing Simulator Di GIIAS 2018
# masuk
# memasukkan berita id  2251
# Insert berita  GIIAS 2018: Suzuki Indonesia Siapkan Mobil Terjangkau Untuk Konsumen Difabel
# masuk
# memasukkan berita id  2257
# Insert berita  Penjualan Stabil Nilai Jual Tinggi, Toyota Mengklaim Belum Ada Mobil Lain Seperti Avanza
# masuk
# memasukkan berita id  2258
# Insert berita  GIIAS 2018: Wanita Cantik Sales Promotional Girl (SPG) Bikin Pameran Makin Menarik
# masuk
# memasukkan berita id  2261
# Insert berita  GIIAS 2018: Aksi Balap Honda Civic TCR
# masuk
# page  3
# https://cintamobil.com/berita-mobil/berita-mobil/p3
# memasukkan berita id  2250
# Insert berita  GIIAS 2018: Perwujudan Semangat Ever Better Cars Sebagai Konsistensi Toyota Memajukan Motorsport Nasional
# masuk
# memasukkan berita id  2245
# Insert berita  GIIAS 2018: Tata Motors Hadirkan Prima 3338.K Sebagai Line Up Baru Truk Angkut Di Indonesia
# masuk
# memasukkan berita id  2249
# Insert berita  GIIAS 2018: Hanya di Minggu Ini Anda Beli Mazda Dapat Untung Berlimpah
# masuk
# memasukkan berita id  2243
# Insert berita  Sampai November 2018, Polisi Semarang Tutup Jalan Gombel Lama
# masuk
# memasukkan berita id  2244
# Insert berita  Gunakan Tagline Global Drive Your Ambition, Mitsubishi Indonesia Resmi Tinggalkan Tagline Lama
# masuk
# memasukkan berita id  2247
# Insert berita  Masih Membandel, 5.303 Penilangan Terjadi Selama Lima Hari Kebijakan Ganjil Genap
# masuk
# memasukkan berita id  2246
# Insert berita  Daihatsu dan Toyota Sedang Garap Produk Kolaborasi ke-5
# masuk
# memasukkan berita id  2248
# Insert berita  Sambut Asian Games ke-18, Daihatsu Luncurkan 18 Unit Ayla Special Edition
# masuk
# memasukkan berita id  2242
# Insert berita  GIIAS 2018: Promo Tiket dan Parkir Gratis bagi Penduduk Tangerang dan Sekitarnya
# masuk
# memasukkan berita id  2241
# Insert berita  GIIAS 2018: Ingin Test Drive? Intip Langkah-Langkahnya Di Sini
# masuk
# page  4
# https://cintamobil.com/berita-mobil/berita-mobil/p4
# memasukkan berita id  2240
# Insert berita  GIIAS 2018: Berbagai Teknologi yang Bisa Ditemukan pada Beyond Mobility Area
# masuk
# memasukkan berita id  2239
# Insert berita  Toyota Tampilkan Kendaraan Elektrikfikasi Di Ajang GIIAS 2018
# masuk
# memasukkan berita id  2238
# Insert berita  GIIAS 2018: Bawa Bus Poncho EV dan Truk CNG, Hino Buktikan Mobil Niaga Juga Bisa Ramah Lingkungan
# masuk
# memasukkan berita id  2235
# Insert berita  GIIAS 2018: Honda NeuV, Mobil Listrik Pintar Yang Tahu Kondisi Pengemudinya
# masuk
# memasukkan berita id  2234
# Insert berita  Dongkrak Penjualan Mobilio, Honda Tawarkan Cashback Rp 27 Juta Rupiah
# masuk
# memasukkan berita id  2237
# Insert berita  GIIAS 2018: Autovision Luncurkan Enam Produk LED Terbaru
# masuk
# memasukkan berita id  2236
# Insert berita  GIIAS 2018: The Entirely New Lexus ES Dirancang Dengan Pendekatan Bercita Rasa Tinggi
# masuk
# memasukkan berita id  2232
# Insert berita  GIIAS 2018: Bosch Perkenalkan Stasiun Pengisian Listrik Rumahan dan Terminal Portabel
# masuk
# memasukkan berita id  2231
# Insert berita  Promo MERDEKA, Program Penjualan Mitsubishi Bulan Agustus 2018 Dengan Hadiah Spesial
# masuk
# memasukkan berita id  2228
# Insert berita  GIIAS 2018: Mercedes Benz Selebrasi Dua Dekade Eksistensi Mobil SUV Mereka di Indonesia
# masuk
# page  5
# https://cintamobil.com/berita-mobil/berita-mobil/p5
# memasukkan berita id  2233
# Insert berita  All New Honda Brio Meluncur, Brio Lawas Diskon Belasan Juta
# masuk
# memasukkan berita id  2216
# Insert berita  DFSK Menawarkan Super Experience Activity Selama GIIAS 2018
# masuk
# memasukkan berita id  2229
# Insert berita  Honda Gratiskan Biaya Jasa Servis Hingga 50.000 Km atau 4 Tahun Untuk Pembelian Mulai Agustus 2018
# masuk
# memasukkan berita id  2230
# Insert berita  GIIAS 2018: Beri Banyak Pilihan, MMKSI Tambah Dua Varian Baru Mitsubishi Xpander
# masuk
# memasukkan berita id  2226
# Insert berita  GIIAS 2018: Komitmen Keselamatan Berkendara, Bosch Bawa Teknologi ESP di GIIAS 2018
# masuk
# memasukkan berita id  2227
# Insert berita  GIIAS 2018: New MINI Countryman Rakitan Lokal Resmi Debut di GIIAS 2018.
# masuk
# memasukkan berita id  2225
# Insert berita  GIIAS 2018: Rekam Jejak SUV Ladder-Frame Nissan: Dari Terrano Hingga Nissan Terra 2018
# masuk
# memasukkan berita id  2224
# Insert berita  GIIAS 2018: Solusi Hidup Tenang, Beli Mobil Nissan Dengan Bunga 0%
# masuk
# memasukkan berita id  2223
# Insert berita  The Next-Gen Nissan GT-R Bakal Diperkenalkan Dengan Konsep Yang Berbeda
# masuk
# memasukkan berita id  2210
# Insert berita  GIIAS 2018: Persiapkan Stamina, Tips Aman dan Nyaman Mengunjungi GIIAS 2018
# masuk
# page  6
# https://cintamobil.com/berita-mobil/berita-mobil/p6
# memasukkan berita id  2217
# Insert berita  GIIAS 2018: MINI Suguhkan Tiga Lini Produk Kekinian Untuk Masyarakat Urban Indonesia
# masuk
# memasukkan berita id  2219
# Insert berita  GIIAS 2018: Bergaya Muda Masa Kini, Datsun Perkenalkan Datsun Go-Live di GIIAS 2018
# masuk
# memasukkan berita id  2222
# Insert berita  GIIAS 2018: Datsun Optimistis Masa Depan Di Indonesia Cerah
# masuk
# memasukkan berita id  2211
# Insert berita  GIIAS 2018: Presiden Jokowi Kunjungi Booth DFSK Dan Jajal Glory 580
# masuk
# memasukkan berita id  2212
# Insert berita  GIIAS 2018: New Honda HR-V Diluncurkan Dengan Fitur Makin Lengkap dan Tampilan Makin Menawan
# masuk
# memasukkan berita id  2218
# Insert berita  GIIAS 2018: Usung Tema Absolute Professional, Mitsubishi Fuso Pamerkan Truk Laba-laba Super Great V Spider
# masuk
# memasukkan berita id  2221
# Insert berita  GIIAS 2018: Citra Premium BMW Semakin Terpancar Melalui Kedatangan BMW Concept X7 iPerformance
# masuk
# memasukkan berita id  2214
# Insert berita  BMW Group Indonesia Kenalkan BMW i8 Roadster di GIIAS 2018
# masuk
# memasukkan berita id  2215
# Insert berita  GIIAS 2018: Volkswagen resmi meluncurkan New Volkswagen Tiguan VRS
# masuk
# memasukkan berita id  2213
# Insert berita  All New Mazda6 Elite Siap Pukau Masyarakat Premium di GIIAS 2018
# masuk
# page  7
# https://cintamobil.com/berita-mobil/berita-mobil/p7
# memasukkan berita id  2205
# Insert berita  GIIAS 2018: Setelah Filipina, Kini Peluncuran Nissan Terra Indonesia Di Ajang GIIAS 2018
# masuk
# memasukkan berita id  2209
# Insert berita  Akhirnya Datang Juga, All New Hyundai Santa Fe Menyapa GIIAS 2018
# masuk
# memasukkan berita id  2208
# Insert berita  GIIAS 2018: The New Chevrolet Trailblazer SUV Premium Khusus Bagi Pecinta Tantangan
# masuk
# memasukkan berita id  2207
# Insert berita  GIIAS 2018: Chevrolet Spark City Car Dengan Warna Fashionable dan Tidak Biasa
# masuk
# memasukkan berita id  2206
# Insert berita  GIIAS 2018: Chevrolet Mampu Menghipnotis Ratusan Pasang Mata di GIIAS 2018
# masuk
# memasukkan berita id  2204
# Insert berita  GIIAS 2018: Indonesia Jadi Saksi Debut Global  All New Honda Brio
# masuk
# memasukkan berita id  2203
# Insert berita  GIIAS 2018: Sambut Asian Games, Daihatsu Hadirkan Keceriaan dan Warna Baru di GIIAS 2018
# masuk
# memasukkan berita id  2201
# Insert berita  GIIAS 2018: Wuling Motors Lakukan Tes Pasar SUV di GIIAS 2018
# masuk
# memasukkan berita id  2202
# Insert berita  DFSK resmi diluncurkan di GIIAS 2018
# masuk
# memasukkan berita id  2200
# Insert berita  GIIAS 2018: Wuling Motors Hadirkan Tema Drive Growth Progress di GIIAS 2018
# masuk
# page  8
# https://cintamobil.com/berita-mobil/berita-mobil/p8
# memasukkan berita id  2199
# Insert berita  GIIAS 2018: Ini Dia Yang Baru Dari Isuzu mu-X Premiere
# masuk
# memasukkan berita id  2198
# Insert berita  GIIAS 2018: Lexus UX Resmi Lakukan Asian Premiere Di GIIAS 2018 Dengan Prediksi Harga Jual Rp 800 Jutaan
# masuk
# memasukkan berita id  2196
# Insert berita  GIIAS 2018: Akhirnya Terkuak, Inilah Tiga Mobil Terbaru Mitsubishi
# masuk
# memasukkan berita id  2197
# Insert berita  GIIAS 2018: Toyota Hadirkan Parade Mobil Masa Depan
# masuk
# memasukkan berita id  2195
# Insert berita  GIIAS 2018: Ikuti GIIAS Kedua Kalinya, Isuzu Passenger Semakin Percaya Diri
# masuk
# memasukkan berita id  2194
# Insert berita  GIIAS 2018: Lexus Hadirkan Konsep The Royal Majestic Booth
# masuk
# memasukkan berita id  2193
# Insert berita  GIIAS 2018: Pameran Otomotif GIIAS 2018 Resmi Dibuka Presiden Joko Widodo
# masuk
# memasukkan berita id  2192
# Insert berita  Tingkatkan Kualitas Layanan, Honda Customer Care Gunakan Nomor Baru Yang Bisa Diakses 24 Jam
# masuk
# memasukkan berita id  2187
# Insert berita  Kemudahan Mengemudi dengan Teknologi Adaptive Cruise Control di GIIAS 2018
# masuk
# memasukkan berita id  2191
# Insert berita  Masih Nekat Melintas Di Kawasan Ganjil Genap, Sejumlah Kendaraan Kena Tilang
# masuk
# page  9
# https://cintamobil.com/berita-mobil/berita-mobil/p9
# memasukkan berita id  2189
# Insert berita  Sukses Sajikan Inovasi Canggih Di Indonesia, Honda Gallery Raih Penghargaan Bergengsi
# masuk
# memasukkan berita id  2185
# Insert berita  Wow, Showroom Terbesar Honda Di Indonesia Layaknya Mall Besar Kekinian
# masuk
# memasukkan berita id  2190
# Insert berita  Hati-Hati, Hari Ini Ada Simulasi Penutupan 19 Gerbang Tol di Jakarta Buat Dukung Asian Games 2018
# masuk
# memasukkan berita id  2181
# Insert berita  Promo Agustus Shell Indonesia Berhadiah BBM Gratis dan Liburan Eropa
# masuk
# memasukkan berita id  2178
# Insert berita  Versi ‘Special Edition’ Datsun Siap Debut di GIIAS 2018
# masuk
# memasukkan berita id  2180
# Insert berita  RESMI: MINI Kenalkan Lebih Dari Tiga Model Kendaraan Baru di GIIAS 2018
# masuk
# memasukkan berita id  2182
# Insert berita  10 Mobil Ini Merupakan Mobil Produksi Indonesia, Tapi Menjadi Produk Terlaris Luar Negeri, Apa Saja Itu?
# masuk
# memasukkan berita id  2174
# Insert berita  Ketika Karya Seni Khas Van Gogh Tertuang dalam Lexus LFA Art
# masuk
# memasukkan berita id  2179
# Insert berita  Mengenal Mobil Hybrid di Beyond Mobility Area GIIAS 2018
# masuk
# memasukkan berita id  2164
# Insert berita  Merek Jerman Kalahkan Jepang Sebagai Brand Otomotif Paling Berharga
# masuk
# page  10
# https://cintamobil.com/berita-mobil/berita-mobil/p10
# memasukkan berita id  2183
# Insert berita  Daftar Mobil Baru GIIAS 2018, Siapkan Beragam Mobil Baru Dan Unjuk Gigi Mobil Konsep
# masuk
# memasukkan berita id  2177
# Insert berita  Ini Dia Best Of The Best BMW Di Acara Bimmerjunction 2018
# masuk
# memasukkan berita id  2176
# Insert berita  Toyota Ingin Reinkarnasi Tiga Bersaudara Sports Car
# masuk
# memasukkan berita id  2175
# Insert berita  Bimmerjunction 2018 Jadi Simbol Kuatnya Komunitas Pecinta BMW di Indonesia
# masuk
# memasukkan berita id  2167
# Insert berita  Diserahkan Langsung Oleh Sang CEO, McLaren Senna 001 Langsung Dibawa Jalan-Jalan
# masuk
# memasukkan berita id  2172
# Insert berita  Saat Otomatis Jadi Tren Dunia, Warga AS Lebih Suka BMW Transmisi Manual
# masuk
# memasukkan berita id  2171
# Insert berita  Viral Open Indent, Benarkah SUV Wuling Baojun 530 Siap Dipesan?
# masuk
# memasukkan berita id  2165
# Insert berita  Tantangan Ekstrem, Nissan LEAF Taklukkan Tiga Puncak Gunung Kurang Dari 24 Jam
# masuk
# memasukkan berita id  2163
# Insert berita  Armada Taksi Pakai MPV, Pamor Sedan Kian Meredup
# masuk
# memasukkan berita id  2170
# Insert berita  Pecinta Mobil Sejati, Pembersih Cerobong Asap Ini Memiliki 114 Volkswagen Golf
# masuk
# page  11
# https://cintamobil.com/berita-mobil/berita-mobil/p11
# memasukkan berita id  2169
# Insert berita  Dilarang Kepolisian, Tantangan Viral Kiki Challenge Tidak Harus di Jalan
# masuk
# memasukkan berita id  2162
# Insert berita  Mengganti Pelat Nomor Putih, Apa Alasannya?
# masuk
# memasukkan berita id  2160
# Insert berita  1 Agustus, Pelanggar Kebijakan Ganjil Genap Langsung Kena Tilang
# masuk
# memasukkan berita id  2161
# Insert berita  Gunakan Mesin Mobil Balap, Sepeda Motor Levis V6 Café Racer Seharga Alphard
# masuk
# memasukkan berita id  2158
# Insert berita  Hadir Lebih Awal, Lamborghini Luncurkan Edisi Khusus Huracán Super Trofeo Evo
# masuk
# memasukkan berita id  2157
# Insert berita  Modifikator Indonesia Siap Pamer, Registrasi NMAA Top 50 Sudah Dibuka
# masuk
# memasukkan berita id  2154
# Insert berita  Mercedes-Benz A-Class Sedan, Si Anak Baru Compact Cars Kelas Wahid
# masuk
# memasukkan berita id  2159
# Insert berita  Daihatsu Donasikan Mobil Ambulans Mini ICU kepada Pemkot Bandung
# masuk
# memasukkan berita id  2156
# Insert berita  Mobil Murah ini Tidak Sampai 100 Juta, Bagaimana Fiturnya?
# masuk
# memasukkan berita id  2145
# Insert berita  Polisi: Tidak Boleh Memasang Stiker Di Pelat Nomor Kendaraan
# masuk
# page  12
# https://cintamobil.com/berita-mobil/berita-mobil/p12
# memasukkan berita id  2152
# Insert berita  SCG 007 LMP1: Hasrat Dan Mimpi Menaklukkan Le Mans 24 Jam
# masuk
# memasukkan berita id  2136
# Insert berita  Ini Jalur Lengkap Perluasan Ganjil Genap untuk Asian Games 2018
# masuk
# memasukkan berita id  2146
# Insert berita  RESMI: BMW Group Indonesia Boyong BMW i8 Roadster Di GIIAS 2018
# masuk
# memasukkan berita id  2145
# Insert berita  Polisi: Tidak Boleh Memasang Stiker Di Pelat Nomor Kendaraan
# salah2
# memasukkan berita id  2142
# Insert berita  Edisi Khusus Toyota GT86 TRD Lebih Sangar dan Bertenaga
# masuk
# memasukkan berita id  2143
# Insert berita  Makin Laris Di Dunia, Tujuan Ekspor Toyota Rush Bertambah
# masuk
# memasukkan berita id  2153
# Insert berita  Lexus Indonesia Siap Pajang Senjata Terbaru Di GIIAS 2018, Apakah Itu Lexus UX 2018?
# masuk
# memasukkan berita id  2144
# Insert berita  Prestige Image Motorcars Datangkan Dua Lamborghini Huracán, Salah Satunya Hanya Ada 1 Unit di Indonesia
# masuk
# memasukkan berita id  2141
# Insert berita  Selamat Jalan Sergio Marchionne, Sang Juru Selamat Fiat!
# masuk
# memasukkan berita id  2149
# Insert berita  Desain Futuristik Hyundai Le Fil Rouge Melenggang ke Concours d’Elegance of America
# masuk
# page  13
# https://cintamobil.com/berita-mobil/berita-mobil/p13
# memasukkan berita id  2148
# Insert berita  Gandeng KimoKal, Mercedes-Benz Gelar Kampanye “Just Like You”
# masuk
# memasukkan berita id  2147
# Insert berita  Modifikasi Unik, Sepeda Kayuh Menggunakan Ban dan Velg Mobil
# masuk
# memasukkan berita id  2138
# Insert berita  Alessandro Dambrosio Bergabung, Mitsubishi Bakal Punya Mobil Bercita Rasa Eropa
# masuk
# memasukkan berita id  2126
# Insert berita  Ini Alasan Mobil Toyota Dijual Lebih Mahal Dari Mobil Daihatsu
# masuk
# memasukkan berita id  2127
# Insert berita  Asian Games 2018 Special Deals, Beli Toyota Berhadiah Alphard dan C-HR
# masuk
# memasukkan berita id  2130
# Insert berita  Evaluasi Kebijakan Ganjil Genap Hadirkan Hasil Positif untuk Jalanan Jakarta
# masuk
# memasukkan berita id  2151
# Insert berita  Rilis Teaser Baru, Lamborghini Aventador SVJ Siap Go Public?
# masuk
# memasukkan berita id  2137
# Insert berita  Buktikan Ketangguhan, Honda Civic Type R Cetak Rekor Lap Time Baru di Sirkuit Estoril, Portugal
# masuk
# memasukkan berita id  2135
# Insert berita  Jasa Raharja Ring of Java X Country Eksplorasi Potensi Pariwisata di Pulau Jawa
# masuk
# memasukkan berita id  2134
# Insert berita  Teknologi Baru Dipadu Desain Atletis Audi Q3 Siap Luncur Tahun Depan
# masuk
# page  14
# https://cintamobil.com/berita-mobil/berita-mobil/p14
# memasukkan berita id  2128
# Insert berita  Tanpa Target Penjualan, Toyota Fokus Kenalkan Teknologi Mobil Ramah Lingkungan di GIIAS 2018
# masuk
# memasukkan berita id  2125
# Insert berita  VinFast Siap Pamerkan Dua Mobil di Paris Motor Show 2018
# masuk
# memasukkan berita id  2124
# Insert berita  Ada MPV Murah Berkualitas Seharga LCGC? Ini Buktinya
# masuk
# memasukkan berita id  2121
# Insert berita  Autovision AutoLightUp 2018 Seri Ke-7 Pacu Kreatifitas Modifikasi Mobil di Kota Medan
# masuk
# memasukkan berita id  2123
# Insert berita  Rasanya Jadi Orang Kaya, Mengintip Layanan VVIP Recall Bugatti Chiron
# masuk
# memasukkan berita id  2133
# Insert berita  BMW Kenalkan 5 Series Touring dan 6 Series Gran Turismo di Indonesia, Harga Di Bawah Rp 2 Miliar
# masuk
# memasukkan berita id  2139
# Insert berita  Dipasarkan di Thailand, Generasi Terbaru Suzuki Jimny Hadir di Indonesia?
# masuk
# memasukkan berita id  2120
# Insert berita  Kondisi Marchionne Memburuk, Ferrari & FCA Rombak Pucuk Pimpinan
# masuk
# memasukkan berita id  2122
# Insert berita  Berbagi Platform dengan Juke, Mitsubishi Siapkan Next-Gen Mitsubishi Mirage
# masuk
# memasukkan berita id  2119
# Insert berita  Kepincut Xpander, Mitsubishi Thailand Rancang Mirage Paling Keren
# masuk
# page  15
# https://cintamobil.com/berita-mobil/berita-mobil/p15
# memasukkan berita id  2118
# Insert berita  DFSK Tak Khawatir Regulasi Baru, DFSK Glory 580 Sudah Memenuhi Standar Emisi Euro4
# masuk
# memasukkan berita id  2116
# Insert berita  Sudah Selesai Pengerjaan, Tol Medan-Kualanamu-Tebing Tinggi (Tol MKTT) Menunggu Diresmikan
# masuk
# memasukkan berita id  2104
# Insert berita  Era Superhero, Hyundai Kona Iron Man Edition Dipasarkan Tahun Depan
# masuk
# memasukkan berita id  2101
# Insert berita  Ini Dia 8 Film Asyik Untuk Penikmat BMW Sejati
# masuk
# memasukkan berita id  2117
# Insert berita  Jelang Standar Emisi Euro4, Produsen Disarankan Mulai Stop Bikin Mobil Euro2
# masuk
# memasukkan berita id  2105
# Insert berita  Membeli Mobil Bekas, Solusi Cerdik Mengatasi Kebijakan Ganjil Genap
# masuk
# memasukkan berita id  2115
# Insert berita  Penjualan Mobil Menurun, Akibat Kebijakan Baru Pemerintah?
# masuk
# memasukkan berita id  2112
# Insert berita  BMW Janjikan Elektrifikasi Line Up Divisi M Rampung 2030
# masuk
# memasukkan berita id  2113
# Insert berita  Versi Nostalgia Hot Wheels Mario Kart Rilis Tahun Depan
# masuk
# memasukkan berita id  2111
# Insert berita  Asian Games Jadi Ajang Uji Coba Mobil Swakemudi Jaringan 5G Telkomsel
# masuk
# page  16
# https://cintamobil.com/berita-mobil/berita-mobil/p16
# memasukkan berita id  2103
# Insert berita  Sama-sama Merek China, DFSK Tak Masalah Bersaing Dengan Wuling
# masuk
# memasukkan berita id  2106
# Insert berita  Semester I 2018, Kijang Innova Masih Terlalu Kuat Mencengkeram Pasar Medium MPV
# masuk
# memasukkan berita id  2102
# Insert berita  Beli Nissan Bulan Juli, Dijamin Dapat Bunga 0% Dan Gratis Servis
# masuk
# memasukkan berita id  2108
# Insert berita  Standar Euro 4 di Indonesia Dimulai dari GIIAS 2018
# masuk
# memasukkan berita id  2109
# Insert berita  PT. UMC Suzuki Surabaya, Pertajam Sektor Niaga Dan Mengadakan Event Sharing Strategi Berwirausaha Lokal
# masuk
# memasukkan berita id  2092
# Insert berita  Tak Ingin Menggarami Lautan, KIA Enggan Main Di Segmen Low MPV
# masuk
# memasukkan berita id  2099
# Insert berita  Mobile Mosque, Bukti Perkembangan Islam di Negeri Matahari Terbit
# masuk
# memasukkan berita id  2095
# Insert berita  Andamas Resmi Jadi Dealer Tata Motors Di Palembang
# masuk
# memasukkan berita id  2100
# Insert berita  BMW i8 Curi Perhatian di We The Fest 2018
# masuk
# memasukkan berita id  2091
# Insert berita  Spesialis Mobil Mungil, Suzuki Siapkan Model Baru Berdesain Crossover
# masuk
# page  17
# https://cintamobil.com/berita-mobil/berita-mobil/p17
# memasukkan berita id  2098
# Insert berita  Track25 Jadi Inisiasi Visi McLaren Automotive Hingga 2025
# masuk
# memasukkan berita id  2096
# Insert berita  Rencana Ambisius DFSK di Indonesia: Basis Ekspor Setir Kanan dan Mobil Listrik
# masuk
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     170             conn = connection.create_connection(
# --> 171                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     172
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      78     if err is not None:
# ---> 79         raise err
#      80
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      68                 sock.bind(source_address)
# ---> 69             sock.connect(sa)
#      70             return sock
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     848         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 849             conn.connect()
#     850
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     313         # Add certificate verification
# --> 314         conn = self._new_conn()
#     315
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     179             raise NewConnectionError(
# --> 180                 self, "Failed to establish a new connection: %s" % e)
#     181
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x000001DF0E3CAB00>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     444                     retries=self.max_retries,
# --> 445                     timeout=timeout
#     446                 )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPSConnectionPool(host='cintamobil.com', port=443): Max retries exceeded with url: /mobil-baru/selasa-depan-bmw-siap-hadirkan-dua-produk-terbaru-aid2090 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000001DF0E3CAB00>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-5-4d9a90f802d7> in <module>()
# ----> 1 obj.getAllBerita([], 1, 'berita-mobil')
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      64                 if page < max_page:
#      65                     time.sleep(5)
# ---> 66                     details = self.getAllBerita(details, page+1, cat, date)
#      67         con.close()
#      68         return details
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getAllBerita(self, details, page, cat, date)
#      53             #     break
#      54             # else:
# ---> 55             detail = self.getDetailBerita(link)
#      56             if self.insertDB(con, detail):
#      57                 details.append(detail)
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\cintamobil\Cintamobil.py in getDetailBerita(self, link)
#      76         #link
#      77         url = link[0]
# ---> 78         response = requests.get(url)
#      79         html = response.text
#      80         # Create a BeautifulSoup object from the HTML: soup
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     620
#     621         # Send the request
# --> 622         r = adapter.send(request, **kwargs)
#     623
#     624         # Total elapsed time of the request (approximately)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     511                 raise SSLError(e, request=request)
#     512
# --> 513             raise ConnectionError(e, request=request)
#     514
#     515         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='cintamobil.com', port=443): Max retries exceeded with url: /mobil-baru/selasa-depan-bmw-siap-hadirkan-dua-produk-terbaru-aid2090 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000001DF0E3CAB00>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond',))

# %%
details = obj.getDetailBerita(links[:3])

# %%
con = mysql.connector.connect(user='root', password='', host='127.0.0.1', database='news_db')
cursor = con.cursor()

# %%
for det in details:
    add_article = ("INSERT INTO article"
              "(post_id, author, pubdate, category, subcategory, content, comments, images, title, tags, url, source) "
              "VALUES (%(id)s, %(author)s, %(pubdate)s, %(category)s, %(subcategory)s, %(content)s, %(comments)s, %(images)s, %(title)s, %(tags)s, %(url)s, %(source)s)")
    # Insert article
    cursor.execute(add_article, det)
    con.commit()

cursor.close()

# %%
con.close()
p15
