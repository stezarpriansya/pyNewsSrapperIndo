# %%
from Otodriver import Otodriver
import mysql.connector
obj = Otodriver()
#KELARRR

# %%
cat = ['tips', 'berita']
init_cat = cat[1:]

# %%
init_page = 37
for c in init_cat:
    obj.getAllBerita([], init_page, c)
    init_page = 1
    init_cat = cat
# Out:
# page  37
# http://otodriver.com/berita?page=37&per-page=18
# memasukkan berita id  1527634951
# Insert berita  SUV Brotherhood Deklarasi "Stop Terrorism" Dalam Ulang Tahunnya yang Kelima
# salah2
# memasukkan berita id  1527629541
# Insert berita  VIDEO: Vokalis Maroon 5 Melesatkan Mobil Listrik Pertama Porsche
# salah2
# memasukkan berita id  1527580937
# Insert berita  Keren, Honda Civic Type R Versi Pick Up Disiapkan di Inggris
# salah2
# memasukkan berita id  1527577326
# Insert berita  SPY SHOT: Suzuki Jimny Generasi Terbaru di Jepang
# salah2
# memasukkan berita id  1527573737
# Insert berita  Awal Kepunahan Mesin Legendaris Isuzu Panther Karena Euro 4?
# salah2
# memasukkan berita id  1527566539
# Insert berita  Penjualan Mazda Masih Tegolong Rendah di Kawasan Asia Pasifik
# salah2
# memasukkan berita id  1527559326
# Insert berita  Honda Berminat Untuk Produksi Sedan di Indonesia?
# salah2
# memasukkan berita id  1527555734
# ...
