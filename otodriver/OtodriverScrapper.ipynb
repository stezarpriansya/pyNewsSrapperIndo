# %%
from Otodriver import Otodriver
import mysql.connector
obj = Otodriver()
#KELARRR

# %%
cat = ['tips', 'berita']

# %%
cat
# Out:
# ['tips', 'berita']

# %%
init_page = 1
for c in cat:
    obj.getAllBerita([], init_page, c)
    init_page = 1
#     init_cat = cat
# Out:
# page  1
# http://otodriver.com/tips?page=1&per-page=18
# memasukkan berita id  1535698920
# Insert berita  Ini Cara Mudah Bedakan BPKB Asli dan Palsu
# masuk
# memasukkan berita id  1535526124
# Insert berita  Apa Kepanjangan Dari SRS Airbag? Ini Jawabannya
# masuk
# memasukkan berita id  1535090531
# Insert berita  Mobil Anda Dilengkapi Sunroof? Ini Tipsnya Supaya Awet
# masuk
# page  1
# http://otodriver.com/berita?page=1&per-page=18
# memasukkan berita id  1535763727
# Insert berita  Mobil Terlaris di Situs Jual Beli Satu ini Adalah...
# masuk
# memasukkan berita id  1535756532
# Insert berita  VIDEO: Bentley Bentayga 2018 Review Indonesia | OtoDriver
# masuk
# memasukkan berita id  1535716939
# Insert berita  "Sirkus Xpander" Sedang Berlangsung di Surabaya, Masuknya Gratis!
# masuk
# memasukkan berita id  1535706134
# Insert berita  Honda CR-V Hybrid Akhirnya Meluncur Dengan Penggerak 4WD
# masuk
# memasukkan berita id  1535702536
# ...
