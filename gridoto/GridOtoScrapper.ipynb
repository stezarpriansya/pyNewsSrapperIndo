# %%
from Gridoto import Gridoto
from datetime import timedelta, date, datetime
from IPython.display import clear_output

def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)
obj = Gridoto()

# %%
end_date = date(2018, 8, 12)
start_date = date(2018, 2, 8)
init_page = 4

# %%
for single_date in daterange(start_date, end_date):
    clear_output()
    print(single_date.strftime("%Y-%m-%d"))
    obj.getAllBerita([], init_page, single_date.strftime("%Y/%m/%d"))
    init_page = 1
# Out:
# 2018-02-18
# page  1
# https://www.gridoto.com/index?day=18&month=2&year=2018&section=all&page=1
# https://www.gridoto.com/read/01227150/out-now-video-komparasi-compact-hatchback-di-indonesia?page=all
# memasukkan berita id  227150
# Insert berita  https://www.gridoto.com/read/01227150/out-now-video-komparasi-compact-hatchback-di-indonesia?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227150/out-now-video-komparasi-compact-hatchback-di-indonesia?page=all'
# masuk
# https://www.gridoto.com/read/01227141/seken-keren-apakah-honda-cbr-150r-cbu-bisa-pakai-oli-lokal?page=all
# memasukkan berita id  227141
# Insert berita  https://www.gridoto.com/read/01227141/seken-keren-apakah-honda-cbr-150r-cbu-bisa-pakai-oli-lokal?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227141/seken-keren-apakah-honda-cbr-150r-cbu-bisa-pakai-oli-lokal?page=all'
# masuk
# https://www.gridoto.com/read/01227142/ternyata-akibatnya-fatal-kalau-jarang-pakai-kick-starter-di-motor-matik-sob?page=all
# memasukkan berita id  227142
# Insert berita  https://www.gridoto.com/read/01227142/ternyata-akibatnya-fatal-kalau-jarang-pakai-kick-starter-di-motor-matik-sob?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227142/ternyata-akibatnya-fatal-kalau-jarang-pakai-kick-starter-di-motor-matik-sob?page=all'
# masuk
# https://www.gridoto.com/read/01227137/seken-keren-berikut-daftar-harga-spare-part-honda-cbr-150r-cbu-karbu?page=all
# memasukkan berita id  227137
# Insert berita  https://www.gridoto.com/read/01227137/seken-keren-berikut-daftar-harga-spare-part-honda-cbr-150r-cbu-karbu?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227137/seken-keren-berikut-daftar-harga-spare-part-honda-cbr-150r-cbu-karbu?page=all'
# masuk
# https://www.gridoto.com/read/01227146/modal-rp-500-ribuan-bisa-dapat-back-protector-rs-taichi-mau?page=all
# memasukkan berita id  227146
# Insert berita  https://www.gridoto.com/read/01227146/modal-rp-500-ribuan-bisa-dapat-back-protector-rs-taichi-mau?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227146/modal-rp-500-ribuan-bisa-dapat-back-protector-rs-taichi-mau?page=all'
# masuk
# https://www.gridoto.com/read/01227100/rangkuman-momen-tes-motogp-di-thailand-siapa-tahu-kamu-ketinggalan?page=all
# memasukkan berita id  227100
# Insert berita  https://www.gridoto.com/read/01227100/rangkuman-momen-tes-motogp-di-thailand-siapa-tahu-kamu-ketinggalan?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227100/rangkuman-momen-tes-motogp-di-thailand-siapa-tahu-kamu-ketinggalan?page=all'
# masuk
# https://www.gridoto.com/read/01227129/seken-keren-motolab-bengkel-spesialis-honda-cbr-150r-cbu?page=all
# memasukkan berita id  227129
# Insert berita  https://www.gridoto.com/read/01227129/seken-keren-motolab-bengkel-spesialis-honda-cbr-150r-cbu?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227129/seken-keren-motolab-bengkel-spesialis-honda-cbr-150r-cbu?page=all'
# masuk
# https://www.gridoto.com/read/01227118/ajib-ribuan-pak-pos-bermotor-padati-wilayah-ini-pada-mau-kemana-sih?page=all
# memasukkan berita id  227118
# Insert berita  https://www.gridoto.com/read/01227118/ajib-ribuan-pak-pos-bermotor-padati-wilayah-ini-pada-mau-kemana-sih?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227118/ajib-ribuan-pak-pos-bermotor-padati-wilayah-ini-pada-mau-kemana-sih?page=all'
# masuk
# https://www.gridoto.com/read/01227133/seken-keren-ini-oli-yang-biasa-digunakan-untuk-toyota-camry-gen-6?page=all
# memasukkan berita id  227133
# Insert berita  https://www.gridoto.com/read/01227133/seken-keren-ini-oli-yang-biasa-digunakan-untuk-toyota-camry-gen-6?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227133/seken-keren-ini-oli-yang-biasa-digunakan-untuk-toyota-camry-gen-6?page=all'
# masuk
# https://www.gridoto.com/read/01227127/seken-keren-segini-harga-shockbreaker-yang-biasa-dipakai-toyota-camry-gen-6?page=all
# memasukkan berita id  227127
# Insert berita  https://www.gridoto.com/read/01227127/seken-keren-segini-harga-shockbreaker-yang-biasa-dipakai-toyota-camry-gen-6?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227127/seken-keren-segini-harga-shockbreaker-yang-biasa-dipakai-toyota-camry-gen-6?page=all'
# masuk
# https://www.gridoto.com/read/01227139/dirjen-perhubungan-darat-pantau-langsung-gt-cikarang-utama?page=all
# memasukkan berita id  227139
# Insert berita  https://www.gridoto.com/read/01227139/dirjen-perhubungan-darat-pantau-langsung-gt-cikarang-utama?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227139/dirjen-perhubungan-darat-pantau-langsung-gt-cikarang-utama?page=all'
# masuk
# https://www.gridoto.com/read/01227124/antisipasi-arus-balik-jasa-marga-kembali-berlakukan-contraflow-di-tol-cikampek?page=all
# memasukkan berita id  227124
# Insert berita  https://www.gridoto.com/read/01227124/antisipasi-arus-balik-jasa-marga-kembali-berlakukan-contraflow-di-tol-cikampek?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227124/antisipasi-arus-balik-jasa-marga-kembali-berlakukan-contraflow-di-tol-cikampek?page=all'
# masuk
# https://www.gridoto.com/read/01227135/thierry-neuville-dan-hyundai-i20-menang-di-reli-swedia-yang-dingin?page=all
# memasukkan berita id  227135
# Insert berita  https://www.gridoto.com/read/01227135/thierry-neuville-dan-hyundai-i20-menang-di-reli-swedia-yang-dingin?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227135/thierry-neuville-dan-hyundai-i20-menang-di-reli-swedia-yang-dingin?page=all'
# masuk
# https://www.gridoto.com/read/01227132/tampilan-kocak-bus-kayak-pesawat-luar-angkasa-jangan-jangan-trayeknya-ke-bulan?page=all
# memasukkan berita id  227132
# Insert berita  https://www.gridoto.com/read/01227132/tampilan-kocak-bus-kayak-pesawat-luar-angkasa-jangan-jangan-trayeknya-ke-bulan?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227132/tampilan-kocak-bus-kayak-pesawat-luar-angkasa-jangan-jangan-trayeknya-ke-bulan?page=all'
# masuk
# https://www.gridoto.com/read/01227122/seken-keren-ini-indikator-shockbreaker-toyota-camry-gen-6-rusak-menurut-bengkel-spesialis?page=all
# memasukkan berita id  227122
# Insert berita  https://www.gridoto.com/read/01227122/seken-keren-ini-indikator-shockbreaker-toyota-camry-gen-6-rusak-menurut-bengkel-spesialis?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227122/seken-keren-ini-indikator-shockbreaker-toyota-camry-gen-6-rusak-menurut-bengkel-spesialis?page=all'
# masuk
# page  2
# https://www.gridoto.com/index?day=18&month=2&year=2018&section=all&page=2
# https://www.gridoto.com/read/01227123/simak-yuk-video-etika-pakai-klakson-asal-pencet-sih-jadinya-kampungan?page=all
# memasukkan berita id  227123
# Insert berita  https://www.gridoto.com/read/01227123/simak-yuk-video-etika-pakai-klakson-asal-pencet-sih-jadinya-kampungan?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227123/simak-yuk-video-etika-pakai-klakson-asal-pencet-sih-jadinya-kampungan?page=all'
# masuk
# https://www.gridoto.com/read/01227121/seken-keren-4-hal-sebelum-beli-honda-cbr-150r-thailand?page=all
# memasukkan berita id  227121
# Insert berita  https://www.gridoto.com/read/01227121/seken-keren-4-hal-sebelum-beli-honda-cbr-150r-thailand?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227121/seken-keren-4-hal-sebelum-beli-honda-cbr-150r-thailand?page=all'
# masuk
# https://www.gridoto.com/read/01227107/awas-jadi-pengen-bmw-g310-gara-gara-lihat-modifan-satu-ini?page=all
# memasukkan berita id  227107
# Insert berita  https://www.gridoto.com/read/01227107/awas-jadi-pengen-bmw-g310-gara-gara-lihat-modifan-satu-ini?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227107/awas-jadi-pengen-bmw-g310-gara-gara-lihat-modifan-satu-ini?page=all'
# masuk
# https://www.gridoto.com/read/01227113/yuk-mengenal-birabongse-pangeran-thailand-pembalap-f1-pertama-di-asia-tenggara?page=all
# memasukkan berita id  227113
# Insert berita  https://www.gridoto.com/read/01227113/yuk-mengenal-birabongse-pangeran-thailand-pembalap-f1-pertama-di-asia-tenggara?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227113/yuk-mengenal-birabongse-pangeran-thailand-pembalap-f1-pertama-di-asia-tenggara?page=all'
# masuk
# https://www.gridoto.com/read/01227110/duh-pakai-ban-cacing-buat-harian-bisa-dipenjara-ini-undang-undangnya?page=all
# memasukkan berita id  227110
# Insert berita  https://www.gridoto.com/read/01227110/duh-pakai-ban-cacing-buat-harian-bisa-dipenjara-ini-undang-undangnya?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227110/duh-pakai-ban-cacing-buat-harian-bisa-dipenjara-ini-undang-undangnya?page=all'
# masuk
# https://www.gridoto.com/read/01227101/nih-masterpiece-yamaha-ikut-balapan-flat-track?page=all
# memasukkan berita id  227101
# Insert berita  https://www.gridoto.com/read/01227101/nih-masterpiece-yamaha-ikut-balapan-flat-track?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227101/nih-masterpiece-yamaha-ikut-balapan-flat-track?page=all'
# masuk
# https://www.gridoto.com/read/01226856/inspirasi-modifikasi-nissan-serena-biar-tampil-lebih-modern?page=all
# memasukkan berita id  226856
# Insert berita  https://www.gridoto.com/read/01226856/inspirasi-modifikasi-nissan-serena-biar-tampil-lebih-modern?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01226856/inspirasi-modifikasi-nissan-serena-biar-tampil-lebih-modern?page=all'
# masuk
# https://www.gridoto.com/read/01227105/masih-ingat-ini-kembaran-honda-cbr-150r-made-in-thailand?page=all
# memasukkan berita id  227105
# Insert berita  https://www.gridoto.com/read/01227105/masih-ingat-ini-kembaran-honda-cbr-150r-made-in-thailand?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227105/masih-ingat-ini-kembaran-honda-cbr-150r-made-in-thailand?page=all'
# masuk
# https://www.gridoto.com/read/01227109/seken-keren-ini-busi-rekomendasi-bengkel-spesialis-untuk-toyota-camry-gen-6?page=all
# memasukkan berita id  227109
# Insert berita  https://www.gridoto.com/read/01227109/seken-keren-ini-busi-rekomendasi-bengkel-spesialis-untuk-toyota-camry-gen-6?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227109/seken-keren-ini-busi-rekomendasi-bengkel-spesialis-untuk-toyota-camry-gen-6?page=all'
# masuk
# https://www.gridoto.com/read/01227102/bahaya-valtteri-bottas-mengancam-rekan-setimnya-lewis-hamilton?page=all
# memasukkan berita id  227102
# Insert berita  https://www.gridoto.com/read/01227102/bahaya-valtteri-bottas-mengancam-rekan-setimnya-lewis-hamilton?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227102/bahaya-valtteri-bottas-mengancam-rekan-setimnya-lewis-hamilton?page=all'
# masuk
# https://www.gridoto.com/read/01227103/ingat-bima-satria-garuda-x-begini-wujud-motornya-kalau-custom?page=all
# memasukkan berita id  227103
# Insert berita  https://www.gridoto.com/read/01227103/ingat-bima-satria-garuda-x-begini-wujud-motornya-kalau-custom?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227103/ingat-bima-satria-garuda-x-begini-wujud-motornya-kalau-custom?page=all'
# masuk
# https://www.gridoto.com/read/01226894/audi-sq5-besutan-abt-performance-torsinya-naik-50-nm?page=all
# memasukkan berita id  226894
# Insert berita  https://www.gridoto.com/read/01226894/audi-sq5-besutan-abt-performance-torsinya-naik-50-nm?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01226894/audi-sq5-besutan-abt-performance-torsinya-naik-50-nm?page=all'
# masuk
# https://www.gridoto.com/read/01227089/masih-nekat-pakai-ban-cacing-buat-harian-duh-bahaya-lo-sob?page=all
# memasukkan berita id  227089
# Insert berita  https://www.gridoto.com/read/01227089/masih-nekat-pakai-ban-cacing-buat-harian-duh-bahaya-lo-sob?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227089/masih-nekat-pakai-ban-cacing-buat-harian-duh-bahaya-lo-sob?page=all'
# masuk
# https://www.gridoto.com/read/01227099/pajak-sedan-akan-diturunkan-mitsubishi-kami-tidak-memanfaatkan-momentum?page=all
# memasukkan berita id  227099
# Insert berita  https://www.gridoto.com/read/01227099/pajak-sedan-akan-diturunkan-mitsubishi-kami-tidak-memanfaatkan-momentum?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227099/pajak-sedan-akan-diturunkan-mitsubishi-kami-tidak-memanfaatkan-momentum?page=all'
# masuk
# https://www.gridoto.com/read/01227094/ini-hasil-akhir-tes-pramusim-motogp-2018-di-buriram-thailand?page=all
# memasukkan berita id  227094
# Insert berita  https://www.gridoto.com/read/01227094/ini-hasil-akhir-tes-pramusim-motogp-2018-di-buriram-thailand?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227094/ini-hasil-akhir-tes-pramusim-motogp-2018-di-buriram-thailand?page=all'
# masuk
# page  3
# https://www.gridoto.com/index?day=18&month=2&year=2018&section=all&page=3
# https://www.gridoto.com/read/01227092/seperti-ini-wujud-yamaha-yzf-r25-facelift-2018-mirip-r1-banget?page=all
# memasukkan berita id  227092
# Insert berita  https://www.gridoto.com/read/01227092/seperti-ini-wujud-yamaha-yzf-r25-facelift-2018-mirip-r1-banget?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227092/seperti-ini-wujud-yamaha-yzf-r25-facelift-2018-mirip-r1-banget?page=all'
# masuk
# https://www.gridoto.com/read/01227088/hasil-tes-pramusim-motogp-2018-thailand-hari-ketiga-zarco-selamatkan-yamaha?page=all
# memasukkan berita id  227088
# Insert berita  https://www.gridoto.com/read/01227088/hasil-tes-pramusim-motogp-2018-thailand-hari-ketiga-zarco-selamatkan-yamaha?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227088/hasil-tes-pramusim-motogp-2018-thailand-hari-ketiga-zarco-selamatkan-yamaha?page=all'
# masuk
# https://www.gridoto.com/read/01226723/tesla-model-s-paling-garang-luar-dalem-serba-gelap?page=all
# memasukkan berita id  226723
# Insert berita  https://www.gridoto.com/read/01226723/tesla-model-s-paling-garang-luar-dalem-serba-gelap?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01226723/tesla-model-s-paling-garang-luar-dalem-serba-gelap?page=all'
# masuk
# https://www.gridoto.com/read/01227090/seken-keren-honda-cbr-150r-honda-cbr-ramping-made-in-thailand?page=all
# memasukkan berita id  227090
# Insert berita  https://www.gridoto.com/read/01227090/seken-keren-honda-cbr-150r-honda-cbr-ramping-made-in-thailand?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227090/seken-keren-honda-cbr-150r-honda-cbr-ramping-made-in-thailand?page=all'
# masuk
# https://www.gridoto.com/read/01226848/toyota-harrier-dibuat-bergaya-racing-kuncinya-di-pelek?page=all
# memasukkan berita id  226848
# Insert berita  https://www.gridoto.com/read/01226848/toyota-harrier-dibuat-bergaya-racing-kuncinya-di-pelek?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01226848/toyota-harrier-dibuat-bergaya-racing-kuncinya-di-pelek?page=all'
# masuk
# https://www.gridoto.com/read/01227037/tahun-2029-sebanyak-60-persen-warga-jakarta-gunakan-transportasi-massal?page=all
# memasukkan berita id  227037
# Insert berita  https://www.gridoto.com/read/01227037/tahun-2029-sebanyak-60-persen-warga-jakarta-gunakan-transportasi-massal?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227037/tahun-2029-sebanyak-60-persen-warga-jakarta-gunakan-transportasi-massal?page=all'
# masuk
# https://www.gridoto.com/read/01227078/motor-jepang-dengan-livery-khusus-tiap-pabrikan-mana-paling-keren?page=all
# memasukkan berita id  227078
# Insert berita  https://www.gridoto.com/read/01227078/motor-jepang-dengan-livery-khusus-tiap-pabrikan-mana-paling-keren?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227078/motor-jepang-dengan-livery-khusus-tiap-pabrikan-mana-paling-keren?page=all'
# masuk
# https://www.gridoto.com/read/01227085/jasa-marga-prediksi-66-ribu-kendaraan-balikhari-ini?page=all
# memasukkan berita id  227085
# Insert berita  https://www.gridoto.com/read/01227085/jasa-marga-prediksi-66-ribu-kendaraan-balikhari-ini?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227085/jasa-marga-prediksi-66-ribu-kendaraan-balikhari-ini?page=all'
# masuk
# https://www.gridoto.com/read/01227075/gaya-agresif-honda-dominator-besutan-builder-italia?page=all
# memasukkan berita id  227075
# Insert berita  https://www.gridoto.com/read/01227075/gaya-agresif-honda-dominator-besutan-builder-italia?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227075/gaya-agresif-honda-dominator-besutan-builder-italia?page=all'
# masuk
# https://www.gridoto.com/read/01227086/ajib-modal-goceng-bisa-bikin-alarm-motor-anti-maling-lihat-videonya?page=all
# memasukkan berita id  227086
# Insert berita  https://www.gridoto.com/read/01227086/ajib-modal-goceng-bisa-bikin-alarm-motor-anti-maling-lihat-videonya?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227086/ajib-modal-goceng-bisa-bikin-alarm-motor-anti-maling-lihat-videonya?page=all'
# masuk
# https://www.gridoto.com/read/01227071/uniknya-cara-pembalap-motogp-atasi-panasnya-thailand?page=all
# memasukkan berita id  227071
# Insert berita  https://www.gridoto.com/read/01227071/uniknya-cara-pembalap-motogp-atasi-panasnya-thailand?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227071/uniknya-cara-pembalap-motogp-atasi-panasnya-thailand?page=all'
# masuk
# https://www.gridoto.com/read/01227083/perhatikan-3-hal-ini-saat-hendak-mebeli-jaket?page=all
# memasukkan berita id  227083
# Insert berita  https://www.gridoto.com/read/01227083/perhatikan-3-hal-ini-saat-hendak-mebeli-jaket?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227083/perhatikan-3-hal-ini-saat-hendak-mebeli-jaket?page=all'
# masuk
# https://www.gridoto.com/read/01227068/terciduk-inikah-sosok-yamaha-r25-versi-facelift-yang-ditunggu-tunggu?page=all
# memasukkan berita id  227068
# Insert berita  https://www.gridoto.com/read/01227068/terciduk-inikah-sosok-yamaha-r25-versi-facelift-yang-ditunggu-tunggu?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227068/terciduk-inikah-sosok-yamaha-r25-versi-facelift-yang-ditunggu-tunggu?page=all'
# masuk
# https://www.gridoto.com/read/01227081/mau-koleksi-motor-imut-alias-minigp-harganya-segini-ternyata?page=all
# memasukkan berita id  227081
# Insert berita  https://www.gridoto.com/read/01227081/mau-koleksi-motor-imut-alias-minigp-harganya-segini-ternyata?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227081/mau-koleksi-motor-imut-alias-minigp-harganya-segini-ternyata?page=all'
# masuk
# https://www.gridoto.com/read/01227080/wuling-sebut-jual-mobil-dengan-harga-jujur-bagaimana-dengan-merek-lain-inikah-penyebab-ketimpangan-harga?page=all
# memasukkan berita id  227080
# Insert berita  https://www.gridoto.com/read/01227080/wuling-sebut-jual-mobil-dengan-harga-jujur-bagaimana-dengan-merek-lain-inikah-penyebab-ketimpangan-harga?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227080/wuling-sebut-jual-mobil-dengan-harga-jujur-bagaimana-dengan-merek-lain-inikah-penyebab-ketimpangan-harga?page=all'
# masuk
# page  4
# https://www.gridoto.com/index?day=18&month=2&year=2018&section=all&page=4
# https://www.gridoto.com/read/01227073/keren-abis-pembalap-malaysia-pecundangi-jorge-lorenzo-di-tes-pramusim-buriram?page=all
# memasukkan berita id  227073
# Insert berita  https://www.gridoto.com/read/01227073/keren-abis-pembalap-malaysia-pecundangi-jorge-lorenzo-di-tes-pramusim-buriram?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227073/keren-abis-pembalap-malaysia-pecundangi-jorge-lorenzo-di-tes-pramusim-buriram?page=all'
# masuk
# https://www.gridoto.com/read/01227074/asyik-pembalap-f1-bisa-ajak-kamu-mengitari-sirkuit-di-musim-2018-ini?page=all
# memasukkan berita id  227074
# Insert berita  https://www.gridoto.com/read/01227074/asyik-pembalap-f1-bisa-ajak-kamu-mengitari-sirkuit-di-musim-2018-ini?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227074/asyik-pembalap-f1-bisa-ajak-kamu-mengitari-sirkuit-di-musim-2018-ini?page=all'
# masuk
# https://www.gridoto.com/read/01227072/dari-tak-pakai-helm-bonceng-tiga-hingga-ratusan-motor-masuk-jalur-cepat-saat-konvoi-jakmania-bagaimana-pendapatmu?page=all
# memasukkan berita id  227072
# Insert berita  https://www.gridoto.com/read/01227072/dari-tak-pakai-helm-bonceng-tiga-hingga-ratusan-motor-masuk-jalur-cepat-saat-konvoi-jakmania-bagaimana-pendapatmu?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227072/dari-tak-pakai-helm-bonceng-tiga-hingga-ratusan-motor-masuk-jalur-cepat-saat-konvoi-jakmania-bagaimana-pendapatmu?page=all'
# masuk
# https://www.gridoto.com/read/01227063/hot-apakah-honda-akan-rilis-crf150l-versi-supermoto-bulan-maret?page=all
# memasukkan berita id  227063
# Insert berita  https://www.gridoto.com/read/01227063/hot-apakah-honda-akan-rilis-crf150l-versi-supermoto-bulan-maret?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227063/hot-apakah-honda-akan-rilis-crf150l-versi-supermoto-bulan-maret?page=all'
# masuk
# https://www.gridoto.com/read/01227028/punya-mobil-honda-tapi-enggak-tau-kepanjangannya-rs-apa-cek-ini-sob?page=all
# memasukkan berita id  227028
# Insert berita  https://www.gridoto.com/read/01227028/punya-mobil-honda-tapi-enggak-tau-kepanjangannya-rs-apa-cek-ini-sob?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227028/punya-mobil-honda-tapi-enggak-tau-kepanjangannya-rs-apa-cek-ini-sob?page=all'
# masuk
# https://www.gridoto.com/read/01227066/ktm-tes-dua-senjata-rahasia-di-thailand-apa-itu?page=all
# memasukkan berita id  227066
# Insert berita  https://www.gridoto.com/read/01227066/ktm-tes-dua-senjata-rahasia-di-thailand-apa-itu?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227066/ktm-tes-dua-senjata-rahasia-di-thailand-apa-itu?page=all'
# masuk
# https://www.gridoto.com/read/01227055/selain-servis-mesin-bengkel-resmi-bisa-perbaiki-cat-lo?page=all
# memasukkan berita id  227055
# Insert berita  https://www.gridoto.com/read/01227055/selain-servis-mesin-bengkel-resmi-bisa-perbaiki-cat-lo?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227055/selain-servis-mesin-bengkel-resmi-bisa-perbaiki-cat-lo?page=all'
# masuk
# https://www.gridoto.com/read/01227059/marc-marquez-dapat-boks-besar-untuk-ulang-tahunnya-isinya-tak-terduga?page=all
# memasukkan berita id  227059
# Insert berita  https://www.gridoto.com/read/01227059/marc-marquez-dapat-boks-besar-untuk-ulang-tahunnya-isinya-tak-terduga?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227059/marc-marquez-dapat-boks-besar-untuk-ulang-tahunnya-isinya-tak-terduga?page=all'
# masuk
# https://www.gridoto.com/read/01227029/keren-romain-grosjean-rilis-helm-baru-ini-rupanya?page=all
# memasukkan berita id  227029
# Insert berita  https://www.gridoto.com/read/01227029/keren-romain-grosjean-rilis-helm-baru-ini-rupanya?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227029/keren-romain-grosjean-rilis-helm-baru-ini-rupanya?page=all'
# masuk
# https://www.gridoto.com/read/01227053/mengenal-lebih-dekat-amelia-tjandra-27-tahun-setia-bersama-daihatsu?page=all
# memasukkan berita id  227053
# Insert berita  https://www.gridoto.com/read/01227053/mengenal-lebih-dekat-amelia-tjandra-27-tahun-setia-bersama-daihatsu?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227053/mengenal-lebih-dekat-amelia-tjandra-27-tahun-setia-bersama-daihatsu?page=all'
# masuk
# https://www.gridoto.com/read/01227052/seken-keren-ini-kata-bengkel-spesialis-soal-kaki-kaki-toyota-camry-gen-6?page=all
# memasukkan berita id  227052
# Insert berita  https://www.gridoto.com/read/01227052/seken-keren-ini-kata-bengkel-spesialis-soal-kaki-kaki-toyota-camry-gen-6?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227052/seken-keren-ini-kata-bengkel-spesialis-soal-kaki-kaki-toyota-camry-gen-6?page=all'
# masuk
# https://www.gridoto.com/read/01227049/ada-red-flag-di-tes-motogp-thailand-penyebabnya-bikin-kamu-ngakak?page=all
# memasukkan berita id  227049
# Insert berita  https://www.gridoto.com/read/01227049/ada-red-flag-di-tes-motogp-thailand-penyebabnya-bikin-kamu-ngakak?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227049/ada-red-flag-di-tes-motogp-thailand-penyebabnya-bikin-kamu-ngakak?page=all'
# masuk
# https://www.gridoto.com/read/01227061/seken-keren-ini-biaya-servis-honda-cbr-150r-di-bengkel-spesialis?page=all
# memasukkan berita id  227061
# Insert berita  https://www.gridoto.com/read/01227061/seken-keren-ini-biaya-servis-honda-cbr-150r-di-bengkel-spesialis?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227061/seken-keren-ini-biaya-servis-honda-cbr-150r-di-bengkel-spesialis?page=all'
# masuk
# https://www.gridoto.com/read/01227035/spesifikasi-honda-accord-turbo-yang-kemungkinan-masuk-indonesia-tahun-ini?page=all
# memasukkan berita id  227035
# Insert berita  https://www.gridoto.com/read/01227035/spesifikasi-honda-accord-turbo-yang-kemungkinan-masuk-indonesia-tahun-ini?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227035/spesifikasi-honda-accord-turbo-yang-kemungkinan-masuk-indonesia-tahun-ini?page=all'
# masuk
# https://www.gridoto.com/read/01227022/inikah-wujud-yamaha-xabre-facelift-pakai-mesin-all-new-r15?page=all
# memasukkan berita id  227022
# Insert berita  https://www.gridoto.com/read/01227022/inikah-wujud-yamaha-xabre-facelift-pakai-mesin-all-new-r15?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227022/inikah-wujud-yamaha-xabre-facelift-pakai-mesin-all-new-r15?page=all'
# masuk
# page  5
# https://www.gridoto.com/index?day=18&month=2&year=2018&section=all&page=5
# https://www.gridoto.com/read/01227048/seken-keren-ini-dia-penyakit-yang-sering-menyerang-honda-cbr-150r?page=all
# memasukkan berita id  227048
# Insert berita  https://www.gridoto.com/read/01227048/seken-keren-ini-dia-penyakit-yang-sering-menyerang-honda-cbr-150r?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227048/seken-keren-ini-dia-penyakit-yang-sering-menyerang-honda-cbr-150r?page=all'
# masuk
# https://www.gridoto.com/read/01227050/serem-sob-begini-akibatnya-kalau-motor-tidak-pernah-di-kick-starter?page=all
# memasukkan berita id  227050
# Insert berita  https://www.gridoto.com/read/01227050/serem-sob-begini-akibatnya-kalau-motor-tidak-pernah-di-kick-starter?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227050/serem-sob-begini-akibatnya-kalau-motor-tidak-pernah-di-kick-starter?page=all'
# masuk
# https://www.gridoto.com/read/01227023/ikutin-kata-valentino-rossi-johann-zarco-sementara-kuasai-tes-buriram?page=all
# memasukkan berita id  227023
# Insert berita  https://www.gridoto.com/read/01227023/ikutin-kata-valentino-rossi-johann-zarco-sementara-kuasai-tes-buriram?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227023/ikutin-kata-valentino-rossi-johann-zarco-sementara-kuasai-tes-buriram?page=all'
# masuk
# https://www.gridoto.com/read/01227046/seken-keren-mau-upgrade-performa-cbr-150r-makin-kece-ini-tempatnya?page=all
# memasukkan berita id  227046
# Insert berita  https://www.gridoto.com/read/01227046/seken-keren-mau-upgrade-performa-cbr-150r-makin-kece-ini-tempatnya?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227046/seken-keren-mau-upgrade-performa-cbr-150r-makin-kece-ini-tempatnya?page=all'
# masuk
# https://www.gridoto.com/read/01227047/mercedes-anggap-tim-ini-sebagai-pesaing-sejati-di-musim-f1-2018?page=all
# memasukkan berita id  227047
# Insert berita  https://www.gridoto.com/read/01227047/mercedes-anggap-tim-ini-sebagai-pesaing-sejati-di-musim-f1-2018?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227047/mercedes-anggap-tim-ini-sebagai-pesaing-sejati-di-musim-f1-2018?page=all'
# masuk
# https://www.gridoto.com/read/01227045/seken-keren-ini-bengkel-spesialis-honda-cbr-150r-impor-thailand?page=all
# memasukkan berita id  227045
# Insert berita  https://www.gridoto.com/read/01227045/seken-keren-ini-bengkel-spesialis-honda-cbr-150r-impor-thailand?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227045/seken-keren-ini-bengkel-spesialis-honda-cbr-150r-impor-thailand?page=all'
# masuk
# https://www.gridoto.com/read/01227043/dirakit-di-indonesia-berapa-besar-kandungan-lokal-mitsubishi-xpander?page=all
# memasukkan berita id  227043
# Insert berita  https://www.gridoto.com/read/01227043/dirakit-di-indonesia-berapa-besar-kandungan-lokal-mitsubishi-xpander?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01227043/dirakit-di-indonesia-berapa-besar-kandungan-lokal-mitsubishi-xpander?page=all'
