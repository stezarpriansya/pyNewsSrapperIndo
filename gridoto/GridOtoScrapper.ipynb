# %%
from Gridoto import Gridoto
from datetime import timedelta, date, datetime
from IPython.display import clear_output

def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)
obj = Gridoto()

# %%
end_date = date(2018, 8, 12)
start_date = date(2018, 1, 2)
init_page = 6

# %%
for single_date in daterange(start_date, end_date):
    clear_output()
    print(single_date.strftime("%Y-%m-%d"))
    obj.getAllBerita([], init_page, single_date.strftime("%Y/%m/%d"))
    init_page = 1
# Out:
# 2018-01-03
# page  1
# https://www.gridoto.com/index?day=3&month=1&year=2018&section=all&page=1
# https://www.gridoto.com/read/01215408/enggak-cuma-motor-boks-juga-bisa-dipasang-remote-control-lho-ini-fungsinya?page=all
# memasukkan berita id  215408
# Enggak Cuma Motor, Boks Juga Bisa Dipasang Remote Control Lho, Ini Fungsinya
# masuk
# https://www.gridoto.com/read/01216760/tahun-baru-matic-honda-ini-punya-warna-baru?page=all
# memasukkan berita id  216760
# Tahun Baru, Matic Honda Ini Punya Warna Baru
# masuk
# https://www.gridoto.com/read/01216782/baru-mau-meluncur-di-indonesia-datsun-cross-sudah-ada-versi-modifnya?page=all
# memasukkan berita id  216782
# Baru Mau Meluncur di Indonesia, Datsun Cross Sudah Ada Versi Modifnya
# masuk
# https://www.gridoto.com/read/01216761/motor-masuk-jurang-20-meter-di-jepara-pengendaranya-tewas?page=all
# memasukkan berita id  216761
# Motor Masuk Jurang 20 Meter di Jepara, Pengendaranya Tewas
# masuk
# https://www.gridoto.com/read/01216778/desainer-seksi-bungkus-huracan-dengan-13-juta-kristal-swarovski?page=all
# memasukkan berita id  216778
# Desainer Seksi Bungkus Huracan Dengan 1,3 Juta Kristal Swarovski
# masuk
# https://www.gridoto.com/read/01216730/selamat-ulang-tahun-michael-schumacher-legenda-formula-1?page=all
# memasukkan berita id  216730
# Selamat Ulang Tahun Michael Schumacher, Legenda Formula 1
# masuk
# https://www.gridoto.com/read/01215447/penyebab-honda-vario-125-pgm-fi-bergetar-dan-cara-mengatasinya?page=all
# memasukkan berita id  215447
# Penyebab Honda Vario 125 PGM FI 'Bergetar' dan Cara Mengatasinya
# masuk
# https://www.gridoto.com/read/01216765/kesepakatan-kecepatan-maksimum-motor-dibatasi-300-kmjam-sudah-ditinggalkan?page=all
# memasukkan berita id  216765
# Kesepakatan Kecepatan Maksimum Motor Dibatasi 300 Km/Jam Sudah Ditinggalkan
# masuk
# https://www.gridoto.com/read/01216675/sabtu-depan-customaxi-yamaha-makassar-siap-digelar-di-pinggir-pantai?page=all
# memasukkan berita id  216675
# Sabtu Depan, Customaxi Yamaha Makassar Siap Digelar di Pinggir Pantai
# masuk
# https://www.gridoto.com/read/01216772/video-terbaru-gridoto-tips-cara-membersihkan-jok-kulit?page=all
# memasukkan berita id  216772
# Video Terbaru GridOto Tips, Cara Membersihkan Jok Kulit
# masuk
# https://www.gridoto.com/read/01216722/belanja-spare-parts-copotan-takut-ketipu-calo-ini-3-tipsnya?page=all
# memasukkan berita id  216722
# Belanja Spare Parts Copotan Takut Ketipu Calo? Ini 3 Tipsnya
# masuk
# https://www.gridoto.com/read/01216616/pilihan-aksesori-resmi-yamaha-mt-25-harganya-mulai-rp-100-ribuan?page=all
# memasukkan berita id  216616
# Pilihan Aksesori Resmi Yamaha MT-25, Harganya Mulai Rp 100 Ribuan
# masuk
# https://www.gridoto.com/read/01216748/ini-6-motor-custom-scrambler-keren-bermesin-di-bawah-250cc?page=all
# memasukkan berita id  216748
# Ini 6 Motor Custom Scrambler Keren&nbsp; Bermesin di Bawah 250cc
# masuk
# https://www.gridoto.com/read/01216715/ngebut-saat-berbelok-truk-kontainer-ini-langsung-tepar?page=all
# memasukkan berita id  216715
# Ngebut Saat Berbelok Truk Kontainer Ini Langsung Tepar
# masuk
# https://www.gridoto.com/read/01216738/mobil-listrik-mungil-bmw-ganti-pelek-jadi-keren-sob?page=all
# memasukkan berita id  216738
# Mobil Listrik Mungil BMW Ganti Pelek Jadi Keren Sob!
# masuk
# page  2
# https://www.gridoto.com/index?day=3&month=1&year=2018&section=all&page=2
# https://www.gridoto.com/read/01216728/baru-ganti-ban-motor-jangan-langsung-diisi-nitrogen-ini-alasannya?page=all
# memasukkan berita id  216728
# Baru Ganti Ban Motor Jangan Langsung Diisi Nitrogen, Ini Alasannya
# masuk
# https://www.gridoto.com/read/01216714/hindari-tempat-ini-saat-memanaskan-sepeda-motor?page=all
# memasukkan berita id  216714
# Hindari Tempat Ini Saat Memanaskan Sepeda Motor
# masuk
# https://www.gridoto.com/read/01216655/hyundai-h-1-royale-memiliki-akomodasi-memadai-bagi-penumpang?page=all
# memasukkan berita id  216655
# Hyundai H-1 Royale Memiliki Akomodasi Memadai Bagi Penumpang?
# masuk
# https://www.gridoto.com/read/01216758/apa-makanan-kesukaan-the-doctor-ternyata-italia-banget?page=all
# memasukkan berita id  216758
# Apa Makanan Kesukaan The Doctor?  Ternyata 'Italia' Banget.
# masuk
# https://www.gridoto.com/read/01216752/ssst-ternyata-stok-daihatsu-terios-lawas-sudah-habis-lho?page=all
# memasukkan berita id  216752
# Ssst..., Ternyata Stok Daihatsu Terios Lawas Sudah Habis Lho
# masuk
# https://www.gridoto.com/read/01216709/logo-movistar-ganti-livery-tim-yamaha-motogp-2018-jadi-kaya-gini?page=all
# memasukkan berita id  216709
# Logo Movistar Ganti, Livery Tim Yamaha MotoGP 2018 Jadi Kaya Gini?
# masuk
# https://www.gridoto.com/read/01216637/subtitusi-knalpot-racing-yamaha-yzf-r25-dan-yamaha-mt-25-gak-bisa-langsung-sob?page=all
# memasukkan berita id  216637
# Subtitusi Knalpot Racing Yamaha YZF-R25 dan Yamaha MT-25? Gak Bisa Langsung Sob
# masuk
# https://www.gridoto.com/read/01216739/sempat-viral-begini-tanggapan-ahm-soal-video-honda-crf150l-terbakar?page=all
# memasukkan berita id  216739
# Sempat Viral, Begini Tanggapan AHM Soal Video Honda CRF150L Terbakar
# masuk
# https://www.gridoto.com/read/01216718/soul-gt-gorontalo-peringati-hari-jadi-ke-4?page=all
# memasukkan berita id  216718
# Soul GT Gorontalo Peringati Hari Jadi Ke-4
# masuk
# https://www.gridoto.com/read/01216741/waduh-rambu-belok-kiri-jalan-terus-sudah-tidak-berlaku-benarkah?page=all
# memasukkan berita id  216741
# Waduh,  Rambu 'Belok Kiri Jalan Terus' Sudah Tidak Berlaku, Benarkah?
# masuk
# https://www.gridoto.com/read/01216633/biar-lebih-paham-ini-fungsi-dan-jenis-tang-snap-ring?page=all
# memasukkan berita id  216633
# Biar Lebih Paham, Ini Fungsi dan Jenis Tang Snap Ring
# masuk
# https://www.gridoto.com/read/01216731/mengejutkan-harga-all-new-terios-resmi-tidak-berubah-dari-sebelumnya?page=all
# memasukkan berita id  216731
# Mengejutkan! Harga All New Terios Resmi Tidak Berubah Dari Sebelumnya
# masuk
# https://www.gridoto.com/read/01216742/video-termasuk-aksi-tipu-tipu-nih-motor-pelan-dibilang-299-kmjam?page=all
# memasukkan berita id  216742
# Video: Termasuk Aksi Tipu-Tipu Nih, Motor Pelan Dibilang 299 Km/Jam
# masuk
# https://www.gridoto.com/read/01216687/ini-yang-harus-dilakukan-untuk-menghindari-tabrakan-saat-berkendara?page=all
# memasukkan berita id  216687
# Ini Yang Harus Dilakukan Untuk Menghindari Tabrakan Saat Berkendara
# masuk
# https://www.gridoto.com/read/01216736/meski-cuma-menyiapkan-sajian-pria-ini-penentu-rossi-juara-dunia?page=all
# memasukkan berita id  216736
# Meski Cuma Menyiapkan Sajian, Pria Ini Penentu Rossi Juara Dunia
# masuk
# page  3
# https://www.gridoto.com/index?day=3&month=1&year=2018&section=all&page=3
# https://www.gridoto.com/read/01216707/beruntung-ada-tembok-fotographer-ini-nyaris-dihantam-mobil-balap?page=all
# memasukkan berita id  216707
# Beruntung Ada Tembok Fotographer Ini Nyaris Dihantam Mobil Balap
# masuk
# https://www.gridoto.com/read/01216653/bersiaplah-makassar-motormu-harus-begini-biar-menang-customaxi-yamaha?page=all
# memasukkan berita id  216653
# Bersiaplah Makassar! Motormu Harus Begini Biar Menang Customaxi Yamaha
# masuk
# https://www.gridoto.com/read/01216737/ini-alasan-ban-mobil-yang-botak-mesti-diganti?page=all
# memasukkan berita id  216737
# Ini Alasan Ban Mobil Yang Botak Mesti Diganti
# masuk
# https://www.gridoto.com/read/01216732/cara-cek-dan-ganti-minyak-rem-mobil-gampang-banget-sob?page=all
# memasukkan berita id  216732
# Cara Cek Dan Ganti Minyak Rem Mobil, Gampang Banget Sob!
# masuk
# https://www.gridoto.com/read/01216682/ganti-knalpot-untuk-naikan-power-jangan-lupa-setting-ulang-ya?page=all
# memasukkan berita id  216682
# Ganti Knalpot Untuk Naikan Power, Jangan Lupa Setting Ulang Ya
# masuk
# https://www.gridoto.com/read/01216586/inilah-hasil-tes-lengkap-audi-termurah-yaitu-a3-sportback?page=all
# memasukkan berita id  216586
# Inilah Hasil Tes Lengkap Audi Termurah Yaitu A3 Sportback
# masuk
# https://www.gridoto.com/read/01216725/yuk-kenalan-sama-nenek-moyangnya-nmax-ini-dia-yamaha-sc-1?page=all
# memasukkan berita id  216725
# Yuk Kenalan Sama Nenek Moyangnya NMAX, Ini Dia Yamaha SC-1
# masuk
# https://www.gridoto.com/read/01216587/kenali-sob-inilah-6-gejala-komstir-motor-kurang-sehat?page=all
# memasukkan berita id  216587
# Kenali Sob! Inilah 6 Gejala Komstir Motor Kurang Sehat
# masuk
# https://www.gridoto.com/read/01216717/kalender-lengkap-formula-1-2018-siapin-dirimu?page=all
# memasukkan berita id  216717
# Kalender Lengkap Formula 1 2018, Siapin Dirimu!
# masuk
# https://www.gridoto.com/read/01216710/hancur-bus-ini-jatuh-dari-tebing-dan-menghantam-bebatuan?page=all
# memasukkan berita id  216710
# Hancur, Bus Ini Jatuh Dari Tebing Dan Menghantam Bebatuan
# masuk
# https://www.gridoto.com/read/01216708/ternyata-ini-alasan-kenapa-harga-all-new-rush-tidak-naik-bahkan-turun?page=all
# memasukkan berita id  216708
# Ternyata Ini Alasan Kenapa Harga All New Rush Tidak Naik, Bahkan Turun
# masuk
# https://www.gridoto.com/read/01216666/kalah-start-mercedes-amg-e63-bungkam-lamborghini-huracan-dan-bmw-m6-di-drag-race?page=all
# memasukkan berita id  216666
# Kalah Start, Mercedes-AMG E63 Bungkam Lamborghini Huracan dan BMW M6 di Drag Race
# masuk
# https://www.gridoto.com/read/01216705/gagah-ini-wujud-6-motor-custom-bergaya-ala-supermoto?page=all
# memasukkan berita id  216705
# Gagah! Ini Wujud 6 Motor Custom Bergaya Ala Supermoto
# masuk
# https://www.gridoto.com/read/01216695/apa-sih-maksudnya-kok-ada-knalpot-slip-on-dan-full-system?page=all
# memasukkan berita id  216695
# Apa Sih Maksudnya Kok Ada Knalpot Slip-on dan Full System?
# masuk
# https://www.gridoto.com/read/01216693/ini-yang-diajarkan-pertamina-agar-terhindar-dari-blind-spot-truk-tangki?page=all
# memasukkan berita id  216693
# Ini Yang Diajarkan Pertamina Agar Terhindar Dari  'Blind Spot' Truk Tangki
# masuk
# page  4
# https://www.gridoto.com/index?day=3&month=1&year=2018&section=all&page=4
# https://www.gridoto.com/read/01216663/bahaya-gini-jadinya-jika-salah-angkat-moge-jatuh?page=all
# memasukkan berita id  216663
# Bahaya, Gini Jadinya Jika Salah Angkat Moge Jatuh
# masuk
# https://www.gridoto.com/read/01216696/pur-wheels-pertegas-tampang-gahar-lamborghini-aventador?page=all
# memasukkan berita id  216696
# PUR Wheels Pertegas Tampang Gahar Lamborghini Aventador
# masuk
# https://www.gridoto.com/read/01216636/ini-moge-baru-yamaha-yang-siap-dipasarkan-tahun-2018?page=all
# memasukkan berita id  216636
# Ini Moge Baru Yamaha Yang Siap Dipasarkan Tahun 2018
# masuk
# https://www.gridoto.com/read/01216626/setelah-angkut-rumput-muncul-daihatsu-xenia-angkut-pasir-komentar-netizen?page=all
# memasukkan berita id  216626
# Setelah Angkut Rumput, Muncul Daihatsu Xenia Angkut Pasir, Komentar Netizen?
# masuk
# https://www.gridoto.com/read/01216627/skill-dewa-video-kelakuan-kids-zaman-now-ngegas-motor-pakai-kaki?page=all
# memasukkan berita id  216627
# Skill Dewa, Video Kelakuan Kids Zaman Now Ngegas Motor Pakai Kaki
# masuk
# https://www.gridoto.com/read/01216702/toyota-sudah-mengeluarkan-harga-untuk-all-new-rush-daihatsu-terios?page=all
# memasukkan berita id  216702
# Toyota Sudah Mengeluarkan Harga Untuk All New Rush, Daihatsu Terios?
# masuk
# https://www.gridoto.com/read/01216703/setelah-cuci-mobil-ritual-ini-harus-dilakukan-agar-mobil-tidak-karatan?page=all
# memasukkan berita id  216703
# Setelah Cuci Mobil, Ritual Ini Harus Dilakukan Agar Mobil Tidak Karatan
# masuk
# https://www.gridoto.com/read/01216673/nih-9-neo-cafe-racer-yang-bisa-jadi-referensi?page=all
# memasukkan berita id  216673
# Nih 9 Neo Cafe Racer Yang Bisa Jadi Referensi
# masuk
# https://www.gridoto.com/read/01216623/video-wanita-zaman-now-bisa-naik-motor-selincah-ini-patut-dicontoh?page=all
# memasukkan berita id  216623
# Video Wanita Zaman Now Bisa Naik Motor Selincah Ini, Patut Dicontoh!
# masuk
# https://www.gridoto.com/read/01216681/seken-keren-nengok-lagi-suzuki-inazuma-250-motor-dua-silinder-berknalpot-double?page=all
# memasukkan berita id  216681
# Seken Keren : Nengok Lagi Suzuki Inazuma 250, Motor Dua Silinder Berknalpot Double!
# masuk
# https://www.gridoto.com/read/01216684/pertamina-ajari-ojek-online-supaya-enggak-kelibas-truk-tangki-bbm?page=all
# memasukkan berita id  216684
# Pertamina Ajari Ojek Online Supaya Enggak Kelibas Truk Tangki BBM
# masuk
# https://www.gridoto.com/read/01216685/franco-morbidelli-lanjutkan-warisan-alex-barros-sebagai-pembalap-berdarah-latin-ke-motogp?page=all
# memasukkan berita id  216685
# Franco Morbidelli Lanjutkan Warisan Alex Barros Sebagai Pembalap Berdarah Latin ke MotoGP
# masuk
# https://www.gridoto.com/read/01216632/gokil-truk-ini-mampu-berbelok-di-jembatan-kecil-kok-bisa-yah?page=all
# memasukkan berita id  216632
# Gokil! Truk Ini Mampu Berbelok di Jembatan Kecil, Kok Bisa Yah?
# masuk
# https://www.gridoto.com/read/01216677/nasihat-pabrik-rantai-potong-rantai-diperbolehkan-asal-dalam-keadaan-ini?page=all
# memasukkan berita id  216677
# Nasihat Pabrik Rantai: Potong Rantai Diperbolehkan, Asal Dalam Keadaan Ini
# masuk
# https://www.gridoto.com/read/01216670/ngeri-bus-anjlok-dari-tebing-setinggi-80-meter?page=all
# memasukkan berita id  216670
# Ngeri! Bus Anjlok Dari Tebing Setinggi 80 Meter
# masuk
# page  5
# https://www.gridoto.com/index?day=3&month=1&year=2018&section=all&page=5
# https://www.gridoto.com/read/01216664/toyota-avanza-terbalik-di-parit-usai-tabrak-dua-bocah-sd-hingga-tewas?page=all
# memasukkan berita id  216664
# Toyota Avanza Terbalik di Parit Usai Tabrak Dua Bocah SD Hingga Tewas
# masuk
# https://www.gridoto.com/read/01216641/ngaku-gp-mania-sejati-hafalin-dulu-istilah-motogp-ini?page=all
# memasukkan berita id  216641
# Ngaku GP Mania Sejati? Hafalin Dulu Istilah MotoGP Ini
# masuk
# https://www.gridoto.com/read/01216628/bikin-mesin-yamaha-mt-25-makin-adem-pakai-radiator-besar?page=all
# memasukkan berita id  216628
# Bikin Mesin Yamaha MT-25 Makin Adem Pakai Radiator Besar
# masuk
# https://www.gridoto.com/read/01216679/video-dibalik-layar-marquez-dan-dani-didandani-sebagai-guru?page=all
# memasukkan berita id  216679
# Video Dibalik Layar : Marquez dan Dani  Didandani Sebagai Guru
# masuk
# https://www.gridoto.com/read/01216639/masih-ingat-dengan-video-crf150l-yang-terbakar-ini-dia-tanggapan-ahm?page=all
# memasukkan berita id  216639
# Masih Ingat Dengan Video CRF150L yang Terbakar? Ini Dia Tanggapan AHM
# masuk
# https://www.gridoto.com/read/01216595/mobil-listrik-tesla-model-s-90d-kencang-meski-cuma-punya-1-gigi?page=all
# memasukkan berita id  216595
# Mobil Listrik Tesla Model S 90D. Kencang Meski Cuma Punya 1 Gigi
# masuk
# https://www.gridoto.com/read/01216576/bikin-geleng-geleng-cewek-ini-naik-motor-sambil-semedi?page=all
# memasukkan berita id  216576
# Bikin Geleng-Geleng! Cewek Ini Naik Motor Sambil 'Semedi'
# masuk
# https://www.gridoto.com/read/01216659/gsx-club-indonesia-tutup-akhir-tahun-dengan-donasi-di-perbatasan-papua?page=all
# memasukkan berita id  216659
# GSX Club Indonesia Tutup Akhir Tahun Dengan Donasi di Perbatasan Papua
# masuk
# https://www.gridoto.com/read/01216647/waduh-porsche-918-spyder-dibungkus-emas?page=all
# memasukkan berita id  216647
# Waduh, Porsche 918 Spyder Dibungkus Emas?
# masuk
# https://www.gridoto.com/read/01216590/57-orang-tewas-kecelakaan-saat-libur-natal-tahun-baru-di-daerah-ini?page=all
# memasukkan berita id  216590
# 57 Orang Tewas Kecelakaan Saat Libur Natal &amp; Tahun Baru di Daerah Ini
# masuk
# https://www.gridoto.com/read/01216614/ini-loh-salah-satu-pengaturan-unik-di-rolls-royce-phantom-metropolitan?page=all
# memasukkan berita id  216614
# Ini Loh Salah Satu Pengaturan Unik di Rolls-Royce Phantom Metropolitan
# masuk
# https://www.gridoto.com/read/01216646/pabrik-yamaha-di-indonesia-berencana-buat-mesin-moge-tahun-ini?page=all
# memasukkan berita id  216646
# Pabrik Yamaha Di Indonesia Berencana Buat Mesin Moge  Tahun Ini
# masuk
# https://www.gridoto.com/read/01216662/jorge-lorenzo-bilang-dialah-pembalap-terbaik-valentino-rossi-dan-marc-marquez-ditaruh-mana?page=all
# memasukkan berita id  216662
# Jorge Lorenzo Bilang Dialah Pembalap Terbaik, Valentino Rossi dan Marc Marquez Ditaruh Mana?
# masuk
# https://www.gridoto.com/read/01216624/wajib-tahu-beda-fungsi-kunci-pas-dan-kunci-ring?page=all
# memasukkan berita id  216624
# Wajib Tahu, Beda Fungsi Kunci Pas dan Kunci Ring
# masuk
# https://www.gridoto.com/read/01216660/toyota-rilis-harga-all-new-rush-2018-tipe-ini-dibanderol-lebih-murah?page=all
# memasukkan berita id  216660
# Toyota Rilis Harga All New Rush 2018, Tipe Ini Dibanderol Lebih Murah
# masuk
# page  6
# https://www.gridoto.com/index?day=3&month=1&year=2018&section=all&page=6
# https://www.gridoto.com/read/01216652/motor-baru-yang-bakal-meluncur-di-indonesia-pada-2018?page=all
# memasukkan berita id  216652
# Motor Baru yang Bakal Meluncur di Indonesia pada 2018
# masuk
# https://www.gridoto.com/read/01216179/skema-biaya-cicilan-cleveland-misfit-mulai-rp-15-jutaan-bro?page=all
# memasukkan berita id  216179
# Skema Biaya Cicilan Cleveland Misfit, Mulai Rp 1,5 Jutaan Bro
# masuk
# https://www.gridoto.com/read/01216581/pasang-mika-stoplamp-smoke-di-yamaha-nmax-biar-makin-sangar-sob?page=all
# memasukkan berita id  216581
# Pasang Mika Stoplamp Smoke di Yamaha NMAX, Biar Makin Sangar Sob
# masuk
# https://www.gridoto.com/read/01216563/kecelakaan-mobil-saat-liburan-tahun-baru-2018-ini-prosedur-klaim-asuransinya?page=all
# memasukkan berita id  216563
# Kecelakaan Mobil Saat Liburan Tahun Baru 2018, Ini Prosedur Klaim Asuransinya
# masuk
# https://www.gridoto.com/read/01216625/bangunkan-motor-jatuh-enggak-sembarang-begini-tekniknya-sob?page=all
# memasukkan berita id  216625
# Bangunkan Motor Jatuh Enggak Sembarang, Begini Tekniknya Sob
# masuk
# https://www.gridoto.com/read/01216608/enggak-banyak-yang-tahu-begini-cara-pakai-kunci-pas-yang-benar?page=all
# memasukkan berita id  216608
# Enggak Banyak yang Tahu, Begini Cara Pakai Kunci Pas yang Benar
# masuk
# https://www.gridoto.com/read/01216561/cara-deteksi-sokbreker-mobil-sudah-lemah?page=all
# memasukkan berita id  216561
# Cara Deteksi Sokbreker Mobil Sudah Lemah
# masuk
# https://www.gridoto.com/read/01216613/atasi-handgrip-setang-motor-melintir-modal-selotip-doang-bro?page=all
# memasukkan berita id  216613
# Atasi Handgrip Setang Motor Melintir, Modal Selotip Doang Bro
# masuk
# https://www.gridoto.com/read/01215542/nih-tank-bag-givi-xs307-pasangnya-enggak-pakai-magnet-sob?page=all
# memasukkan berita id  215542
# Nih Tank Bag GIVI XS307, Pasangnya Enggak Pakai Magnet, Sob
# masuk
# https://www.gridoto.com/read/01216620/merinding-truk-kontainer-hampir-lindas-balita-saat-menyerempet-motor?page=all
# memasukkan berita id  216620
# Merinding! Truk Kontainer Hampir Lindas Balita Saat Menyerempet Motor
# masuk
# https://www.gridoto.com/read/01216622/motor-pikap-roda-tigaternyata-bisa-wheelie-sayang-caranya-enggak-sah?page=all
# memasukkan berita id  216622
# Motor Pikap Roda Tiga&nbsp;Ternyata Bisa Wheelie, Sayang Caranya Enggak 'Sah'&nbsp;&nbsp;
# masuk
# https://www.gridoto.com/read/01216538/bmw-m4-paling-sangar-pakai-body-kit-dan-sayap-lebar?page=all
# memasukkan berita id  216538
# BMW M4 Paling Sangar Pakai Body Kit dan Sayap Lebar
# masuk
# https://www.gridoto.com/read/01216555/tips-membersihkan-kaki-kaki-mobil-setelah-berlibur-tahun-baru-2018?page=all
# memasukkan berita id  216555
# Tips Membersihkan Kaki-kaki Mobil Setelah Berlibur Tahun Baru 2018
# masuk
# https://www.gridoto.com/read/01216502/biaya-servis-dan-harga-komponen-fast-moving-yamaha-mt-25?page=all
# memasukkan berita id  216502
# Biaya Servis dan Harga Komponen Fast Moving Yamaha MT-25
# masuk
# https://www.gridoto.com/read/01216612/wuih-tahun-ini-yamaha-bakal-jual-moge-model-baru?page=all
# memasukkan berita id  216612
# Wuih, Tahun ini Yamaha Bakal Jual Moge Model Baru!
# masuk
# page  7
# https://www.gridoto.com/index?day=3&month=1&year=2018&section=all&page=7
# https://www.gridoto.com/read/01216609/pembayaran-tol-sempat-padam-ini-kata-jasa-marga?page=all
# memasukkan berita id  216609
# Pembayaran Tol Sempat Padam, Ini Kata Jasa Marga
# masuk
# https://www.gridoto.com/read/01216530/intip-kabin-toyota-agya-rasa-mobil-rally?page=all
# memasukkan berita id  216530
# Intip Kabin Toyota Agya Rasa Mobil Rally
# masuk
# https://www.gridoto.com/read/01216552/mengenal-fungsi-dan-jenis-per-mobil?page=all
# memasukkan berita id  216552
# Mengenal Fungsi Dan Jenis Per Mobil
# masuk
# https://www.gridoto.com/read/01216607/sikat-awal-2018-pabrikan-mobil-pada-diskon-ada-yang-sampai-40-juta?page=all
# memasukkan berita id  216607
# Sikat! Awal 2018 Pabrikan Mobil Pada Diskon, Ada Yang Sampai 40 Juta!
# masuk
# https://www.gridoto.com/read/01216541/ganti-visor-yamaha-aerox-155-lebih-sporty-cuma-modal-rp-100-ribuan?page=all
# memasukkan berita id  216541
# Ganti Visor Yamaha Aerox 155, Lebih Sporty Cuma Modal Rp 100 Ribuan
# masuk
# https://www.gridoto.com/read/01216602/satu-dekade-paguyuban-vario-nusantara-dirayakan-dengan-menanam-pohon?page=all
# memasukkan berita id  216602
# Satu Dekade Paguyuban Vario Nusantara Dirayakan Dengan Menanam Pohon
# masuk
# https://www.gridoto.com/read/01216603/foto-rekayasa-mitsubishi-xpander-jadi-angkot-netizen-komentar-begini?page=all
# memasukkan berita id  216603
# Foto Rekayasa Mitsubishi Xpander Jadi Angkot, Netizen Komentar Begini
# masuk
# https://www.gridoto.com/read/01216605/kocak-kamu-kasih-judul-apa-foto-dua-cewek-terciduk-polisi-ini?page=all
# memasukkan berita id  216605
# Kocak, Kamu Kasih Judul Apa Foto Dua Cewek Terciduk Polisi Ini?
# masuk
# https://www.gridoto.com/read/01216592/ini-kecelakaan-paling-menonjol-saat-libur-natal-tahun-baru-di-jatim?page=all
# memasukkan berita id  216592
# Ini Kecelakaan Paling Menonjol Saat Libur Natal &amp; Tahun Baru di Jatim
# masuk
# https://www.gridoto.com/read/01216546/tips-beli-honda-freed-psd-2012-ini-yang-perlu-diperhatikan?page=all
# memasukkan berita id  216546
# Tips Beli Honda Freed PSD 2012, Ini Yang Perlu Diperhatikan!
# masuk
# https://www.gridoto.com/read/01216591/banyak-kecelakaan-saat-tahun-baru-di-jatim-kendaraan-ini-mendominasi?page=all
# memasukkan berita id  216591
# Banyak Kecelakaan Saat Tahun Baru di Jatim, Kendaraan Ini Mendominasi
# masuk
# https://www.gridoto.com/read/01216583/parah-yamaha-v-ixion-seruduk-tiga-perempuan-di-sumatera-utara?page=all
# memasukkan berita id  216583
# Parah, Yamaha V-Ixion Seruduk Tiga Perempuan di Sumatera Utara
# masuk
# https://www.gridoto.com/read/01216582/video-gokil-dua-pembalap-bersaing-ujung-ujungnya-malah-boncengan?page=all
# memasukkan berita id  216582
# Video Gokil : Dua Pembalap Bersaing, Ujung-Ujungnya Malah Boncengan
# masuk
# https://www.gridoto.com/read/01216556/kepala-mekanik-valentino-rossi-ungkap-bedanya-rossi-vinales-dan-zarco?page=all
# memasukkan berita id  216556
# Kepala Mekanik Valentino Rossi Ungkap Bedanya Rossi, Vinales dan Zarco
# masuk
# https://www.gridoto.com/read/01216537/tips-bersihkan-ruang-mesin-usai-perjalanan-liburan-tahun-baru-2018?page=all
# memasukkan berita id  216537
# Tips Bersihkan Ruang Mesin Usai Perjalanan Liburan Tahun Baru 2018
# masuk
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-3-c6891f3cbdf1> in <module>()
#       2     clear_output()
#       3     print(single_date.strftime("%Y-%m-%d"))
# ----> 4     obj.getAllBerita([], init_page, single_date.strftime("%Y/%m/%d"))
#       5     init_page = 1
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\gridoto\Gridoto.py in getAllBerita(self, details, page, date)
#      69                 if last_page != active_page:
#      70                     time.sleep(5)
# ---> 71                     details = self.getAllBerita(details, page+1, date)
#      72
#      73         con.close()
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\gridoto\Gridoto.py in getAllBerita(self, details, page, date)
#      69                 if last_page != active_page:
#      70                     time.sleep(5)
# ---> 71                     details = self.getAllBerita(details, page+1, date)
#      72
#      73         con.close()
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\gridoto\Gridoto.py in getAllBerita(self, details, page, date)
#      69                 if last_page != active_page:
#      70                     time.sleep(5)
# ---> 71                     details = self.getAllBerita(details, page+1, date)
#      72
#      73         con.close()
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\gridoto\Gridoto.py in getAllBerita(self, details, page, date)
#      69                 if last_page != active_page:
#      70                     time.sleep(5)
# ---> 71                     details = self.getAllBerita(details, page+1, date)
#      72
#      73         con.close()
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\gridoto\Gridoto.py in getAllBerita(self, details, page, date)
#      69                 if last_page != active_page:
#      70                     time.sleep(5)
# ---> 71                     details = self.getAllBerita(details, page+1, date)
#      72
#      73         con.close()
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\gridoto\Gridoto.py in getAllBerita(self, details, page, date)
#      69                 if last_page != active_page:
#      70                     time.sleep(5)
# ---> 71                     details = self.getAllBerita(details, page+1, date)
#      72
#      73         con.close()
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\gridoto\Gridoto.py in getAllBerita(self, details, page, date)
#      69                 if last_page != active_page:
#      70                     time.sleep(5)
# ---> 71                     details = self.getAllBerita(details, page+1, date)
#      72
#      73         con.close()
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\gridoto\Gridoto.py in getAllBerita(self, details, page, date)
#      23         date = Y/m/d
#      24         """
# ---> 25         con = mysql.connector.connect(user='root', password='', host='127.0.0.1', database='news_db')
#      26         print("page ", page)
#      27         date2 = datetime.strptime(date, '%Y/%m/%d')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
#     160
#     161     # Regular connection
# --> 162     return MySQLConnection(*args, **kwargs)
#     163 Connect = connect  # pylint: disable=C0103
#     164
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mysql\connector\connection.py in __init__(self, *args, **kwargs)
#     127
#     128         if len(kwargs) > 0:
# --> 129             self.connect(**kwargs)
#     130
#     131     def _get_self(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mysql\connector\connection.py in connect(self, **kwargs)
#     452
#     453         self.disconnect()
# --> 454         self._open_connection()
#     455         self._post_connection()
#     456
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mysql\connector\connection.py in _open_connection(self)
#     416         self._socket = self._get_connection()
#     417         self._socket.open_connection()
# --> 418         self._do_handshake()
#     419         self._do_auth(self._user, self._password,
#     420                       self._database, self._client_flags, self._charset_id,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mysql\connector\connection.py in _do_handshake(self)
#     141         packet = self._socket.recv()
#     142         if packet[4] == 255:
# --> 143             raise errors.get_exception(packet)
#     144
#     145         try:
#
# DatabaseError: 1040: Too many connections
