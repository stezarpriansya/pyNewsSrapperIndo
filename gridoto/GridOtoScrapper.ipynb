# %%
from Gridoto import Gridoto
from datetime import timedelta, date, datetime
from IPython.display import clear_output

def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)
obj = Gridoto()

# %%
end_date = date(2018, 8, 12)
start_date = date(2018, 7, 17)
init_page = 6

# %%
for single_date in daterange(start_date, end_date):
    clear_output()
    print(single_date.strftime("%Y-%m-%d"))
    obj.getAllBerita([], init_page, single_date.strftime("%Y/%m/%d"))
    init_page = 1
# Out:
# 2018-07-19
# page  1
# https://www.gridoto.com/index?day=19&month=7&year=2018&section=all&page=1
# https://www.gridoto.com/read/01259670/upgrade-lampu-honda-pcx-lokal-pakai-lampu-mobil-biar-makin-terang?page=all
# memasukkan berita id  259670
# Insert berita  https://www.gridoto.com/read/01259670/upgrade-lampu-honda-pcx-lokal-pakai-lampu-mobil-biar-makin-terang?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259670/upgrade-lampu-honda-pcx-lokal-pakai-lampu-mobil-biar-makin-terang?page=all'
# masuk
# https://www.gridoto.com/read/01259838/pakai-sarung-tangan-enggak-bisa-cek-hp-itu-dulu-pakai-sarung-tangan-ini-bisa-kok?page=all
# memasukkan berita id  259838
# Insert berita  https://www.gridoto.com/read/01259838/pakai-sarung-tangan-enggak-bisa-cek-hp-itu-dulu-pakai-sarung-tangan-ini-bisa-kok?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259838/pakai-sarung-tangan-enggak-bisa-cek-hp-itu-dulu-pakai-sarung-tangan-ini-bisa-kok?page=all'
# masuk
# https://www.gridoto.com/read/01259741/miris-bagian-toyota-sienta-ini-remuk-gara-gara-rider-gagal-atraksi?page=all
# memasukkan berita id  259741
# Insert berita  https://www.gridoto.com/read/01259741/miris-bagian-toyota-sienta-ini-remuk-gara-gara-rider-gagal-atraksi?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259741/miris-bagian-toyota-sienta-ini-remuk-gara-gara-rider-gagal-atraksi?page=all'
# masuk
# https://www.gridoto.com/read/01259730/klasik-ini-6-motor-legendaris-yang-sampai-sekarang-masih-eksis-di-indonesia?page=all
# memasukkan berita id  259730
# Insert berita  https://www.gridoto.com/read/01259730/klasik-ini-6-motor-legendaris-yang-sampai-sekarang-masih-eksis-di-indonesia?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259730/klasik-ini-6-motor-legendaris-yang-sampai-sekarang-masih-eksis-di-indonesia?page=all'
# masuk
# https://www.gridoto.com/read/01259752/kenapa-setir-berbentuk-lingkaran-ternyata-ini-lho-alasannya?page=all
# memasukkan berita id  259752
# Insert berita  https://www.gridoto.com/read/01259752/kenapa-setir-berbentuk-lingkaran-ternyata-ini-lho-alasannya?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259752/kenapa-setir-berbentuk-lingkaran-ternyata-ini-lho-alasannya?page=all'
# masuk
# https://www.gridoto.com/read/01259767/video-biker-nyaris-diseruduk-truk-setelah-tertabrak-oleh-mobil?page=all
# memasukkan berita id  259767
# Insert berita  https://www.gridoto.com/read/01259767/video-biker-nyaris-diseruduk-truk-setelah-tertabrak-oleh-mobil?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259767/video-biker-nyaris-diseruduk-truk-setelah-tertabrak-oleh-mobil?page=all'
# masuk
# https://www.gridoto.com/read/01259668/honda-cbr150r-kroasia-dimodif-ala-motor-balap-sungguhan?page=all
# memasukkan berita id  259668
# Insert berita  https://www.gridoto.com/read/01259668/honda-cbr150r-kroasia-dimodif-ala-motor-balap-sungguhan?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259668/honda-cbr150r-kroasia-dimodif-ala-motor-balap-sungguhan?page=all'
# masuk
# https://www.gridoto.com/read/01259819/waspada-modus-jambret-bermotor-pakai-atribut-ojek-online-sasarannya-wanita-pulang-malam?page=all
# memasukkan berita id  259819
# Insert berita  https://www.gridoto.com/read/01259819/waspada-modus-jambret-bermotor-pakai-atribut-ojek-online-sasarannya-wanita-pulang-malam?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259819/waspada-modus-jambret-bermotor-pakai-atribut-ojek-online-sasarannya-wanita-pulang-malam?page=all'
# masuk
# https://www.gridoto.com/read/01259813/asyik-nih-spesial-nih-ganti-oli-di-tanggal-20-tiap-bulan-khusus-pengguna-motor-honda?page=all
# memasukkan berita id  259813
# Insert berita  https://www.gridoto.com/read/01259813/asyik-nih-spesial-nih-ganti-oli-di-tanggal-20-tiap-bulan-khusus-pengguna-motor-honda?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259813/asyik-nih-spesial-nih-ganti-oli-di-tanggal-20-tiap-bulan-khusus-pengguna-motor-honda?page=all'
# masuk
# https://www.gridoto.com/read/01259801/hadir-dari-seluruh-indonesia-segini-jumlah-peserta-ah-sric-ke-12?page=all
# memasukkan berita id  259801
# Insert berita  https://www.gridoto.com/read/01259801/hadir-dari-seluruh-indonesia-segini-jumlah-peserta-ah-sric-ke-12?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259801/hadir-dari-seluruh-indonesia-segini-jumlah-peserta-ah-sric-ke-12?page=all'
# masuk
# https://www.gridoto.com/read/01259826/ganteng-pol-bro-ini-langkah-mudah-bikin-ignis-tambah-modis?page=all
# memasukkan berita id  259826
# Insert berita  https://www.gridoto.com/read/01259826/ganteng-pol-bro-ini-langkah-mudah-bikin-ignis-tambah-modis?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259826/ganteng-pol-bro-ini-langkah-mudah-bikin-ignis-tambah-modis?page=all'
# masuk
# https://www.gridoto.com/read/01259803/honda-bangun-safety-riding-center-di-pekanbaru-ini-alasannya?page=all
# memasukkan berita id  259803
# Insert berita  https://www.gridoto.com/read/01259803/honda-bangun-safety-riding-center-di-pekanbaru-ini-alasannya?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259803/honda-bangun-safety-riding-center-di-pekanbaru-ini-alasannya?page=all'
# masuk
# https://www.gridoto.com/read/01259818/isu-aksi-demo-ojek-online-saat-pembukaan-asian-games-2018-begini-reaksi-petinggi-polisi?page=all
# memasukkan berita id  259818
# Insert berita  https://www.gridoto.com/read/01259818/isu-aksi-demo-ojek-online-saat-pembukaan-asian-games-2018-begini-reaksi-petinggi-polisi?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259818/isu-aksi-demo-ojek-online-saat-pembukaan-asian-games-2018-begini-reaksi-petinggi-polisi?page=all'
# masuk
# https://www.gridoto.com/read/01259802/bukan-hanya-di-pekanbaru-ini-daftar-lokasi-safety-riding-center-honda-di-indonesia?page=all
# memasukkan berita id  259802
# Insert berita  https://www.gridoto.com/read/01259802/bukan-hanya-di-pekanbaru-ini-daftar-lokasi-safety-riding-center-honda-di-indonesia?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259802/bukan-hanya-di-pekanbaru-ini-daftar-lokasi-safety-riding-center-honda-di-indonesia?page=all'
# masuk
# https://www.gridoto.com/read/01259781/enggak-pakai-lama-video-maling-berhasil-gondol-yamaha-v-ixion-parkir-di-minimarket-dengan-kunci-t?page=all
# memasukkan berita id  259781
# Insert berita  https://www.gridoto.com/read/01259781/enggak-pakai-lama-video-maling-berhasil-gondol-yamaha-v-ixion-parkir-di-minimarket-dengan-kunci-t?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259781/enggak-pakai-lama-video-maling-berhasil-gondol-yamaha-v-ixion-parkir-di-minimarket-dengan-kunci-t?page=all'
# masuk
# page  2
# https://www.gridoto.com/index?day=19&month=7&year=2018&section=all&page=2
# https://www.gridoto.com/read/01259822/wajib-dicatat-mulai-24-juli-ada-penyesuaian-tarif-jalan-tol-semarang-solo-seksi-i-dan-ii?page=all
# memasukkan berita id  259822
# Insert berita  https://www.gridoto.com/read/01259822/wajib-dicatat-mulai-24-juli-ada-penyesuaian-tarif-jalan-tol-semarang-solo-seksi-i-dan-ii?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259822/wajib-dicatat-mulai-24-juli-ada-penyesuaian-tarif-jalan-tol-semarang-solo-seksi-i-dan-ii?page=all'
# masuk
# https://www.gridoto.com/read/01259804/gahar-begini-suara-gold-wing-generasi-pertama-yang-dirombak-jadi-cafe-racer?page=all
# memasukkan berita id  259804
# Insert berita  https://www.gridoto.com/read/01259804/gahar-begini-suara-gold-wing-generasi-pertama-yang-dirombak-jadi-cafe-racer?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259804/gahar-begini-suara-gold-wing-generasi-pertama-yang-dirombak-jadi-cafe-racer?page=all'
# masuk
# https://www.gridoto.com/read/01259759/video-jeep-wrangler-paling-lebar-sedunia-makan-jalan-ini-mah-namanya?page=all
# memasukkan berita id  259759
# Insert berita  https://www.gridoto.com/read/01259759/video-jeep-wrangler-paling-lebar-sedunia-makan-jalan-ini-mah-namanya?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259759/video-jeep-wrangler-paling-lebar-sedunia-makan-jalan-ini-mah-namanya?page=all'
# masuk
# https://www.gridoto.com/read/01259809/speaker-mobil-bikin-sound-system-mobil-makin-ajib-yang-ini-lagi-diskon-rp-500-ribu?page=all
# memasukkan berita id  259809
# Insert berita  https://www.gridoto.com/read/01259809/speaker-mobil-bikin-sound-system-mobil-makin-ajib-yang-ini-lagi-diskon-rp-500-ribu?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259809/speaker-mobil-bikin-sound-system-mobil-makin-ajib-yang-ini-lagi-diskon-rp-500-ribu?page=all'
# masuk
# https://www.gridoto.com/read/01259786/bikin-keren-tampang-belakang-ignis-tinggal-pasang-2-item-ini-cuma-rp-600-ribuan?page=all
# memasukkan berita id  259786
# Insert berita  https://www.gridoto.com/read/01259786/bikin-keren-tampang-belakang-ignis-tinggal-pasang-2-item-ini-cuma-rp-600-ribuan?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259786/bikin-keren-tampang-belakang-ignis-tinggal-pasang-2-item-ini-cuma-rp-600-ribuan?page=all'
# masuk
# https://www.gridoto.com/read/01259776/kayak-gini-nih-kalau-honda-gold-wing-generasi-pertama-jadi-cafe-racer?page=all
# memasukkan berita id  259776
# Insert berita  https://www.gridoto.com/read/01259776/kayak-gini-nih-kalau-honda-gold-wing-generasi-pertama-jadi-cafe-racer?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259776/kayak-gini-nih-kalau-honda-gold-wing-generasi-pertama-jadi-cafe-racer?page=all'
# masuk
# https://www.gridoto.com/read/01259783/parah-video-mobil-damkar-saat-menuju-lokasi-kebakaran-dihalangi-sopir-angkot?page=all
# memasukkan berita id  259783
# Insert berita  https://www.gridoto.com/read/01259783/parah-video-mobil-damkar-saat-menuju-lokasi-kebakaran-dihalangi-sopir-angkot?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259783/parah-video-mobil-damkar-saat-menuju-lokasi-kebakaran-dihalangi-sopir-angkot?page=all'
# masuk
# https://www.gridoto.com/read/01259789/lumayan-lebih-unggul-dari-nissan-grand-livina-segini-penjualan-wuling-confero-di-semester-pertama-2018?page=all
# memasukkan berita id  259789
# Insert berita  https://www.gridoto.com/read/01259789/lumayan-lebih-unggul-dari-nissan-grand-livina-segini-penjualan-wuling-confero-di-semester-pertama-2018?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259789/lumayan-lebih-unggul-dari-nissan-grand-livina-segini-penjualan-wuling-confero-di-semester-pertama-2018?page=all'
# masuk
# https://www.gridoto.com/read/01259785/resmi-suzuki-burgman-street-125-diluncurkan-segini-harganya?page=all
# memasukkan berita id  259785
# Insert berita  https://www.gridoto.com/read/01259785/resmi-suzuki-burgman-street-125-diluncurkan-segini-harganya?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259785/resmi-suzuki-burgman-street-125-diluncurkan-segini-harganya?page=all'
# masuk
# https://www.gridoto.com/read/01259791/belum-banyak-yang-tahu-ini-dia-jenis-jenis-dongkrak-mobil?page=all
# memasukkan berita id  259791
# Insert berita  https://www.gridoto.com/read/01259791/belum-banyak-yang-tahu-ini-dia-jenis-jenis-dongkrak-mobil?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259791/belum-banyak-yang-tahu-ini-dia-jenis-jenis-dongkrak-mobil?page=all'
# masuk
# https://www.gridoto.com/read/01259793/breaking-news-lewis-hamilton-perpanjang-kontrak-bersama-mercedes?page=all
# memasukkan berita id  259793
# Insert berita  https://www.gridoto.com/read/01259793/breaking-news-lewis-hamilton-perpanjang-kontrak-bersama-mercedes?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259793/breaking-news-lewis-hamilton-perpanjang-kontrak-bersama-mercedes?page=all'
# masuk
# https://www.gridoto.com/read/01259788/siap-ke-jepang-puluhan-instruktur-safety-riding-honda-bejek-gas?page=all
# memasukkan berita id  259788
# Insert berita  https://www.gridoto.com/read/01259788/siap-ke-jepang-puluhan-instruktur-safety-riding-honda-bejek-gas?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259788/siap-ke-jepang-puluhan-instruktur-safety-riding-honda-bejek-gas?page=all'
# masuk
# https://www.gridoto.com/read/01259719/out-now-video-first-drive-kia-grand-sedona-diesel-crdi?page=all
# memasukkan berita id  259719
# Insert berita  https://www.gridoto.com/read/01259719/out-now-video-first-drive-kia-grand-sedona-diesel-crdi?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259719/out-now-video-first-drive-kia-grand-sedona-diesel-crdi?page=all'
# masuk
# https://www.gridoto.com/read/01259765/gara-gara-slogan-presiden-as-donald-trump-pembalap-junior-tim-haas-f1-harus-menerima-nasib-nahas?page=all
# memasukkan berita id  259765
# Insert berita  https://www.gridoto.com/read/01259765/gara-gara-slogan-presiden-as-donald-trump-pembalap-junior-tim-haas-f1-harus-menerima-nasib-nahas?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259765/gara-gara-slogan-presiden-as-donald-trump-pembalap-junior-tim-haas-f1-harus-menerima-nasib-nahas?page=all'
# masuk
# https://www.gridoto.com/read/01259780/kenapa-pengaturan-elektronik-bisa-bikin-ban-motor-motogp-lebih-cepat-rusak?page=all
# memasukkan berita id  259780
# Insert berita  https://www.gridoto.com/read/01259780/kenapa-pengaturan-elektronik-bisa-bikin-ban-motor-motogp-lebih-cepat-rusak?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259780/kenapa-pengaturan-elektronik-bisa-bikin-ban-motor-motogp-lebih-cepat-rusak?page=all'
# masuk
# page  3
# https://www.gridoto.com/index?day=19&month=7&year=2018&section=all&page=3
# https://www.gridoto.com/read/01259779/kisah-mike-vaughan-orang-yang-memberi-nama-ninja-di-motor-kawasaki?page=all
# memasukkan berita id  259779
# Insert berita  https://www.gridoto.com/read/01259779/kisah-mike-vaughan-orang-yang-memberi-nama-ninja-di-motor-kawasaki?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259779/kisah-mike-vaughan-orang-yang-memberi-nama-ninja-di-motor-kawasaki?page=all'
# masuk
# https://www.gridoto.com/read/01259760/antara-toyota-all-new-fortuner-dan-mitsubishi-pajero-sport-siapa-yang-rapornya-paling-bagus-di-semester-pertama-tahun-ini?page=all
# memasukkan berita id  259760
# Insert berita  https://www.gridoto.com/read/01259760/antara-toyota-all-new-fortuner-dan-mitsubishi-pajero-sport-siapa-yang-rapornya-paling-bagus-di-semester-pertama-tahun-ini?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259760/antara-toyota-all-new-fortuner-dan-mitsubishi-pajero-sport-siapa-yang-rapornya-paling-bagus-di-semester-pertama-tahun-ini?page=all'
# masuk
# https://www.gridoto.com/read/01259772/video-ini-bisa-ungkap-masalah-setting-elektronik-bikin-ban-motor-valentino-rossi-cepat-rusak?page=all
# memasukkan berita id  259772
# Insert berita  https://www.gridoto.com/read/01259772/video-ini-bisa-ungkap-masalah-setting-elektronik-bikin-ban-motor-valentino-rossi-cepat-rusak?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259772/video-ini-bisa-ungkap-masalah-setting-elektronik-bikin-ban-motor-valentino-rossi-cepat-rusak?page=all'
# masuk
# https://www.gridoto.com/read/01259769/bos-honda-ungkap-alasan-ban-soft-marc-marquez-lebih-awet-dari-ban-medium-valentino-rossi?page=all
# memasukkan berita id  259769
# Insert berita  https://www.gridoto.com/read/01259769/bos-honda-ungkap-alasan-ban-soft-marc-marquez-lebih-awet-dari-ban-medium-valentino-rossi?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259769/bos-honda-ungkap-alasan-ban-soft-marc-marquez-lebih-awet-dari-ban-medium-valentino-rossi?page=all'
# masuk
# https://www.gridoto.com/read/01259778/kondisi-kontrak-jorge-lorenzo-dengan-honda-bisa-kejadian-seperti-valentino-rossi-pindah-ke-yamaha-tahun-2004?page=all
# memasukkan berita id  259778
# Insert berita  https://www.gridoto.com/read/01259778/kondisi-kontrak-jorge-lorenzo-dengan-honda-bisa-kejadian-seperti-valentino-rossi-pindah-ke-yamaha-tahun-2004?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259778/kondisi-kontrak-jorge-lorenzo-dengan-honda-bisa-kejadian-seperti-valentino-rossi-pindah-ke-yamaha-tahun-2004?page=all'
# masuk
# https://www.gridoto.com/read/01259758/para-mekanik-yamaha-hindari-valentino-rossi-ada-masalah?page=all
# memasukkan berita id  259758
# Insert berita  https://www.gridoto.com/read/01259758/para-mekanik-yamaha-hindari-valentino-rossi-ada-masalah?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259758/para-mekanik-yamaha-hindari-valentino-rossi-ada-masalah?page=all'
# masuk
# https://www.gridoto.com/read/01259656/ingin-mengganti-pelek-mobil-pertimbangkan-hal-ini?page=all
# memasukkan berita id  259656
# Insert berita  https://www.gridoto.com/read/01259656/ingin-mengganti-pelek-mobil-pertimbangkan-hal-ini?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259656/ingin-mengganti-pelek-mobil-pertimbangkan-hal-ini?page=all'
# masuk
# https://www.gridoto.com/read/01259665/mengganti-pelek-mobil-lebih-besar-perlukah-mengubah-kaki-kaki-juga?page=all
# memasukkan berita id  259665
# Insert berita  https://www.gridoto.com/read/01259665/mengganti-pelek-mobil-lebih-besar-perlukah-mengubah-kaki-kaki-juga?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259665/mengganti-pelek-mobil-lebih-besar-perlukah-mengubah-kaki-kaki-juga?page=all'
# masuk
# https://www.gridoto.com/read/01259481/komparasi-akomodasi-antara-datsun-go-dan-brio-rs-yakin-menang-go?page=all
# memasukkan berita id  259481
# Insert berita  https://www.gridoto.com/read/01259481/komparasi-akomodasi-antara-datsun-go-dan-brio-rs-yakin-menang-go?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259481/komparasi-akomodasi-antara-datsun-go-dan-brio-rs-yakin-menang-go?page=all'
# masuk
# https://www.gridoto.com/read/01259751/toro-rosso-bakal-berkorban-buat-red-bull-demi-f1-2019?page=all
# memasukkan berita id  259751
# Insert berita  https://www.gridoto.com/read/01259751/toro-rosso-bakal-berkorban-buat-red-bull-demi-f1-2019?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259751/toro-rosso-bakal-berkorban-buat-red-bull-demi-f1-2019?page=all'
# masuk
# https://www.gridoto.com/read/01259308/kesimpulan-dan-data-tes-lengkap-honda-brio-rs-vs-datsun-go-t-active?page=all
# memasukkan berita id  259308
# Insert berita  https://www.gridoto.com/read/01259308/kesimpulan-dan-data-tes-lengkap-honda-brio-rs-vs-datsun-go-t-active?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259308/kesimpulan-dan-data-tes-lengkap-honda-brio-rs-vs-datsun-go-t-active?page=all'
# masuk
# https://www.gridoto.com/read/01259771/juara-dunia-f1-sebastian-vettel-dianggap-rentan-saat-dapat-tekanan?page=all
# memasukkan berita id  259771
# Insert berita  https://www.gridoto.com/read/01259771/juara-dunia-f1-sebastian-vettel-dianggap-rentan-saat-dapat-tekanan?page=all
# SELECT count(*) FROM article WHERE url like 'https://www.gridoto.com/read/01259771/juara-dunia-f1-sebastian-vettel-dianggap-rentan-saat-dapat-tekanan?page=all'
# masuk
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-c6891f3cbdf1> in <module>()
#       2     clear_output()
#       3     print(single_date.strftime("%Y-%m-%d"))
# ----> 4     obj.getAllBerita([], init_page, single_date.strftime("%Y/%m/%d"))
#       5     init_page = 1
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\gridoto\Gridoto.py in getAllBerita(self, details, page, date)
#      71                 if last_page != active_page:
#      72                     time.sleep(5)
# ---> 73                     details = self.getAllBerita(details, page+1, date)
#      74
#      75
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\gridoto\Gridoto.py in getAllBerita(self, details, page, date)
#      71                 if last_page != active_page:
#      72                     time.sleep(5)
# ---> 73                     details = self.getAllBerita(details, page+1, date)
#      74
#      75
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\gridoto\Gridoto.py in getAllBerita(self, details, page, date)
#      57             #     break
#      58             # else:
# ---> 59             detail = self.getDetailBerita(link)
#      60             if detail:
#      61                 if self.insertDB(detail):
#
# D:\OJT FILES\Scrapper\pyNewsSrapperIndo\gridoto\Gridoto.py in getDetailBerita(self, link)
#      80         Mengambil seluruh element dari halaman berita
#      81         """
# ---> 82         time.sleep(5)
#      83         articles = {}
#      84         #link
#
# KeyboardInterrupt:
