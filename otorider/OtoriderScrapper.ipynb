# %%
from Otorider import Otorider
import mysql.connector
#kelarr
obj = Otorider()

# %%
cat = [1, 14, 12]

# %%
init_page = 1
for c in cat:
    obj.getAllBerita([], init_page, c)
    init_page = 1
# Out:
# page  1
# http://otorider.com/post/jscategoryfeed?page=1&c=1&per-page=10
# memasukkan berita id  1535755944
# Insert berita  Kumpulan Modifikasi Motor Suzuki, Benar-Benar Bergairah & Penuh Energi
# masuk
# memasukkan berita id  1535672840
# Insert berita  Modifikasi Motor Berwarna Merah, Cocok Untuk Skutik Hingga Sport
# masuk
# memasukkan berita id  1535624237
# Insert berita  Anda Ingin Membeli Helm Arai Terbaru? Berikut Daftar Harganya!
# masuk
# memasukkan berita id  1535594258
# Insert berita  Modifikasi Motor Berkelir Biru Timbulkan Sejuta Pesona, Bikin Mata Enggan Berkedip
# masuk
# memasukkan berita id  1535497078
# Insert berita  Kumpulan Modifikasi Kawasaki Ninja 250 Paling Nyeleneh Di Indonesia, Dari Corak Wayang Hingga Iron Man
# masuk
# memasukkan berita id  1535327558
# Insert berita  Kumpulan Modifikasi Motor Sport Yamaha Vs Honda, Manakah Menurut Anda Paling Keren?
# masuk
# memasukkan berita id  1534909038
# ...
