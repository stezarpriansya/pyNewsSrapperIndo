# %%
from Rumahhokie import Rumahhokie
# import mysql.connector
#kelaarr
obj = Rumahhokie()

# %%
obj.getAllBerita([], 3)
# Out:
# page  3
# http://www.rumahhokie.com/beritaproperti/page/3/?s
# http://www.rumahhokie.com/beritaproperti/bank-btn-kucurkan-kpa-ke-dua-proyek-apartemen-pp-urban/
# memasukkan berita id  16307
# Insert berita  Bank BTN Kucurkan KPA ke Dua Proyek Apartemen PP Urban
# salah2
# http://www.rumahhokie.com/beritaproperti/tips-merancang-ruang-keluarga-yang-nyaman-dan-bersahabat/
# memasukkan berita id  16300
# Insert berita  Tips Merancang Ruang Keluarga yang Nyaman dan Bersahabat
# masuk
# http://www.rumahhokie.com/beritaproperti/kementerian-pupr-tawarkan-teknologi-risha-kepada-pengembang-perumahan/
# memasukkan berita id  16288
# Insert berita  Kementerian PUPR Tawarkan Teknologi RISHA kepada Pengembang Perumahan
# masuk
# http://www.rumahhokie.com/beritaproperti/perbaiki-sistem-distribusi-matahari-gandeng-manhattan-associates/
# memasukkan berita id  16283
# Insert berita  Perbaiki Sistem Distribusi, Matahari Gandeng Manhattan Associates
# masuk
# ...
