# %%
from Otosia import Otosia #class news Scrapper
from datetime import timedelta, date, datetime
from IPython.display import clear_output

# %%
obj = Otosia()
init_page = 616
list_cat = [['berita'],['tips'],['lifestyle'],['selebriti'],['komunitas']]
init_cat = list_cat[0:]

# %%
for cat in init_cat:
    clear_output()
    print(cat[0])
    obj.getAllBerita([], init_page, cat[0])
    init_page = 1
init_cat = list_cat
# Out:
# berita
# page  616
# https://www.otosia.com/berita/index616.html
# Insert berita  Voting Warna Mio Z, Motor Yamaha Lain Juga Bisa?
# salah2
# Insert berita  Siap siap! Nonton Balap ini Bisa Bikin Tangan Berkeringat
# salah2
# Insert berita  F1 GP Hungaria, Seri Terakhir Rio Haryanto?
# salah2
# Insert berita  Ini Tampang New Mirage yang Meluncur Selasa Depan
# salah2
# Insert berita  Marahi Pengendara Lain, Pria ini Langsung Kena Batunya!
# salah2
# Insert berita  Belum Kunjung Menangi Balapan F1 2016, Bos Ferrari Terancam Lengser
# masuk
# Insert berita  Pembeli Mau Yamaha R25 Jadi R3
# masuk
# Insert berita  Bakal Tinggalkan Suzuki, Espargaro Masih Lempar Pujian
# masuk
# Insert berita  Serius Mobil Listrik, BMW Segera Ikut Balap Formula E
# masuk
# Insert berita  Valentino Rossi Setuju Ide Komunikasi Radio Di MotoGP
# masuk
# Insert berita  Honda CB150R Berbaju CBR 250 Tokyo Concept
# masuk
# Insert berita  General Motors Segera Siapkan Pesaing Wrangler?
# masuk
# Insert berita  Gagal Finis Di Jerman, Espargaro Fokus Suzuka 8 Hours
# masuk
# Insert berita  Bugatti Veyron Super Sport Spesial, Dijual dengan Harga 'Absurd'
# masuk
# Insert berita  BMW Kenalkan Sedan Pertama Dengan Penggerak Roda Depan
# masuk
# page  617
# https://www.otosia.com/berita/index617.html
# Insert berita  Gagal Podium, Miller Banyak Belajar Dari MotoGP Jerman
# masuk
# Insert berita  Inilah Alasan Mengapa Bus 'Ngebut' adalah Pemancing Maut!
# masuk
# Insert berita  Merasa Iklan Mobil Membosankan? Coba Tonton Punya Honda
# masuk
# Insert berita  Tak Nyaman Di Jerman, Pedrosa Pasrah Finis Keenam
# masuk
# Insert berita  Datsun Spesial Lebaran Banyak Dipinang Selama PRJ
# masuk
# Insert berita  Lorenzo: Segalanya Belum Berakhir, Marquez!
# masuk
# Insert berita  Mau Jadi Biker Harley? Pakai yang 500 CC Dulu
# masuk
# Insert berita  Datsun Sukses Jual 639 Mobil Selama PRJ
# masuk
# Insert berita  Ubah Hadiah Spesial Jadi Cafe Racer
# masuk
# Insert berita  Baik'ers Garas Siap Antar-Jemput Servis Harley Davidson
# masuk
# Insert berita  Inilah Sosok Legenda lainnya dari Pabrikan Suzuki
# masuk
# Insert berita  Begini Gambaran Paket Kredit Mobil Murah 7 Penumpang versi ACC
# masuk
# Insert berita  Honda CB750 1969 Adalah Superbike Pertama di Dunia
# masuk
# Insert berita  Honda Big Wing Akan Hadir di Jakarta Pusat
# masuk
# Insert berita  New Mega Pro Berkonsep Black to Black
# masuk
# page  618
# https://www.otosia.com/berita/index618.html
# Insert berita  Mabua Tutup, Baik'ers Garas Tampung Bikers Harley yang Butuh Servis
# masuk
# Insert berita  FIAT-Chrysler Tantang Hacker Untuk Retas Produknya
# masuk
# Insert berita  Rossi Sebut Kejar Marquez Bikin Tugas Lebih Berat
# masuk
# Insert berita  Pilih Warna Evora Edisi Spesial, Lotus Gelar Poling
# masuk
# Insert berita  Unggul 48 Poin, Marquez Akui Tak Boleh Lengah
# masuk
# Insert berita  Tiga Alasan Umum Mengapa Mobil MPV Tetap Laris di Pasar Otomotif
# masuk
# Insert berita  Idul Fitri di Italia, Pebalap RI Dapat Selamat Lebaran dari Rossi
# masuk
# Insert berita  Redding Frustrasi Gagal Ulang Podium Di Sachsenring
# masuk
# Insert berita  Go-kart ini Sukses Permalukan Lamborghini di Jalan Tol!
# masuk
# Insert berita  Jual Warna Merah, Yamaha Optimis Mio Z Makin Diburu
# masuk
# Insert berita  Jorge Lorenzo: Pekan Balap Penuh Bencana
# masuk
# Insert berita  Mitsubishi Indonesia pastikan New Mirage meluncur Selasa pekan depan
# masuk
# Insert berita  Saat Para 'Racer' Bernostalgia dengan Tamiya-nya, Begini Keseruannya!
# masuk
# Insert berita  FMI Finalisasi Kontrak dengan RMA Group, Diler Tetap Aktif
# masuk
# Insert berita  Dovizioso: Jika Ada Yang Harus Marah, Maka Itu Saya!
# masuk
# page  619
# https://www.otosia.com/berita/index619.html
# Insert berita  LCGC MPV Cayla-Sigra Total Hampir 100.000 Unit?
# masuk
# Insert berita  Ford Luncurkan Mustang Edisi Spesial, Inspirasi Dari Pesawat Tempur
# masuk
# Insert berita  Crutchlow Puas Akhirnya Kembali Rebut Podium
# masuk
# Insert berita  Yamaha Bawa 10 Orang Bergaya Z-Selfie Nonton MotoGP Sepang
# masuk
# Insert berita  Kecewa Finis Kedelapan, Rossi Akui Sangat Lamban
# masuk
# Insert berita  Pedaftaran Asia Talent Cup 2017 Resmi Dibuka
# masuk
# Insert berita  Out of the Box, Bristol Siap Berikan Sportscar yang 'Beda'!
# masuk
# Insert berita  Menangi MotoGP Jerman, Marquez Kepikiran Motocross
# masuk
# Insert berita  BMW Siapkan Seri 3 Full Electric
# masuk
# Insert berita  Berapa RPM yang Mampu Dicapai Mesin Aston Martin-Red Bull?
# masuk
# Insert berita  Jelang GP F1 Hungaria, Pilihan Ban Hampir Sama Semua
# masuk
# Insert berita  Klasemen Sementara MotoGP 2016 Usai Seri Jerman
# masuk
# Insert berita  Seperti Apa Jadinya Jika Pembalap F1 Lintas Generasi Balapan Karting?
# masuk
# Insert berita  Sachsenring Penuh Drama, Marquez Juarai MotoGP Jerman
# masuk
# Insert berita  Rayakan Kemenangan Pesawat Legendaris, Aston Martin Luncurkan Vantage Edisi Terbatas
# masuk
# page  620
# https://www.otosia.com/berita/index620.html
# Insert berita  Yamaha N-Max Laris Manis di Jakarta Fair
# masuk
# Insert berita  Klasemen Sementara Moto3 2016 Usai Seri Jerman
# masuk
# Insert berita  Konsumen Minta Warna, Yamaha Lepas Mio Z Merah
# masuk
# Insert berita  Pawi Raih Kemenangan Kedua Di Moto3 Jerman
# masuk
# Insert berita  Ford Tunjuk Tim Balap untuk Latih Mekanik Ford GT
# masuk
# Insert berita  Ini Alasan Munculnya Mio Z Merah Rp 15,1 Juta
# masuk
# Insert berita  Pedrosa Tercepat Di Sesi Pemanasan MotoGP Jerman
# masuk
# Insert berita  Mio Z Merah Luncur Bersama Pebalap Lulusan Akademi Rossi
# masuk
# Insert berita  Headunit Layar Toyota Innova Rp 1,7 Juta Sudah Pasang
# masuk
# Insert berita  Honda Freed Jadi Soal karena Bentuknya Kotak
# masuk
# Insert berita  KIA Sudah 2 Tahun Tak Jualan MPV
# masuk
# Insert berita  Anti Berisik Angin, Sena Prism Tube Pilihan Jitu Motovlog
# masuk
# Insert berita  Konfirmasi Resmi BMW Motorrad Terkait R nineT Scrambler X
# masuk
# Insert berita  All New Kawasaki Ninja 1000 Dikabarkan Akan Menggantikan Z1000SX
# masuk
# Insert berita  Sinatra, Custom Cafe Tiger Revo 2012
# masuk
# page  621
# https://www.otosia.com/berita/index621.html
# Insert berita  Rayakan 75 Tahun Produksi Jeep, Wrangler Bertampilan Retro
# masuk
# Insert berita  Royal Enfield 750cc Paralel-Twin Mulai Tes Jalan
# masuk
# Insert berita  Mau Melepas Kaca Film? Begini Cara Mudahnya, Bro
# masuk
# Insert berita  Mazda 2 Dapat 'Red Edition', Tampak Elegan dan Mewah!
# masuk
# Insert berita  Buruan, Pendaftaran Asia Talent Cup 2017 Dibuka Hari Ini
# masuk
# Insert berita  TVS Luncurkan Teaser Resmi Akula 310, Tapi...
# masuk
# Insert berita  Ford Focus RS Ilegal di Australia, Kenapa?
# masuk
# Insert berita  Sembrono Terobos Perlintasan Kereta, Pemotor 'Dihajar' Kereta Api
# masuk
# Insert berita  Sedan Honda Indonesia, Bisa Pinjam Bodi Jazz-CRV
# masuk
# Insert berita  Audi dan Bentley Tertarik Gunakan Mesin Canggih Milik Porsche
# masuk
# Insert berita  Begini Jadinya Jika Tim F1 Parodikan Serial Drama
# masuk
# Insert berita  Begini Jadinya Jika Tracktor Dijadikan Mobil F1
# masuk
# Insert berita  Dua Jagoan 'Kecil' Old-School Suzuki Terbaru Untuk Tahun 2017
# masuk
# Insert berita  Freed Baru, Apa Kata Bos Honda Indonesia?
# masuk
# Insert berita  Deretan Moge Roda Tige Can-Am Spyder Terbaru Model 2017
# masuk
# page  622
# https://www.otosia.com/berita/index622.html
# Insert berita  Tiongkok Siap Bikin Toyota Innova
# masuk
# Insert berita  Semakin Tangguh, Inilah Yamaha WR250R Terbaru
# masuk
# Insert berita  Inikah Nissan March Generasi Selanjutnya?
# masuk
# Insert berita  Ini Akibatnya Jika Main Pokemon Tanpa Perhatikan Jalan
# masuk
# Insert berita  Iannone Pimpin Latihan Perdana MotoGP Jerman
# masuk
# Insert berita  Yamaha Byson Tunggangan L002 Byonic Suroboyo
# masuk
# Insert berita  Inilah Mengapa Menantang Mobil Penyemprot Air Adalah Ide Buruk!
# masuk
# Insert berita  Jamin Kualitas, CEO Aston Martin Inspeksi Produknya Sendiri
# masuk
# Insert berita  Seperti Inilah Hasilnya Jika Mercedes-Benz Membuat Mobil Golf
# masuk
# Insert berita  Marquez: Awasi Lorenzo, Jangan Lupakan Rossi!
# masuk
# Insert berita  Harga Resmi Subaru BRZ 2017 Dirilis!
# masuk
# Insert berita  Segmen LCGC Terus Berkembang, City Car Sudah Jenuh
# masuk
# Insert berita  Tato Tubuh Bisa Dipakai Untuk Bodi Mobil?
# masuk
# Insert berita  Alex Marquez Resmi Bertahan Di Marc VDS Tahun Depan
# masuk
# Insert berita  Menegangkan! Karena Cara Parkir Mobil, Konflik ini Berakhir Mengejutkan
# masuk
# page  623
# https://www.otosia.com/berita/index623.html
# Insert berita  Lupa Tidak Dikunci, Mobil Menjadi Sarang Beruang
# masuk
# Insert berita  Gara-gara Satu Truk, Suasana Negara Perancis Mencekam
# masuk
# Insert berita  Ford Mustang Dikatakan Muscle Car Super Cepat, Seberapa Cepatkah?
# masuk
# Insert berita  Cara Paling Tepat Derek Kendaraan Besar yang Terguling
# masuk
# Insert berita  Diler Protes Keras Ford Tunjuk Pihak Ketiga Soal Sukucadang
# masuk
# Insert berita  Ini Kata Rossi Tentang Sebutan 'The Doctor' dalam Video Keempatnya
# masuk
# Insert berita  Komunitas Kia Picanto Serentak Baksos di 2 Kota
# masuk
# Insert berita  Cerita Biker Klub Byson Menikmati Kepadatan Mudik
# masuk
# Insert berita  Berburu Aksesori Mobil dengan Harga Miring di Jakarta Fair
# masuk
# Insert berita  '18 Milestone Moments' Tandai Hari Jadi Pabrikan Moge Victory
# masuk
# Insert berita  Panitia GIIAS Siapkan Lomba Tujuh Belasan Tarik Truk
# masuk
# Insert berita  Husqvarna Resmi Umumkan Deretan Motor Enduro Terbarunya
# masuk
# Insert berita  Yamaha Scorpio 2009 Custom Tracker
# masuk
# Insert berita  SUV Ford Ecosport Baru Dipasangi Mesin 'Naga'
# masuk
# Insert berita  Mari Cermati Bagaimana Cara Kopling Motor Bekerja
# masuk
# page  624
# https://www.otosia.com/berita/index624.html
# Insert berita  Harga Cocok di Kantong, Belum Tentu Orang Beli Mobil
# masuk
# Insert berita  5 Mobil Honda Terlaris di Tengah Tahun
# masuk
# Insert berita  TNI dan Guru Gratis Masuk Pameran Otomotif GIIAS
# masuk
# Insert berita  Tidak Laku, Tesla Luncurkan Mobil Listrik Varian Termurah
# masuk
# Insert berita  Vinales: Rossi Bukan Iming-iming Gabung Yamaha
# masuk
# Insert berita  Waduh! Porsche 918 Kena Recall, Apa Penyebabnya?
# masuk
# Insert berita  Inilah Penyebab Mengapa Ganti Ban Truk Bisa Sangat Berbahaya!
# masuk
# Insert berita  Komisi X Sayangkan MotoGP Gagal Digelar Di Indonesia
# masuk
# Insert berita  Edan! Balapan ini Lebih Mengerikan dari Isle of Man
# masuk
# Insert berita  BR-V, Mobilio dan HR-V Masih Menjadi Backbone Penjualan Honda
# masuk
# Insert berita  Greget! Berburu Pokemon di Sirkuit Nurburgring
# masuk
# Insert berita  Ups! Porsche 911 GT3 Terbaru Bocor Lewat Buku Mewarnai
# masuk
# Insert berita  Inilah Tampang LaFerrari Atap Terbuka
# masuk
# Insert berita  Suzuki Umumkan Dua Model Motor Trail Terbarunya
# masuk
# Insert berita  BMW Motorrad Umumkan Penyegaran Pada Deretan R1200 Terbarunya
# masuk
# page  625
# https://www.otosia.com/berita/index625.html
# Insert berita  Saat Mudik Shell Ganti Oli Gratis 160 Mobil Komunitas Subuh
# masuk
# Insert berita  Bottpower Hadirkan Pesaing H-D XG750R Street Tracker
# masuk
# Insert berita  Nissan Beberkan Tampang Asli All New Serena 2017
# masuk
# Insert berita  Harley-Davidson Diisukan Merugi dan Pindah Tangan
# masuk
# Insert berita  New Mirage Menampakkan Diri Senin Depan
# masuk
# Insert berita  Pertamina Perkenalkan Oli Bio Diesel Mobil Penumpang dan Niaga
# masuk
# Insert berita  LCGC Baru Honda Jadi Buruan
# masuk
# Insert berita  Target 180.000, Honda Sudah Jual 100.000 Mobil
# masuk
# Insert berita  Paling Powerful di Kelasnya, Hyundai Bongkar Bungkus Elantra 2017!
# masuk
# Insert berita  Demam Pokemon Go, Kesempatan Jadi Sopir Pemain Pokemon Terbuka
# masuk
# Insert berita  Rayakan Hari Jadi, Toyota Luncurkan Corolla 50th Anniversary
# masuk
# Insert berita  Tak Cuma Jalan, Para Pria ini Main Pokemon Go Pakai Porsche!
# masuk
# Insert berita  BMW Akan Hentikan Produksi Z4, Apa Alasannya?
# masuk
# Insert berita  'Nyelonong' Saat isi Bensin, Mobil ini Bikin Mesin SPBU Terbakar!
# masuk
# Insert berita  Dukungan Veloz Community dalam Arus Mudik dan Arus Balik Tahun 2016
# masuk
# page  626
# https://www.otosia.com/berita/index626.html
# Insert berita  Saingi NSX dan GT-R, Toyota Supra Terbaru Akan Gunakan Mesin BMW
# masuk
# Insert berita  Sudah Berhenti Produksi, Miliuner Ini Ingin Bangkitkan Land Rover Defender
# masuk
# Insert berita  Jazz Crossover Mulai Tampakkan 'Hidung' Mirip CR-V
# masuk
# Insert berita  DAM Bidik Juara Kontes Layanan Motor Honda Nasional
# masuk
# Insert berita  Aplikasi ANAVIGO Bisa Dimanfaatkan Saat Arus Balik Lebaran
# masuk
# Insert berita  Sentul Dapat Saingan Jadi Tuan Rumah MotoGP
# masuk
# Insert berita  Supaya Pebalap Indonesia Pro, Orang Tua Jangan Ikut Campur
# masuk
# Insert berita  Kabin Sporty Elegan Toyota 86 Facelift Terbaru
# masuk
# Insert berita  Honda Freed Terbaru Mirip Jazz
# masuk
# Insert berita  Porsche Panamera Terbaru Muncul ke Publik
# masuk
# Insert berita  Apes, Perancis Kalah, Bus Kemenangan Tertangkap Kamera
# masuk
# Insert berita  Renaldi dari Indonesia Menang Balapan Ferrari di Cina
# masuk
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     440             try:
# --> 441                 cnx.do_handshake()
#     442             except OpenSSL.SSL.WantReadError:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1805         result = _lib.SSL_do_handshake(self._ssl)
# -> 1806         self._raise_ssl_error(self._ssl, result)
#    1807
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1538                         raise SysCallError(errno, errorcode.get(errno))
# -> 1539                 raise SysCallError(-1, "Unexpected EOF")
#    1540             else:
#
# SysCallError: (-1, 'Unexpected EOF')
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     325             server_hostname=hostname,
# --> 326             ssl_context=context)
#     327
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     328     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 329         return context.wrap_socket(sock, server_hostname=server_hostname)
#     330
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     447             except OpenSSL.SSL.Error as e:
# --> 448                 raise ssl.SSLError('bad handshake: %r' % e)
#     449             break
#
# SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='www.otosia.com', port=443): Max retries exceeded with url: /berita/tidak-bisa-kompetitif-honda-gagal-dapatkan-tim-kedua-di-f1.html (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')",),))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-26-c154e5164c38> in <module>()
#       2     clear_output()
#       3     print(cat[0])
# ----> 4     obj.getAllBerita([], init_page, cat[0])
#       5     init_page = 1
#       6 init_cat = list_cat
#
# D:\OJT\pyNewsSrapperIndo\otosia\Otosia.py in getAllBerita(self, details, page, cat, date)
#      70             if active_page <= last_page:
#      71                 time.sleep(5)
# ---> 72                 details = self.getAllBerita(details, active_page+1, cat, date)
#      73
#      74         return 'berhasil ambil semua berita'
#
# D:\OJT\pyNewsSrapperIndo\otosia\Otosia.py in getAllBerita(self, details, page, cat, date)
#      70             if active_page <= last_page:
#      71                 time.sleep(5)
# ---> 72                 details = self.getAllBerita(details, active_page+1, cat, date)
#      73
#      74         return 'berhasil ambil semua berita'
#
# D:\OJT\pyNewsSrapperIndo\otosia\Otosia.py in getAllBerita(self, details, page, cat, date)
#      70             if active_page <= last_page:
#      71                 time.sleep(5)
# ---> 72                 details = self.getAllBerita(details, active_page+1, cat, date)
#      73
#      74         return 'berhasil ambil semua berita'
#
# D:\OJT\pyNewsSrapperIndo\otosia\Otosia.py in getAllBerita(self, details, page, cat, date)
#      70             if active_page <= last_page:
#      71                 time.sleep(5)
# ---> 72                 details = self.getAllBerita(details, active_page+1, cat, date)
#      73
#      74         return 'berhasil ambil semua berita'
#
# D:\OJT\pyNewsSrapperIndo\otosia\Otosia.py in getAllBerita(self, details, page, cat, date)
#      70             if active_page <= last_page:
#      71                 time.sleep(5)
# ---> 72                 details = self.getAllBerita(details, active_page+1, cat, date)
#      73
#      74         return 'berhasil ambil semua berita'
#
# D:\OJT\pyNewsSrapperIndo\otosia\Otosia.py in getAllBerita(self, details, page, cat, date)
#      70             if active_page <= last_page:
#      71                 time.sleep(5)
# ---> 72                 details = self.getAllBerita(details, active_page+1, cat, date)
#      73
#      74         return 'berhasil ambil semua berita'
#
# D:\OJT\pyNewsSrapperIndo\otosia\Otosia.py in getAllBerita(self, details, page, cat, date)
#      70             if active_page <= last_page:
#      71                 time.sleep(5)
# ---> 72                 details = self.getAllBerita(details, active_page+1, cat, date)
#      73
#      74         return 'berhasil ambil semua berita'
#
# D:\OJT\pyNewsSrapperIndo\otosia\Otosia.py in getAllBerita(self, details, page, cat, date)
#      70             if active_page <= last_page:
#      71                 time.sleep(5)
# ---> 72                 details = self.getAllBerita(details, active_page+1, cat, date)
#      73
#      74         return 'berhasil ambil semua berita'
#
# D:\OJT\pyNewsSrapperIndo\otosia\Otosia.py in getAllBerita(self, details, page, cat, date)
#      70             if active_page <= last_page:
#      71                 time.sleep(5)
# ---> 72                 details = self.getAllBerita(details, active_page+1, cat, date)
#      73
#      74         return 'berhasil ambil semua berita'
#
# D:\OJT\pyNewsSrapperIndo\otosia\Otosia.py in getAllBerita(self, details, page, cat, date)
#      70             if active_page <= last_page:
#      71                 time.sleep(5)
# ---> 72                 details = self.getAllBerita(details, active_page+1, cat, date)
#      73
#      74         return 'berhasil ambil semua berita'
#
# D:\OJT\pyNewsSrapperIndo\otosia\Otosia.py in getAllBerita(self, details, page, cat, date)
#      57             #     break
#      58             # else:
# ---> 59             detail = self.getDetailBerita(link)
#      60             if detail:
#      61                 if self.insertDB(detail):
#
# D:\OJT\pyNewsSrapperIndo\otosia\Otosia.py in getDetailBerita(self, link)
#      82         #link
#      83         url = link[0]
# ---> 84         response = requests.get(url)
#      85         html = response.text
#      86         # Create a BeautifulSoup object from the HTML: soup
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     504             if isinstance(e.reason, _SSLError):
#     505                 # This branch is for urllib3 v1.22 and later.
# --> 506                 raise SSLError(e, request=request)
#     507
#     508             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='www.otosia.com', port=443): Max retries exceeded with url: /berita/tidak-bisa-kompetitif-honda-gagal-dapatkan-tim-kedua-di-f1.html (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')",),))
