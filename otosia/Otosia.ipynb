# %%
from Otosia import Otosia #class news Scrapper
from datetime import timedelta, date, datetime
from IPython.display import clear_output

# %%
# error date 796
# error date 942
# halaman terakhir 3215
obj = Otosia()
init_page = 1017
list_cat = [['berita'],['tips'],['lifestyle'],['selebriti'],['komunitas']]
init_cat = list_cat[0:]

# %%
for cat in init_cat:
    clear_output()
    print(cat[0])
    obj.getAllBerita([], init_page, cat[0])
    init_page = 1
init_cat = list_cat
# Out:
# berita
# page  1017
# https://www.otosia.com/berita/index1017.html
# Insert berita  Casey Stoner-Ducati Berpotensi 'CLBK' di MotoGP 2016
# salah2
# Insert berita  Marquez-Vinales Pimpin Hari Kedua Uji Coba Pascamusim MotoGP
# salah2
# Insert berita  Yamaha Siapkan Sajian Istimewa di Seri Pamungkas YCR
# salah2
# Insert berita  Sering Naik Motor, Komunitas Kutu Vespa Cari Tahu Soal Tulang
# salah2
# Insert berita  Mobil Kena Recall Tak Dikenakan Biaya oleh Honda
# salah2
# Insert berita  TACI Wilayah Tangerang Adakan Touring dan Family Gathering yang Pertama
# salah2
# Insert berita  Honda Mobil Tambah Sekolah Binaan Teknis di Tangerang Selatan
# salah2
# Insert berita  Perkumpulan N-Max Puluhan Kota Se-Indonesia Dibentuk Tanpa Kepala
# salah2
# Insert berita  Naik Motor N-Max Sendirian 1.000 Km dari Palembang
# salah2
# Insert berita  Ferrari Dapat Rp 12,03 Triliun
# salah2
# Insert berita  Bocoran Kabin Mewah Kijang Innova
# salah2
# Insert berita  Banyak yang Tanya, Kawasaki Masih Tahan Pemesanan Ninja ZX-10R
# salah2
# Insert berita  Bersaing di Segmen Low MPV, Ertiga Gratiskan 6 Kali Cicilan
# salah2
# Insert berita  2.553 Suzuki Ertiga Banjiri Kawasan Sentul City
# salah2
# Insert berita  Eksklusif, Produksi Fenyr Supersport Bakal Dibatasi
# salah2
# page  1018
# https://www.otosia.com/berita/index1018.html
# Insert berita  Kijang Innova Luncur 2 Minggu Lagi
# salah2
# Insert berita  Harga Terendah All-New Innova Masih di bawah Rp 300 Juta
# salah2
# Insert berita  Begini Cara Nissan Pikat Calon Pembeli X-Trail
# salah2
# Insert berita  Simak Otolovers, Proses Pembuatan Turbocharge pada Mobil
# salah2
# Insert berita  Honda Ambil Alih Kepemimpinan Segmen Motor Sport
# salah2
# Insert berita  Jalanan Ekstrim Ini Jadi Tantangan Bagi Sopir Truk
# salah2
# Insert berita  Komunitas RX-King Jakarta Tembus 1.000 Anggota
# salah2
# Insert berita  Yamaha Ogah Kembalikan Dinding Pemisah Lorenzo-Rossi
# salah2
# Insert berita  10 Jalanan Paling Mematikan yang Tak Pernah Anda Bayangkan
# masuk
# Insert berita  Yogyakarta Jadi Seri Pamungkas BlackAuto Battle 2015
# masuk
# Insert berita  'Meski Tak Dipenalti, Rossi Tetap Takkan Bisa Juara'
# masuk
# Insert berita  Pengendara Ini Salah Jalur di Jalan Tol, Sebabkan Kecelakaan Maut
# masuk
# Insert berita  Inilah Cara Test Helm yang 'Istimewa'
# masuk
# Insert berita  Jajal Ban Baru Michelin, Ini Evaluasi Jorge Lorenzo
# masuk
# Insert berita  Terobos Lampu Merah, Bus Ini Sebabkan Kecelakaan Beruntun
# masuk
# page  1019
# https://www.otosia.com/berita/index1019.html
# Insert berita  Marquez: Butuh Waktu Pelajari ECU MotoGP 2016
# masuk
# Insert berita  Yard Built Yamaha 'Faster Wasp' Flat-Tracker by Roland Sands
# masuk
# Insert berita  Kesalahan Para Pengendara Ini Bisa Dijadikan Pelajaran
# masuk
# Insert berita  Berniat isi Ban, Pria ini Coba Ungkap Penipuan Pengisian Nitrogen
# masuk
# Insert berita  Uji Coba Pascamusim, Rossi Langsung Komentari ECU Baru
# masuk
# Insert berita  Wow, Lihat Cara Pria Ini Cuci Mobilnya!
# masuk
# Insert berita  Auto2000, Dealer Pertama Peraih Sertifikasi TSM Kodawari
# masuk
# Insert berita  Uji Coba Regulasi Baru, Marquez Tercepat di Valencia
# masuk
# Insert berita  Klub PI1 Nikmati Keindahan Teluk Kiluan
# masuk
# Insert berita  Pajero Indonesia One Tambah Dua Chapter Baru
# masuk
# Insert berita  Piaggio Indonesia: Persaingan Itu Penting
# masuk
# Insert berita  Fenyr Supersport, 'Adik' Sang Hypercar Termahal Dunia Dirilis!
# masuk
# Insert berita  Honda BR-V Dipasarkan Kwartal Awal Tahun 2016
# masuk
# Insert berita  Perempuan Berani Naik Yamaha N-Max
# masuk
# Insert berita  'Auman' Knalpot Motor Sport Tak Harus Selalu Menggelegar?
# masuk
# page  1020
# https://www.otosia.com/berita/index1020.html
# Insert berita  Suzuki Siapkan APV Baru?
# masuk
# Insert berita  Yamaha Resonator, Retro-Classic Beraroma Mewah 125cc
# masuk
# Insert berita  Piaggio Indonesia Berikan Pengalaman Sempurna di MotoPlex 2015
# masuk
# Insert berita  Ini Harga Evoque Convertible yang Debut Minggu Depan!
# masuk
# Insert berita  Begini Jika Halalkan Segala Cara Untuk Mendahului
# masuk
# Insert berita  Raup Transaksi Lebih Rp 1 Miliar, IDE 2015 Dihadiri Diecaster Australia
# masuk
# Insert berita  'Gondol' SUV, Wanita Ini Tabrak Polisi Dalam Kecepatan Tinggi
# masuk
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     440             try:
# --> 441                 cnx.do_handshake()
#     442             except OpenSSL.SSL.WantReadError:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1805         result = _lib.SSL_do_handshake(self._ssl)
# -> 1806         self._raise_ssl_error(self._ssl, result)
#    1807
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1538                         raise SysCallError(errno, errorcode.get(errno))
# -> 1539                 raise SysCallError(-1, "Unexpected EOF")
#    1540             else:
#
# SysCallError: (-1, 'Unexpected EOF')
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     325             server_hostname=hostname,
# --> 326             ssl_context=context)
#     327
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     328     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 329         return context.wrap_socket(sock, server_hostname=server_hostname)
#     330
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     447             except OpenSSL.SSL.Error as e:
# --> 448                 raise ssl.SSLError('bad handshake: %r' % e)
#     449             break
#
# SSLError: ("bad handshake: SysCallError(-1, 'Unexpected EOF')",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='www.otosia.com', port=443): Max retries exceeded with url: /berita/benarkah-ini-sosok-matic-bongsor-terbaru-honda.html (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')",),))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-5-c154e5164c38> in <module>()
#       2     clear_output()
#       3     print(cat[0])
# ----> 4     obj.getAllBerita([], init_page, cat[0])
#       5     init_page = 1
#       6 init_cat = list_cat
#
# D:\OJT\pyNewsSrapperIndo\otosia\Otosia.py in getAllBerita(self, details, page, cat, date)
#      70             if active_page <= last_page:
#      71                 time.sleep(5)
# ---> 72                 details = self.getAllBerita(details, active_page+1, cat, date)
#      73
#      74         return 'berhasil ambil semua berita'
#
# D:\OJT\pyNewsSrapperIndo\otosia\Otosia.py in getAllBerita(self, details, page, cat, date)
#      70             if active_page <= last_page:
#      71                 time.sleep(5)
# ---> 72                 details = self.getAllBerita(details, active_page+1, cat, date)
#      73
#      74         return 'berhasil ambil semua berita'
#
# D:\OJT\pyNewsSrapperIndo\otosia\Otosia.py in getAllBerita(self, details, page, cat, date)
#      70             if active_page <= last_page:
#      71                 time.sleep(5)
# ---> 72                 details = self.getAllBerita(details, active_page+1, cat, date)
#      73
#      74         return 'berhasil ambil semua berita'
#
# D:\OJT\pyNewsSrapperIndo\otosia\Otosia.py in getAllBerita(self, details, page, cat, date)
#      57             #     break
#      58             # else:
# ---> 59             detail = self.getDetailBerita(link)
#      60             if detail:
#      61                 if self.insertDB(detail):
#
# D:\OJT\pyNewsSrapperIndo\otosia\Otosia.py in getDetailBerita(self, link)
#      82         #link
#      83         url = link[0]
# ---> 84         response = requests.get(url)
#      85         html = response.text
#      86         # Create a BeautifulSoup object from the HTML: soup
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     504             if isinstance(e.reason, _SSLError):
#     505                 # This branch is for urllib3 v1.22 and later.
# --> 506                 raise SSLError(e, request=request)
#     507
#     508             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='www.otosia.com', port=443): Max retries exceeded with url: /berita/benarkah-ini-sosok-matic-bongsor-terbaru-honda.html (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')",),))
